# %%
## This Cell is related to date preprocessing and is completely copied from original kipf's github code!

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.sparse as sp
import torch,torch.nn,torch.sparse,torch.nn.functional,torch.distributions
from sklearn.metrics import roc_auc_score,average_precision_score
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
np.set_printoptions(threshold=np.inf)


from google.colab import drive
drive.mount('/content/drive')


W_gene      =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/gene.txt", delim_whitespace=True).to_numpy()
W_methy     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/methy.txt", delim_whitespace=True).to_numpy()
W_mirna     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/mirna.txt", delim_whitespace=True).to_numpy()

gene      =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Gene_Expression.txt", delim_whitespace=True).to_numpy().transpose()
methy     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Methy_Expression.txt", delim_whitespace=True).to_numpy().transpose()
mirna     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Mirna_Expression.txt", delim_whitespace=True).to_numpy().transpose()
truelabel =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Survival.txt", delim_whitespace=True).to_numpy()



print(gene.shape)
print(methy.shape)
print(mirna.shape)

def get_nomralized_laplacian(a):
    b = np.diag(np.power(1.0 / a.sum(axis=1), 0.5))
    return (b @ a @ b)





features = np.c_[mirna,methy,gene]

patient_no = features.shape[0]

idx = np.arange(patient_no)
np.random.shuffle(idx)
train_idx = idx[0:int(patient_no * 0.75)]
val_idx =   idx[int(patient_no * 0.75):]

train_features = features[train_idx]
train_features = features
val_features   = features[val_idx]
print(train_features.shape)
print(val_features.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# (215, 12042)
# (215, 1305)
# (215, 534)
# (215, 13881)
# (54, 13881)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.

# %%
#Model definition Cell

num_features = features.shape[1]

train_features_tensor  = torch.Tensor(train_features)
val_features_tensor    = torch.Tensor(val_features)





class Model(torch.nn.Module):

    def __init__(self,**kwargs):
        super(Model, self).__init__(**kwargs)
        
        
        
            

        self.W0 = torch.nn.Linear(num_features,6000)
        self.W1 = torch.nn.Linear(6000,3000)
        self.W2 = torch.nn.Linear(3000,6000)
        self.W3 = torch.nn.Linear(6000,num_features)

        self.drouput1 = torch.nn.Dropout(p=0)
        self.drouput2 = torch.nn.Dropout(p=0)
        
        param_list = []
        param_list += list(self.W0.parameters())
        param_list += list(self.W1.parameters())
        param_list += list(self.W2.parameters())
        param_list += list(self.W3.parameters())
        
        

        self.optimizer = torch.optim.Adam(param_list,lr=0.0001)
        self.recon = None
        
        self.normal_dist = torch.distributions.MultivariateNormal(loc=torch.zeros(3000),scale_tril=torch.eye(3000))

        
        
        
    


        
    def forward(self,x) : 
        self.layer_1 = torch.nn.functional.tanh(self.W0(self.drouput1(x)))
        self.layer_2 = torch.nn.functional.tanh(self.W1(self.drouput2(self.layer_1)))
        self.layer_3 = torch.nn.functional.tanh(self.W2(self.layer_2+self.normal_dist.sample((x.shape[0],))))
        self.layer_4 = self.W3(self.layer_3)
        
        

        self.x_prim = self.layer_4
        self.embedding = self.layer_2
        
        self.recon_loss = ((self.x_prim-x)**2).mean(0)
        self.recon_loss = self.recon_loss[0:534].mean()+self.recon_loss[534:534+1305].mean()+self.recon_loss[534+1305:534+1305+12042].mean()
        self.recon_loss = self.recon_loss/3
       
        self.l1_regularization =  (torch.norm(list(self.W0.parameters())[0],1))+(torch.norm(list(self.W1.parameters())[0],1))

        #print(self.l1_regularization)
        self.loss = self.recon_loss 
        #self.l1_regularization/1000000
        
        
        
        
        
        return self.loss.item()
        
    def backward(self) :
        
        self.optimizer.zero_grad()
        self.loss.backward()
        self.optimizer.step()

        
        
    def get_cosine_sim_emb(self):
        
        emb = self.embedding.detach().numpy()

        norms =  (emb*emb).sum(1).reshape(-1,1)**0.5
        normalized_emb = emb/norms

        emb_matrix = np.abs( normalized_emb@normalized_emb.transpose())
        return emb_matrix
        

    def get_euclidian(self):
        emb = self.embedding.detach().numpy()
        
        emb_matrix = np.zeros((emb.shape[0],emb.shape[0]))
        
        for i in range(emb.shape[0]):
            for j in range(emb.shape[0]):
                emb_matrix[i,j] = ((emb[i]-emb[j])**2).sum()
                
        return emb_matrix

# %%
#Training Cell 

my_model = Model()


for epoch_counter in range(20000):
    
    train_loss = my_model.forward(train_features_tensor)
    my_model.backward()
    val_loss = my_model.forward(val_features_tensor)
    my_model.optimizer.zero_grad()
    #val_loss = 0

    if epoch_counter % 1 ==0:
        print("Epoch:", '%04d' % (epoch_counter + 1), "train_loss=", "{:.5f}".format(train_loss), "val_loss=", "{:.5f}".format(val_loss))


print('\n',"#########################################################",'\n')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch: 0001 train_loss= 1.06868 val_loss= 1.02654
# Epoch: 0002 train_loss= 1.02658 val_loss= 0.98555
# Epoch: 0003 train_loss= 0.98354 val_loss= 0.93675
# Epoch: 0004 train_loss= 0.93986 val_loss= 0.89517
# Epoch: 0005 train_loss= 0.89666 val_loss= 0.85550
# Epoch: 0006 train_loss= 0.85766 val_loss= 0.81874
# Epoch: 0007 train_loss= 0.81994 val_loss= 0.78527
# Epoch: 0008 train_loss= 0.78825 val_loss= 0.75806
# Epoch: 0009 train_loss= 0.76082 val_loss= 0.73077
# Epoch: 0010 train_loss= 0.73497 val_loss= 0.70572
# Epoch: 0011 train_loss= 0.71158 val_loss= 0.68384
# Epoch: 0012 train_loss= 0.69242 val_loss= 0.66686
# Epoch: 0013 train_loss= 0.67093 val_loss= 0.64699
# Epoch: 0014 train_loss= 0.65494 val_loss= 0.63307
# Epoch: 0015 train_loss= 0.63877 val_loss= 0.61432
# Epoch: 0016 train_loss= 0.62380 val_loss= 0.59859
# Epoch: 0017 train_loss= 0.60987 val_loss= 0.58787
# Epoch: 0018 train_loss= 0.59574 val_loss= 0.57486
# Epoch: 0019 train_loss= 0.58253 val_loss= 0.56204
# Epoch: 0020 train_loss= 0.57089 val_loss= 0.54866
# Epoch: 0021 train_loss= 0.56060 val_loss= 0.54019
# Epoch: 0022 train_loss= 0.54882 val_loss= 0.52999
# Epoch: 0023 train_loss= 0.53894 val_loss= 0.52191
# Epoch: 0024 train_loss= 0.52917 val_loss= 0.50997
# Epoch: 0025 train_loss= 0.51888 val_loss= 0.50122
# Epoch: 0118 train_loss= 0.15709 val_loss= 0.15947
# Epoch: 0119 train_loss= 0.15602 val_loss= 0.15712
# Epoch: 0120 train_loss= 0.15382 val_loss= 0.15134
# Epoch: 0121 train_loss= 0.15375 val_loss= 0.15321
# Epoch: 0122 train_loss= 0.15125 val_loss= 0.15112
# Epoch: 0123 train_loss= 0.14936 val_loss= 0.14957
# Epoch: 0124 train_loss= 0.14715 val_loss= 0.14810
# Epoch: 0125 train_loss= 0.14588 val_loss= 0.14741
# Epoch: 0126 train_loss= 0.14300 val_loss= 0.14604
# Epoch: 0127 train_loss= 0.14182 val_loss= 0.14485
# Epoch: 0128 train_loss= 0.14190 val_loss= 0.14248
# Epoch: 0129 train_loss= 0.13977 val_loss= 0.13941
# Epoch: 0130 train_loss= 0.13764 val_loss= 0.13991
# Epoch: 0131 train_loss= 0.13762 val_loss= 0.13740
# Epoch: 0132 train_loss= 0.13545 val_loss= 0.13690
# Epoch: 0133 train_loss= 0.13498 val_loss= 0.13691
# Epoch: 0134 train_loss= 0.13273 val_loss= 0.13512
# Epoch: 0135 train_loss= 0.13135 val_loss= 0.13192
# Epoch: 0136 train_loss= 0.13007 val_loss= 0.13190
# Epoch: 0137 train_loss= 0.12832 val_loss= 0.12969
# Epoch: 0138 train_loss= 0.12803 val_loss= 0.12908
# Epoch: 0139 train_loss= 0.12627 val_loss= 0.12766
# Epoch: 0140 train_loss= 0.12445 val_loss= 0.12558
# Epoch: 0141 train_loss= 0.12356 val_loss= 0.12485
# Epoch: 0142 train_loss= 0.12223 val_loss= 0.12406
# Epoch: 0143 train_loss= 0.12118 val_loss= 0.12172
# Epoch: 0144 train_loss= 0.12029 val_loss= 0.12178
# Epoch: 0145 train_loss= 0.11819 val_loss= 0.11867
# Epoch: 0146 train_loss= 0.11811 val_loss= 0.11895
# Epoch: 0147 train_loss= 0.11647 val_loss= 0.11676
# Epoch: 0148 train_loss= 0.11558 val_loss= 0.11657
# Epoch: 0149 train_loss= 0.11432 val_loss= 0.11671
# Epoch: 0150 train_loss= 0.11184 val_loss= 0.11238
# Epoch: 0151 train_loss= 0.11147 val_loss= 0.11420
# Epoch: 0152 train_loss= 0.11152 val_loss= 0.11251
# Epoch: 0153 train_loss= 0.10975 val_loss= 0.11102
# Epoch: 0154 train_loss= 0.10898 val_loss= 0.11122
# Epoch: 0155 train_loss= 0.10661 val_loss= 0.10906
# Epoch: 0156 train_loss= 0.10620 val_loss= 0.10832
# Epoch: 0157 train_loss= 0.10461 val_loss= 0.10718
# Epoch: 0158 train_loss= 0.10457 val_loss= 0.10749
# Epoch: 0159 train_loss= 0.10331 val_loss= 0.10503
# Epoch: 0160 train_loss= 0.10242 val_loss= 0.10416
# Epoch: 0161 train_loss= 0.10144 val_loss= 0.10329
# Epoch: 0162 train_loss= 0.10054 val_loss= 0.10327
# Epoch: 0163 train_loss= 0.09979 val_loss= 0.10149
# Epoch: 0164 train_loss= 0.09938 val_loss= 0.09919
# Epoch: 0165 train_loss= 0.09841 val_loss= 0.09924
# Epoch: 0166 train_loss= 0.09743 val_loss= 0.09905
# Epoch: 0167 train_loss= 0.09587 val_loss= 0.09885
# Epoch: 0168 train_loss= 0.09560 val_loss= 0.09741
# Epoch: 0169 train_loss= 0.09537 val_loss= 0.09736
# Epoch: 0170 train_loss= 0.09292 val_loss= 0.09524
# Epoch: 0171 train_loss= 0.09265 val_loss= 0.09599
# Epoch: 0172 train_loss= 0.09193 val_loss= 0.09237
# Epoch: 0173 train_loss= 0.09143 val_loss= 0.09219
# Epoch: 0174 train_loss= 0.09058 val_loss= 0.09289
# Epoch: 0175 train_loss= 0.09060 val_loss= 0.09090
# Epoch: 0176 train_loss= 0.08873 val_loss= 0.08965
# Epoch: 0177 train_loss= 0.08849 val_loss= 0.08908
# Epoch: 0178 train_loss= 0.08799 val_loss= 0.08988
# Epoch: 0179 train_loss= 0.08720 val_loss= 0.08926
# Epoch: 0180 train_loss= 0.08650 val_loss= 0.08834
# Epoch: 0181 train_loss= 0.08576 val_loss= 0.08903
# Epoch: 0182 train_loss= 0.08514 val_loss= 0.08669
# Epoch: 0183 train_loss= 0.08391 val_loss= 0.08700
# Epoch: 0184 train_loss= 0.08389 val_loss= 0.08506
# Epoch: 0185 train_loss= 0.08334 val_loss= 0.08538
# Epoch: 0186 train_loss= 0.08230 val_loss= 0.08347
# Epoch: 0187 train_loss= 0.08327 val_loss= 0.08247
# Epoch: 0188 train_loss= 0.08093 val_loss= 0.08266
# Epoch: 0189 train_loss= 0.08099 val_loss= 0.08236
# Epoch: 0190 train_loss= 0.07997 val_loss= 0.08252
# Epoch: 0191 train_loss= 0.07966 val_loss= 0.08016
# Epoch: 0192 train_loss= 0.07867 val_loss= 0.07846
# Epoch: 0193 train_loss= 0.07854 val_loss= 0.07980
# Epoch: 0194 train_loss= 0.07770 val_loss= 0.07871
# Epoch: 0195 train_loss= 0.07622 val_loss= 0.07683
# Epoch: 0196 train_loss= 0.07695 val_loss= 0.07740
# Epoch: 0197 train_loss= 0.07602 val_loss= 0.07657
# Epoch: 0198 train_loss= 0.07582 val_loss= 0.07716
# Epoch: 0199 train_loss= 0.07410 val_loss= 0.07545
# Epoch: 0200 train_loss= 0.07480 val_loss= 0.07563
# Epoch: 0201 train_loss= 0.07450 val_loss= 0.07548
# Epoch: 0202 train_loss= 0.07301 val_loss= 0.07236
# Epoch: 0203 train_loss= 0.07283 val_loss= 0.07358
# Epoch: 0204 train_loss= 0.07225 val_loss= 0.07314
# Epoch: 0205 train_loss= 0.07173 val_loss= 0.07296
# Epoch: 0206 train_loss= 0.07072 val_loss= 0.07202
# Epoch: 0207 train_loss= 0.07074 val_loss= 0.07041
# Epoch: 0208 train_loss= 0.07024 val_loss= 0.07167
# Epoch: 0209 train_loss= 0.07035 val_loss= 0.07222
# Epoch: 0210 train_loss= 0.06920 val_loss= 0.07191
# Epoch: 0211 train_loss= 0.06937 val_loss= 0.06993
# Epoch: 0212 train_loss= 0.06834 val_loss= 0.07042
# Epoch: 0213 train_loss= 0.06806 val_loss= 0.07004
# Epoch: 0214 train_loss= 0.06806 val_loss= 0.06866
# Epoch: 0215 train_loss= 0.06766 val_loss= 0.07001
# Epoch: 0216 train_loss= 0.06684 val_loss= 0.06880
# Epoch: 0217 train_loss= 0.06688 val_loss= 0.06664
# Epoch: 0218 train_loss= 0.06741 val_loss= 0.06804
# Epoch: 0219 train_loss= 0.06551 val_loss= 0.06661
# Epoch: 0220 train_loss= 0.06594 val_loss= 0.06546
# Epoch: 0221 train_loss= 0.06519 val_loss= 0.06571
# Epoch: 0222 train_loss= 0.06500 val_loss= 0.06659
# Epoch: 0223 train_loss= 0.06350 val_loss= 0.06297
# Epoch: 0224 train_loss= 0.06383 val_loss= 0.06503
# Epoch: 0225 train_loss= 0.06359 val_loss= 0.06279
# Epoch: 0226 train_loss= 0.06305 val_loss= 0.06373
# Epoch: 0227 train_loss= 0.06328 val_loss= 0.06227
# Epoch: 0228 train_loss= 0.06292 val_loss= 0.06270
# Epoch: 0229 train_loss= 0.06252 val_loss= 0.06355
# Epoch: 0230 train_loss= 0.06219 val_loss= 0.06119
# Epoch: 0231 train_loss= 0.06230 val_loss= 0.06339
# Epoch: 0232 train_loss= 0.06113 val_loss= 0.06027
# Epoch: 0233 train_loss= 0.06019 val_loss= 0.06186
# Epoch: 0234 train_loss= 0.06029 val_loss= 0.06162
# Epoch: 0235 train_loss= 0.06037 val_loss= 0.06168
# Epoch: 0236 train_loss= 0.05974 val_loss= 0.05990
# Epoch: 0237 train_loss= 0.05972 val_loss= 0.06041
# Epoch: 0238 train_loss= 0.05937 val_loss= 0.05919
# Epoch: 0239 train_loss= 0.05846 val_loss= 0.05879
# Epoch: 0240 train_loss= 0.05863 val_loss= 0.05865
# Epoch: 0241 train_loss= 0.05832 val_loss= 0.05776
# Epoch: 0242 train_loss= 0.05750 val_loss= 0.05840
# Epoch: 0243 train_loss= 0.05752 val_loss= 0.05972
# Epoch: 0244 train_loss= 0.05791 val_loss= 0.05838
# Epoch: 0245 train_loss= 0.05785 val_loss= 0.05777
# Epoch: 0246 train_loss= 0.05745 val_loss= 0.05831
# Epoch: 0247 train_loss= 0.05653 val_loss= 0.05613
# Epoch: 0248 train_loss= 0.05672 val_loss= 0.05605
# Epoch: 0249 train_loss= 0.05611 val_loss= 0.05729
# Epoch: 0250 train_loss= 0.05589 val_loss= 0.05580
# Epoch: 0251 train_loss= 0.05639 val_loss= 0.05581
# Epoch: 0252 train_loss= 0.05509 val_loss= 0.05549
# Epoch: 0253 train_loss= 0.05555 val_loss= 0.05619
# Epoch: 0254 train_loss= 0.05546 val_loss= 0.05540
# Epoch: 0255 train_loss= 0.05481 val_loss= 0.05497
# Epoch: 0256 train_loss= 0.05409 val_loss= 0.05472
# Epoch: 0257 train_loss= 0.05446 val_loss= 0.05431
# Epoch: 0258 train_loss= 0.05336 val_loss= 0.05327
# Epoch: 0259 train_loss= 0.05438 val_loss= 0.05443
# Epoch: 0260 train_loss= 0.05420 val_loss= 0.05456
# Epoch: 0261 train_loss= 0.05364 val_loss= 0.05391
# Epoch: 0262 train_loss= 0.05278 val_loss= 0.05301
# Epoch: 0263 train_loss= 0.05345 val_loss= 0.05366
# Epoch: 0264 train_loss= 0.05206 val_loss= 0.05246
# Epoch: 0265 train_loss= 0.05253 val_loss= 0.05209
# Epoch: 0266 train_loss= 0.05222 val_loss= 0.05189
# Epoch: 0267 train_loss= 0.05223 val_loss= 0.05149
# Epoch: 0268 train_loss= 0.05156 val_loss= 0.05197
# Epoch: 0269 train_loss= 0.05154 val_loss= 0.05079
# Epoch: 0270 train_loss= 0.05050 val_loss= 0.05134
# Epoch: 0271 train_loss= 0.05131 val_loss= 0.05129
# Epoch: 0272 train_loss= 0.05111 val_loss= 0.05045
# Epoch: 0273 train_loss= 0.05106 val_loss= 0.04985
# Epoch: 0274 train_loss= 0.05085 val_loss= 0.04971
# Epoch: 0275 train_loss= 0.05070 val_loss= 0.04938
# Epoch: 0276 train_loss= 0.05034 val_loss= 0.04905
# Epoch: 0277 train_loss= 0.05013 val_loss= 0.05009
# Epoch: 0278 train_loss= 0.04986 val_loss= 0.04902
# Epoch: 0279 train_loss= 0.04990 val_loss= 0.04867
# Epoch: 0280 train_loss= 0.04958 val_loss= 0.04996
# Epoch: 0281 train_loss= 0.04843 val_loss= 0.04920
# Epoch: 0282 train_loss= 0.04939 val_loss= 0.04979
# Epoch: 0283 train_loss= 0.04950 val_loss= 0.04794
# Epoch: 0284 train_loss= 0.04833 val_loss= 0.04810
# Epoch: 0285 train_loss= 0.04846 val_loss= 0.04609
# Epoch: 0286 train_loss= 0.04819 val_loss= 0.04757
# Epoch: 0287 train_loss= 0.04801 val_loss= 0.04860
# Epoch: 0288 train_loss= 0.04783 val_loss= 0.04763
# Epoch: 0289 train_loss= 0.04837 val_loss= 0.04751
# Epoch: 0290 train_loss= 0.04704 val_loss= 0.04768
# Epoch: 0291 train_loss= 0.04777 val_loss= 0.04712
# Epoch: 0292 train_loss= 0.04732 val_loss= 0.04661
# Epoch: 0293 train_loss= 0.04676 val_loss= 0.04701
# Epoch: 0294 train_loss= 0.04705 val_loss= 0.04647
# Epoch: 0295 train_loss= 0.04721 val_loss= 0.04639
# Epoch: 0296 train_loss= 0.04661 val_loss= 0.04709
# Epoch: 0297 train_loss= 0.04607 val_loss= 0.04581
# Epoch: 0298 train_loss= 0.04624 val_loss= 0.04589
# Epoch: 0299 train_loss= 0.04604 val_loss= 0.04554
# Epoch: 0300 train_loss= 0.04643 val_loss= 0.04600
# Epoch: 0301 train_loss= 0.04542 val_loss= 0.04550
# Epoch: 0302 train_loss= 0.04510 val_loss= 0.04527
# Epoch: 0303 train_loss= 0.04513 val_loss= 0.04483
# Epoch: 0304 train_loss= 0.04498 val_loss= 0.04476
# Epoch: 0305 train_loss= 0.04537 val_loss= 0.04443
# Epoch: 0306 train_loss= 0.04529 val_loss= 0.04514
# Epoch: 0307 train_loss= 0.04473 val_loss= 0.04335
# Epoch: 0308 train_loss= 0.04473 val_loss= 0.04424
# Epoch: 0309 train_loss= 0.04510 val_loss= 0.04508
# Epoch: 0310 train_loss= 0.04457 val_loss= 0.04376
# Epoch: 0311 train_loss= 0.04454 val_loss= 0.04390
# Epoch: 0312 train_loss= 0.04478 val_loss= 0.04318
# Epoch: 0313 train_loss= 0.04387 val_loss= 0.04330
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-9c797013058b> in <module>()
#       7     train_loss = my_model.forward(train_features_tensor)
#       8     my_model.backward()
# ----> 9     val_loss = my_model.forward(val_features_tensor)
#      10     my_model.optimizer.zero_grad()
#      11     #val_loss = 0
#
# <ipython-input-7-ba9ad5efc988> in forward(self, x)
#      50         self.layer_2 = torch.nn.functional.tanh(self.W1(self.drouput2(self.layer_1)))
#      51         self.layer_3 = torch.nn.functional.tanh(self.W2(self.layer_2+self.normal_dist.sample((x.shape[0],))))
# ---> 52         self.layer_4 = self.W3(self.layer_3)
#      53
#      54
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#      90     @weak_script_method
#      91     def forward(self, input):
# ---> 92         return F.linear(input, self.weight, self.bias)
#      93
#      94     def extra_repr(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1404     if input.dim() == 2 and bias is not None:
#    1405         # fused op is marginally faster
# -> 1406         ret = torch.addmm(bias, input, weight.t())
#    1407     else:
#    1408         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
my_model.forward(train_features_tensor)
my_model.drouput1.eval()
my_model.drouput2.eval()

#my_model.drouput1.train()
#my_model.drouput2.train()

print(my_model.forward(train_features_tensor))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# 0.04305138811469078

# %%
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
np.savetxt("/content/drive/My Drive/Data Fusion/results/emb_v14_n_0_1.txt",emb,delimiter='\t')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
emb = np.loadtxt("/content/drive/My Drive/Data Fusion/results/emb_v11.txt",delimiter='\t')
# Out:
# [1, 1, 1, 1, 1]

# %%
####PCA on embedding
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
circle_areas = (truelabel[:,1].astype(float)/8)
X_embedded = PCA(n_components=2).fit_transform(emb)
plt.scatter(x=X_embedded[:,0], y=X_embedded[:,1], s=circle_areas, c= 1*np.ones(215), alpha=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
### TSNE on embedding
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
circle_areas = (truelabel[:,1].astype(float)/8)
X_embedded = TSNE(n_components=2).fit_transform(emb)
plt.scatter(x=X_embedded[:,0], y=X_embedded[:,1], s=circle_areas, c= 1*np.ones(215), alpha=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")

# %%
from sklearn.cluster import KMeans
X = emb
n_clusters=3
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X)

for i in range(n_clusters):
    indx = np.argwhere(kmeans.labels_==i).reshape(-1)
    print(truelabel[indx][:,1].mean())
# Out:
# 626.8765432098766
# 536.3030303030303
# 573.3168316831683

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
emb = np.loadtxt("/content/drive/My Drive/Data Fusion/results/emb_v11.txt",delimiter='\t')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#print(list(my_model.W0.parameters()))
print(torch.norm(list(my_model.W0.parameters())[0],1))
#l1_regularization += torch.norm(param, 1)
#torch.norm()
# Out:
# tensor(220043., grad_fn=<NormBackward0>)
