# %%
## This Cell is related to date preprocessing and is completely copied from original kipf's github code!

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.sparse as sp
import torch,torch.nn,torch.sparse,torch.nn.functional,torch.distributions
from sklearn.metrics import roc_auc_score,average_precision_score
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
np.set_printoptions(threshold=np.inf)


from google.colab import drive
drive.mount('/content/drive')


W_gene      =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/gene.txt", delim_whitespace=True).to_numpy()
W_methy     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/methy.txt", delim_whitespace=True).to_numpy()
W_mirna     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/mirna.txt", delim_whitespace=True).to_numpy()

gene      =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Gene_Expression.txt", delim_whitespace=True).to_numpy().transpose()
methy     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Methy_Expression.txt", delim_whitespace=True).to_numpy().transpose()
mirna     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Mirna_Expression.txt", delim_whitespace=True).to_numpy().transpose()
truelabel =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Survival.txt", delim_whitespace=True).to_numpy()



print(gene.shape)
print(methy.shape)
print(mirna.shape)

def get_nomralized_laplacian(a):
    b = np.diag(np.power(1.0 / a.sum(axis=1), 0.5))
    return (b @ a @ b)





features = np.c_[mirna,methy,gene]

patient_no = features.shape[0]

idx = np.arange(patient_no)
np.random.shuffle(idx)
train_idx = idx[0:int(patient_no * 0.75)]
val_idx =   idx[int(patient_no * 0.75):]

train_features = features[train_idx]
train_features = features
val_features   = features[val_idx]
print(train_features.shape)
print(val_features.shape)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# (215, 12042)
# (215, 1305)
# (215, 534)
# (215, 13881)
# (54, 13881)

# %%
#Model definition Cell

num_features = features.shape[1]

train_features_tensor  = torch.Tensor(train_features)
val_features_tensor    = torch.Tensor(val_features)





class Model(torch.nn.Module):

    def __init__(self,**kwargs):
        super(Model, self).__init__(**kwargs)
        
        
        
            

        self.W0 = torch.nn.Linear(num_features,6000)
        self.W1 = torch.nn.Linear(6000,3000)
        self.W2 = torch.nn.Linear(3000,6000)
        self.W3 = torch.nn.Linear(6000,num_features)

        self.drouput1 = torch.nn.Dropout(p=0.5)
        self.drouput2 = torch.nn.Dropout(p=0.5)
        
        param_list = []
        param_list += list(self.W0.parameters())
        param_list += list(self.W1.parameters())
        param_list += list(self.W2.parameters())
        param_list += list(self.W3.parameters())
        
        

        self.optimizer = torch.optim.Adam(param_list,lr=0.0001)
        self.recon = None
        
        
        
        
    


        
    def forward(self,x) : 
        self.layer_1 = torch.nn.functional.tanh(self.W0(self.drouput1(x)))
        self.layer_2 = torch.nn.functional.tanh(self.W1(self.drouput2(self.layer_1)))
        self.layer_3 = torch.nn.functional.tanh(self.W2(self.layer_2))
        self.layer_4 = self.W3(self.layer_3)
        


        self.x_prim = self.layer_4
        self.embedding = self.layer_2
        
        self.recon_loss = ((self.x_prim-x)**2).mean(0)
        self.recon_loss = self.recon_loss[0:534].mean()+self.recon_loss[534:534+1305].mean()+self.recon_loss[534+1305:534+1305+12042].mean()
        self.recon_loss = self.recon_loss/3
       
        self.l1_regularization =  (torch.norm(list(self.W0.parameters())[0],1))+(torch.norm(list(self.W1.parameters())[0],1))

        print(self.l1_regularization)
        self.loss = self.recon_loss + self.l1_regularization/1000000
        
        
        
        
        
        return self.loss.item()
        
    def backward(self) :
        
        self.optimizer.zero_grad()
        self.loss.backward()
        self.optimizer.step()

        
        
    def get_cosine_sim_emb(self):
        
        emb = self.embedding.detach().numpy()

        norms =  (emb*emb).sum(1).reshape(-1,1)**0.5
        normalized_emb = emb/norms

        emb_matrix = np.abs( normalized_emb@normalized_emb.transpose())
        return emb_matrix
        

    def get_euclidian(self):
        emb = self.embedding.detach().numpy()
        
        emb_matrix = np.zeros((emb.shape[0],emb.shape[0]))
        
        for i in range(emb.shape[0]):
            for j in range(emb.shape[0]):
                emb_matrix[i,j] = ((emb[i]-emb[j])**2).sum()
                
        return emb_matrix

# %%
#Training Cell 

my_model = Model()


for epoch_counter in range(20000):
    
    train_loss = my_model.forward(train_features_tensor)
    my_model.backward()
    val_loss = my_model.forward(val_features_tensor)
    my_model.optimizer.zero_grad()
    #val_loss = 0

    if epoch_counter % 1 ==0:
        print("Epoch:", '%04d' % (epoch_counter + 1), "train_loss=", "{:.5f}".format(train_loss), "val_loss=", "{:.5f}".format(val_loss))


print('\n',"#########################################################",'\n')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(404092.1250, grad_fn=<AddBackward0>)
# tensor(403380.4375, grad_fn=<AddBackward0>)
# Epoch: 0001 train_loss= 1.41534 val_loss= 1.43780
# tensor(403380.4375, grad_fn=<AddBackward0>)
# tensor(402638.5625, grad_fn=<AddBackward0>)
# Epoch: 0002 train_loss= 1.37580 val_loss= 1.39083
# tensor(402638.5625, grad_fn=<AddBackward0>)
# tensor(401889.4375, grad_fn=<AddBackward0>)
# Epoch: 0003 train_loss= 1.33141 val_loss= 1.34205
# tensor(401889.4375, grad_fn=<AddBackward0>)
# tensor(401148.0312, grad_fn=<AddBackward0>)
# Epoch: 0004 train_loss= 1.28261 val_loss= 1.29749
# tensor(401148.0312, grad_fn=<AddBackward0>)
# tensor(400404.4375, grad_fn=<AddBackward0>)
# Epoch: 0005 train_loss= 1.23828 val_loss= 1.25640
# tensor(400404.4375, grad_fn=<AddBackward0>)
# tensor(399652.2188, grad_fn=<AddBackward0>)
# Epoch: 0006 train_loss= 1.19795 val_loss= 1.21914
# tensor(399652.2188, grad_fn=<AddBackward0>)
# tensor(398893.7500, grad_fn=<AddBackward0>)
# Epoch: 0007 train_loss= 1.16201 val_loss= 1.18468
# tensor(398893.7500, grad_fn=<AddBackward0>)
# tensor(398185.5625, grad_fn=<AddBackward0>)
# Epoch: 0008 train_loss= 1.13051 val_loss= 1.15545
# tensor(398185.5625, grad_fn=<AddBackward0>)
# tensor(397585.8750, grad_fn=<AddBackward0>)
# Epoch: 0009 train_loss= 1.10259 val_loss= 1.12514
# tensor(397585.8750, grad_fn=<AddBackward0>)
# tensor(397047.7188, grad_fn=<AddBackward0>)
# Epoch: 0010 train_loss= 1.07498 val_loss= 1.09997
# tensor(397047.7188, grad_fn=<AddBackward0>)
# tensor(396547.7500, grad_fn=<AddBackward0>)
# Epoch: 0011 train_loss= 1.05348 val_loss= 1.08100
# tensor(396547.7500, grad_fn=<AddBackward0>)
# tensor(396077.9375, grad_fn=<AddBackward0>)
# Epoch: 0012 train_loss= 1.03427 val_loss= 1.06260
# tensor(396077.9375, grad_fn=<AddBackward0>)
# tensor(395628.5625, grad_fn=<AddBackward0>)
# Epoch: 0013 train_loss= 1.01585 val_loss= 1.04207
# tensor(395628.5625, grad_fn=<AddBackward0>)
# tensor(395195., grad_fn=<AddBackward0>)
# Epoch: 0014 train_loss= 0.99690 val_loss= 1.02228
# tensor(395195., grad_fn=<AddBackward0>)
# tensor(394768.0312, grad_fn=<AddBackward0>)
# Epoch: 0015 train_loss= 0.98016 val_loss= 1.00580
# tensor(394768.0312, grad_fn=<AddBackward0>)
# tensor(394348.5938, grad_fn=<AddBackward0>)
# Epoch: 0016 train_loss= 0.96426 val_loss= 0.99293
# tensor(394348.5938, grad_fn=<AddBackward0>)
# tensor(393939.6250, grad_fn=<AddBackward0>)
# Epoch: 0017 train_loss= 0.95014 val_loss= 0.97810
# tensor(393939.6250, grad_fn=<AddBackward0>)
# tensor(393531., grad_fn=<AddBackward0>)
# Epoch: 0018 train_loss= 0.93716 val_loss= 0.96706
# tensor(393531., grad_fn=<AddBackward0>)
# tensor(393128.0312, grad_fn=<AddBackward0>)
# Epoch: 0019 train_loss= 0.92462 val_loss= 0.95443
# tensor(393128.0312, grad_fn=<AddBackward0>)
# tensor(392734.3125, grad_fn=<AddBackward0>)
# Epoch: 0020 train_loss= 0.91255 val_loss= 0.94245
# tensor(392734.3125, grad_fn=<AddBackward0>)
# tensor(392337.4062, grad_fn=<AddBackward0>)
# Epoch: 0021 train_loss= 0.90120 val_loss= 0.92769
# tensor(392337.4062, grad_fn=<AddBackward0>)
# tensor(391952.6875, grad_fn=<AddBackward0>)
# Epoch: 0022 train_loss= 0.88964 val_loss= 0.91788
# tensor(391952.6875, grad_fn=<AddBackward0>)
# tensor(391574.4062, grad_fn=<AddBackward0>)
# Epoch: 0023 train_loss= 0.87836 val_loss= 0.90288
# tensor(391574.4062, grad_fn=<AddBackward0>)
# tensor(391190.7500, grad_fn=<AddBackward0>)
# Epoch: 0024 train_loss= 0.86772 val_loss= 0.89442
# tensor(391190.7500, grad_fn=<AddBackward0>)
# tensor(390808.9375, grad_fn=<AddBackward0>)
# Epoch: 0025 train_loss= 0.85729 val_loss= 0.87917
# tensor(390808.9375, grad_fn=<AddBackward0>)
# tensor(390438.8438, grad_fn=<AddBackward0>)
# Epoch: 0026 train_loss= 0.84716 val_loss= 0.86913
# tensor(390438.8438, grad_fn=<AddBackward0>)
# tensor(390064.4375, grad_fn=<AddBackward0>)
# Epoch: 0027 train_loss= 0.83808 val_loss= 0.85954
# tensor(390064.4375, grad_fn=<AddBackward0>)
# tensor(389692.1562, grad_fn=<AddBackward0>)
# Epoch: 0028 train_loss= 0.82843 val_loss= 0.84766
# tensor(389692.1562, grad_fn=<AddBackward0>)
# tensor(389322.6875, grad_fn=<AddBackward0>)
# Epoch: 0029 train_loss= 0.81949 val_loss= 0.83803
# tensor(389322.6875, grad_fn=<AddBackward0>)
# tensor(388952.3125, grad_fn=<AddBackward0>)
# Epoch: 0030 train_loss= 0.81093 val_loss= 0.82867
# tensor(388952.3125, grad_fn=<AddBackward0>)
# tensor(388592., grad_fn=<AddBackward0>)
# Epoch: 0031 train_loss= 0.80362 val_loss= 0.82081
# tensor(388592., grad_fn=<AddBackward0>)
# tensor(388230.3750, grad_fn=<AddBackward0>)
# Epoch: 0032 train_loss= 0.79474 val_loss= 0.81180
# tensor(388230.3750, grad_fn=<AddBackward0>)
# tensor(387870.5625, grad_fn=<AddBackward0>)
# Epoch: 0033 train_loss= 0.78640 val_loss= 0.80231
# tensor(387870.5625, grad_fn=<AddBackward0>)
# tensor(387511.0625, grad_fn=<AddBackward0>)
# Epoch: 0034 train_loss= 0.78025 val_loss= 0.79603
# tensor(387511.0625, grad_fn=<AddBackward0>)
# tensor(387153.4375, grad_fn=<AddBackward0>)
# Epoch: 0035 train_loss= 0.77193 val_loss= 0.78632
# tensor(387153.4375, grad_fn=<AddBackward0>)
# tensor(386792.8438, grad_fn=<AddBackward0>)
# Epoch: 0036 train_loss= 0.76467 val_loss= 0.77721
# tensor(386792.8438, grad_fn=<AddBackward0>)
# tensor(386435.0625, grad_fn=<AddBackward0>)
# Epoch: 0037 train_loss= 0.75757 val_loss= 0.77145
# tensor(386435.0625, grad_fn=<AddBackward0>)
# tensor(386074.6875, grad_fn=<AddBackward0>)
# Epoch: 0038 train_loss= 0.75196 val_loss= 0.76290
# tensor(386074.6875, grad_fn=<AddBackward0>)
# tensor(385726.4062, grad_fn=<AddBackward0>)
# Epoch: 0039 train_loss= 0.74463 val_loss= 0.75544
# tensor(385726.4062, grad_fn=<AddBackward0>)
# tensor(385370.3750, grad_fn=<AddBackward0>)
# Epoch: 0040 train_loss= 0.73750 val_loss= 0.75049
# tensor(385370.3750, grad_fn=<AddBackward0>)
# tensor(385021.7500, grad_fn=<AddBackward0>)
# Epoch: 0041 train_loss= 0.73262 val_loss= 0.74117
# tensor(385021.7500, grad_fn=<AddBackward0>)
# tensor(384671.1875, grad_fn=<AddBackward0>)
# Epoch: 0042 train_loss= 0.72508 val_loss= 0.73553
# tensor(384671.1875, grad_fn=<AddBackward0>)
# tensor(384320.1875, grad_fn=<AddBackward0>)
# Epoch: 0043 train_loss= 0.71939 val_loss= 0.72820
# tensor(384320.1875, grad_fn=<AddBackward0>)
# tensor(383978.5000, grad_fn=<AddBackward0>)
# Epoch: 0044 train_loss= 0.71450 val_loss= 0.72218
# tensor(383978.5000, grad_fn=<AddBackward0>)
# tensor(383632.6250, grad_fn=<AddBackward0>)
# Epoch: 0045 train_loss= 0.70890 val_loss= 0.71518
# tensor(383632.6250, grad_fn=<AddBackward0>)
# tensor(383286.6250, grad_fn=<AddBackward0>)
# Epoch: 0046 train_loss= 0.70322 val_loss= 0.70894
# tensor(383286.6250, grad_fn=<AddBackward0>)
# tensor(382949.9688, grad_fn=<AddBackward0>)
# Epoch: 0047 train_loss= 0.69723 val_loss= 0.70341
# tensor(382949.9688, grad_fn=<AddBackward0>)
# tensor(382612.3438, grad_fn=<AddBackward0>)
# Epoch: 0048 train_loss= 0.69177 val_loss= 0.69396
# tensor(382612.3438, grad_fn=<AddBackward0>)
# tensor(382282.5000, grad_fn=<AddBackward0>)
# Epoch: 0049 train_loss= 0.68581 val_loss= 0.69055
# tensor(382282.5000, grad_fn=<AddBackward0>)
# tensor(381949.8438, grad_fn=<AddBackward0>)
# Epoch: 0050 train_loss= 0.68111 val_loss= 0.68399
# tensor(381949.8438, grad_fn=<AddBackward0>)
# tensor(381616.6875, grad_fn=<AddBackward0>)
# Epoch: 0051 train_loss= 0.67517 val_loss= 0.67829
# tensor(381616.6875, grad_fn=<AddBackward0>)
# tensor(381295., grad_fn=<AddBackward0>)
# Epoch: 0052 train_loss= 0.67189 val_loss= 0.67319
# tensor(381295., grad_fn=<AddBackward0>)
# tensor(380968.2812, grad_fn=<AddBackward0>)
# Epoch: 0053 train_loss= 0.66517 val_loss= 0.66863
# tensor(380968.2812, grad_fn=<AddBackward0>)
# tensor(380647.8750, grad_fn=<AddBackward0>)
# Epoch: 0054 train_loss= 0.66031 val_loss= 0.66268
# tensor(380647.8750, grad_fn=<AddBackward0>)
# tensor(380328.7500, grad_fn=<AddBackward0>)
# Epoch: 0055 train_loss= 0.65604 val_loss= 0.65804
# tensor(380328.7500, grad_fn=<AddBackward0>)
# tensor(380011.3125, grad_fn=<AddBackward0>)
# Epoch: 0056 train_loss= 0.65062 val_loss= 0.65219
# tensor(380011.3125, grad_fn=<AddBackward0>)
# tensor(379696.9062, grad_fn=<AddBackward0>)
# Epoch: 0057 train_loss= 0.64718 val_loss= 0.64889
# tensor(379696.9062, grad_fn=<AddBackward0>)
# tensor(379380.8125, grad_fn=<AddBackward0>)
# Epoch: 0058 train_loss= 0.64146 val_loss= 0.64439
# tensor(379380.8125, grad_fn=<AddBackward0>)
# tensor(379064.7500, grad_fn=<AddBackward0>)
# Epoch: 0059 train_loss= 0.63889 val_loss= 0.63910
# tensor(379064.7500, grad_fn=<AddBackward0>)
# tensor(378753.6562, grad_fn=<AddBackward0>)
# Epoch: 0060 train_loss= 0.63317 val_loss= 0.63303
# tensor(378753.6562, grad_fn=<AddBackward0>)
# tensor(378447.4375, grad_fn=<AddBackward0>)
# Epoch: 0061 train_loss= 0.62925 val_loss= 0.63043
# tensor(378447.4375, grad_fn=<AddBackward0>)
# tensor(378144.4688, grad_fn=<AddBackward0>)
# Epoch: 0062 train_loss= 0.62433 val_loss= 0.62603
# tensor(378144.4688, grad_fn=<AddBackward0>)
# tensor(377839.4062, grad_fn=<AddBackward0>)
# Epoch: 0063 train_loss= 0.62039 val_loss= 0.62167
# tensor(377839.4062, grad_fn=<AddBackward0>)
# tensor(377540.9375, grad_fn=<AddBackward0>)
# Epoch: 0064 train_loss= 0.61630 val_loss= 0.61601
# tensor(377540.9375, grad_fn=<AddBackward0>)
# tensor(377239.8125, grad_fn=<AddBackward0>)
# Epoch: 0065 train_loss= 0.61201 val_loss= 0.61206
# tensor(377239.8125, grad_fn=<AddBackward0>)
# tensor(376941.1875, grad_fn=<AddBackward0>)
# Epoch: 0066 train_loss= 0.60723 val_loss= 0.60757
# tensor(376941.1875, grad_fn=<AddBackward0>)
# tensor(376642.9062, grad_fn=<AddBackward0>)
# Epoch: 0067 train_loss= 0.60447 val_loss= 0.60336
# tensor(376642.9062, grad_fn=<AddBackward0>)
# tensor(376347.7812, grad_fn=<AddBackward0>)
# Epoch: 0068 train_loss= 0.59973 val_loss= 0.60042
# tensor(376347.7812, grad_fn=<AddBackward0>)
# tensor(376055.4688, grad_fn=<AddBackward0>)
# Epoch: 0069 train_loss= 0.59578 val_loss= 0.59611
# tensor(376055.4688, grad_fn=<AddBackward0>)
# tensor(375759.5000, grad_fn=<AddBackward0>)
# Epoch: 0070 train_loss= 0.59178 val_loss= 0.59136
# tensor(375759.5000, grad_fn=<AddBackward0>)
# tensor(375463.5625, grad_fn=<AddBackward0>)
# Epoch: 0071 train_loss= 0.58818 val_loss= 0.58739
# tensor(375463.5625, grad_fn=<AddBackward0>)
# tensor(375175.4375, grad_fn=<AddBackward0>)
# Epoch: 0072 train_loss= 0.58487 val_loss= 0.58243
# tensor(375175.4375, grad_fn=<AddBackward0>)
# tensor(374887.1250, grad_fn=<AddBackward0>)
# Epoch: 0073 train_loss= 0.58137 val_loss= 0.57983
# tensor(374887.1250, grad_fn=<AddBackward0>)
# tensor(374601.2500, grad_fn=<AddBackward0>)
# Epoch: 0074 train_loss= 0.57756 val_loss= 0.57496
# tensor(374601.2500, grad_fn=<AddBackward0>)
# tensor(374315.8125, grad_fn=<AddBackward0>)
# Epoch: 0075 train_loss= 0.57392 val_loss= 0.57151
# tensor(374315.8125, grad_fn=<AddBackward0>)
# tensor(374035.6562, grad_fn=<AddBackward0>)
# Epoch: 0076 train_loss= 0.57100 val_loss= 0.56888
# tensor(374035.6562, grad_fn=<AddBackward0>)
# tensor(373757.0938, grad_fn=<AddBackward0>)
# Epoch: 0077 train_loss= 0.56652 val_loss= 0.56484
# tensor(373757.0938, grad_fn=<AddBackward0>)
# tensor(373472.6250, grad_fn=<AddBackward0>)
# Epoch: 0078 train_loss= 0.56374 val_loss= 0.56168
# tensor(373472.6250, grad_fn=<AddBackward0>)
# tensor(373188.8750, grad_fn=<AddBackward0>)
# Epoch: 0079 train_loss= 0.55938 val_loss= 0.55758
# tensor(373188.8750, grad_fn=<AddBackward0>)
# tensor(372909.1562, grad_fn=<AddBackward0>)
# Epoch: 0080 train_loss= 0.55599 val_loss= 0.55388
# tensor(372909.1562, grad_fn=<AddBackward0>)
# tensor(372633.5625, grad_fn=<AddBackward0>)
# Epoch: 0081 train_loss= 0.55320 val_loss= 0.55153
# tensor(372633.5625, grad_fn=<AddBackward0>)
# tensor(372357.5000, grad_fn=<AddBackward0>)
# Epoch: 0082 train_loss= 0.54907 val_loss= 0.54692
# tensor(372357.5000, grad_fn=<AddBackward0>)
# tensor(372078.3750, grad_fn=<AddBackward0>)
# Epoch: 0083 train_loss= 0.54710 val_loss= 0.54415
# tensor(372078.3750, grad_fn=<AddBackward0>)
# tensor(371804.4375, grad_fn=<AddBackward0>)
# Epoch: 0084 train_loss= 0.54333 val_loss= 0.54107
# tensor(371804.4375, grad_fn=<AddBackward0>)
# tensor(371539.5312, grad_fn=<AddBackward0>)
# Epoch: 0085 train_loss= 0.53941 val_loss= 0.53686
# tensor(371539.5312, grad_fn=<AddBackward0>)
# tensor(371269.1250, grad_fn=<AddBackward0>)
# Epoch: 0086 train_loss= 0.53682 val_loss= 0.53460
# tensor(371269.1250, grad_fn=<AddBackward0>)
# tensor(370996.3125, grad_fn=<AddBackward0>)
# Epoch: 0087 train_loss= 0.53405 val_loss= 0.53042
# tensor(370996.3125, grad_fn=<AddBackward0>)
# tensor(370727.5312, grad_fn=<AddBackward0>)
# Epoch: 0088 train_loss= 0.53093 val_loss= 0.52716
# tensor(370727.5312, grad_fn=<AddBackward0>)
# tensor(370454.3438, grad_fn=<AddBackward0>)
# Epoch: 0089 train_loss= 0.52768 val_loss= 0.52403
# tensor(370454.3438, grad_fn=<AddBackward0>)
# tensor(370186., grad_fn=<AddBackward0>)
# Epoch: 0090 train_loss= 0.52449 val_loss= 0.52035
# tensor(370186., grad_fn=<AddBackward0>)
# tensor(369921.0312, grad_fn=<AddBackward0>)
# Epoch: 0091 train_loss= 0.52259 val_loss= 0.51786
# tensor(369921.0312, grad_fn=<AddBackward0>)
# tensor(369659.0312, grad_fn=<AddBackward0>)
# Epoch: 0092 train_loss= 0.51897 val_loss= 0.51574
# tensor(369659.0312, grad_fn=<AddBackward0>)
# tensor(369391.8750, grad_fn=<AddBackward0>)
# Epoch: 0093 train_loss= 0.51656 val_loss= 0.51280
# tensor(369391.8750, grad_fn=<AddBackward0>)
# tensor(369131.6250, grad_fn=<AddBackward0>)
# Epoch: 0094 train_loss= 0.51367 val_loss= 0.50959
# tensor(369131.6250, grad_fn=<AddBackward0>)
# tensor(368872.3125, grad_fn=<AddBackward0>)
# Epoch: 0095 train_loss= 0.51052 val_loss= 0.50636
# tensor(368872.3125, grad_fn=<AddBackward0>)
# tensor(368609.2500, grad_fn=<AddBackward0>)
# Epoch: 0096 train_loss= 0.50823 val_loss= 0.50431
# tensor(368609.2500, grad_fn=<AddBackward0>)
# tensor(368348.3750, grad_fn=<AddBackward0>)
# Epoch: 0097 train_loss= 0.50541 val_loss= 0.50226
# tensor(368348.3750, grad_fn=<AddBackward0>)
# tensor(368088.4062, grad_fn=<AddBackward0>)
# Epoch: 0098 train_loss= 0.50260 val_loss= 0.49952
# tensor(368088.4062, grad_fn=<AddBackward0>)
# tensor(367826.8750, grad_fn=<AddBackward0>)
# Epoch: 0099 train_loss= 0.50084 val_loss= 0.49705
# tensor(367826.8750, grad_fn=<AddBackward0>)
# tensor(367571.8125, grad_fn=<AddBackward0>)
# Epoch: 0100 train_loss= 0.49676 val_loss= 0.49503
# tensor(367571.8125, grad_fn=<AddBackward0>)
# tensor(367308.7812, grad_fn=<AddBackward0>)
# Epoch: 0101 train_loss= 0.49478 val_loss= 0.49093
# tensor(367308.7812, grad_fn=<AddBackward0>)
# tensor(367055.0312, grad_fn=<AddBackward0>)
# Epoch: 0102 train_loss= 0.49236 val_loss= 0.48817
# tensor(367055.0312, grad_fn=<AddBackward0>)
# tensor(366797.0625, grad_fn=<AddBackward0>)
# Epoch: 0103 train_loss= 0.48976 val_loss= 0.48610
# tensor(366797.0625, grad_fn=<AddBackward0>)
# tensor(366546.2500, grad_fn=<AddBackward0>)
# Epoch: 0104 train_loss= 0.48710 val_loss= 0.48243
# tensor(366546.2500, grad_fn=<AddBackward0>)
# tensor(366302.0938, grad_fn=<AddBackward0>)
# Epoch: 0105 train_loss= 0.48540 val_loss= 0.48065
# tensor(366302.0938, grad_fn=<AddBackward0>)
# tensor(365717., grad_fn=<AddBackward0>)
# Epoch: 0106 train_loss= 0.48264 val_loss= 0.47723
# tensor(365717., grad_fn=<AddBackward0>)
# tensor(364762.1250, grad_fn=<AddBackward0>)
# Epoch: 0107 train_loss= 0.48008 val_loss= 0.47463
# tensor(364762.1250, grad_fn=<AddBackward0>)
# tensor(363813.1875, grad_fn=<AddBackward0>)
# Epoch: 0108 train_loss= 0.47752 val_loss= 0.47196
# tensor(363813.1875, grad_fn=<AddBackward0>)
# tensor(362863.8438, grad_fn=<AddBackward0>)
# Epoch: 0109 train_loss= 0.47433 val_loss= 0.47019
# tensor(362863.8438, grad_fn=<AddBackward0>)
# tensor(361913.6875, grad_fn=<AddBackward0>)
# Epoch: 0110 train_loss= 0.47154 val_loss= 0.46511
# tensor(361913.6875, grad_fn=<AddBackward0>)
# tensor(360958.8125, grad_fn=<AddBackward0>)
# Epoch: 0111 train_loss= 0.46731 val_loss= 0.46344
# tensor(360958.8125, grad_fn=<AddBackward0>)
# tensor(360010.0625, grad_fn=<AddBackward0>)
# Epoch: 0112 train_loss= 0.46494 val_loss= 0.46070
# tensor(360010.0625, grad_fn=<AddBackward0>)
# tensor(359055., grad_fn=<AddBackward0>)
# Epoch: 0113 train_loss= 0.46276 val_loss= 0.45710
# tensor(359055., grad_fn=<AddBackward0>)
# tensor(358102.8750, grad_fn=<AddBackward0>)
# Epoch: 0114 train_loss= 0.45966 val_loss= 0.45510
# tensor(358102.8750, grad_fn=<AddBackward0>)
# tensor(357151.1562, grad_fn=<AddBackward0>)
# Epoch: 0115 train_loss= 0.45609 val_loss= 0.45075
# tensor(357151.1562, grad_fn=<AddBackward0>)
# tensor(356199.2812, grad_fn=<AddBackward0>)
# Epoch: 0116 train_loss= 0.45356 val_loss= 0.44850
# tensor(356199.2812, grad_fn=<AddBackward0>)
# tensor(355239.8125, grad_fn=<AddBackward0>)
# Epoch: 0117 train_loss= 0.45166 val_loss= 0.44610
# tensor(355239.8125, grad_fn=<AddBackward0>)
# tensor(354288.4375, grad_fn=<AddBackward0>)
# Epoch: 0118 train_loss= 0.44794 val_loss= 0.44295
# tensor(354288.4375, grad_fn=<AddBackward0>)
# tensor(353333.0312, grad_fn=<AddBackward0>)
# Epoch: 0119 train_loss= 0.44518 val_loss= 0.44064
# tensor(353333.0312, grad_fn=<AddBackward0>)
# tensor(352377.0625, grad_fn=<AddBackward0>)
# Epoch: 0120 train_loss= 0.44272 val_loss= 0.43781
# tensor(352377.0625, grad_fn=<AddBackward0>)
# tensor(351418.3125, grad_fn=<AddBackward0>)
# Epoch: 0121 train_loss= 0.44055 val_loss= 0.43556
# tensor(351418.3125, grad_fn=<AddBackward0>)
# tensor(350461.1250, grad_fn=<AddBackward0>)
# Epoch: 0122 train_loss= 0.43745 val_loss= 0.43285
# tensor(350461.1250, grad_fn=<AddBackward0>)
# tensor(349502.1875, grad_fn=<AddBackward0>)
# Epoch: 0123 train_loss= 0.43516 val_loss= 0.43015
# tensor(349502.1875, grad_fn=<AddBackward0>)
# tensor(348542.2500, grad_fn=<AddBackward0>)
# Epoch: 0124 train_loss= 0.43252 val_loss= 0.42774
# tensor(348542.2500, grad_fn=<AddBackward0>)
# tensor(347581.0625, grad_fn=<AddBackward0>)
# Epoch: 0125 train_loss= 0.43008 val_loss= 0.42395
# tensor(347581.0625, grad_fn=<AddBackward0>)
# tensor(346622.2188, grad_fn=<AddBackward0>)
# Epoch: 0126 train_loss= 0.42756 val_loss= 0.42285
# tensor(346622.2188, grad_fn=<AddBackward0>)
# tensor(345656.0312, grad_fn=<AddBackward0>)
# Epoch: 0127 train_loss= 0.42474 val_loss= 0.41989
# tensor(345656.0312, grad_fn=<AddBackward0>)
# tensor(344692.9375, grad_fn=<AddBackward0>)
# Epoch: 0128 train_loss= 0.42274 val_loss= 0.41784
# tensor(344692.9375, grad_fn=<AddBackward0>)
# tensor(343731.9375, grad_fn=<AddBackward0>)
# Epoch: 0129 train_loss= 0.42018 val_loss= 0.41543
# tensor(343731.9375, grad_fn=<AddBackward0>)
# tensor(342766.6562, grad_fn=<AddBackward0>)
# Epoch: 0130 train_loss= 0.41765 val_loss= 0.41328
# tensor(342766.6562, grad_fn=<AddBackward0>)
# tensor(341802.2812, grad_fn=<AddBackward0>)
# Epoch: 0131 train_loss= 0.41555 val_loss= 0.41105
# tensor(341802.2812, grad_fn=<AddBackward0>)
# tensor(340835., grad_fn=<AddBackward0>)
# Epoch: 0132 train_loss= 0.41290 val_loss= 0.40899
# tensor(340835., grad_fn=<AddBackward0>)
# tensor(339867.3125, grad_fn=<AddBackward0>)
# Epoch: 0133 train_loss= 0.41034 val_loss= 0.40622
# tensor(339867.3125, grad_fn=<AddBackward0>)
# tensor(338906.2812, grad_fn=<AddBackward0>)
# Epoch: 0134 train_loss= 0.40771 val_loss= 0.40405
# tensor(338906.2812, grad_fn=<AddBackward0>)
# tensor(337940.5000, grad_fn=<AddBackward0>)
# Epoch: 0135 train_loss= 0.40606 val_loss= 0.40138
# tensor(337940.5000, grad_fn=<AddBackward0>)
# tensor(336977.3750, grad_fn=<AddBackward0>)
# Epoch: 0136 train_loss= 0.40401 val_loss= 0.39971
# tensor(336977.3750, grad_fn=<AddBackward0>)
# tensor(336016.4062, grad_fn=<AddBackward0>)
# Epoch: 0137 train_loss= 0.40171 val_loss= 0.39673
# tensor(336016.4062, grad_fn=<AddBackward0>)
# tensor(335053.3750, grad_fn=<AddBackward0>)
# Epoch: 0138 train_loss= 0.39958 val_loss= 0.39529
# tensor(335053.3750, grad_fn=<AddBackward0>)
# tensor(334083.5312, grad_fn=<AddBackward0>)
# Epoch: 0139 train_loss= 0.39746 val_loss= 0.39319
# tensor(334083.5312, grad_fn=<AddBackward0>)
# tensor(333113., grad_fn=<AddBackward0>)
# Epoch: 0140 train_loss= 0.39489 val_loss= 0.39079
# tensor(333113., grad_fn=<AddBackward0>)
# tensor(332146.5000, grad_fn=<AddBackward0>)
# Epoch: 0141 train_loss= 0.39248 val_loss= 0.38858
# tensor(332146.5000, grad_fn=<AddBackward0>)
# tensor(331176.8438, grad_fn=<AddBackward0>)
# Epoch: 0142 train_loss= 0.39087 val_loss= 0.38720
# tensor(331176.8438, grad_fn=<AddBackward0>)
# tensor(330207.2500, grad_fn=<AddBackward0>)
# Epoch: 0143 train_loss= 0.38936 val_loss= 0.38523
# tensor(330207.2500, grad_fn=<AddBackward0>)
# tensor(329235.0312, grad_fn=<AddBackward0>)
# Epoch: 0144 train_loss= 0.38650 val_loss= 0.38324
# tensor(329235.0312, grad_fn=<AddBackward0>)
# tensor(328263.8750, grad_fn=<AddBackward0>)
# Epoch: 0145 train_loss= 0.38473 val_loss= 0.38240
# tensor(328263.8750, grad_fn=<AddBackward0>)
# tensor(327294.5000, grad_fn=<AddBackward0>)
# Epoch: 0146 train_loss= 0.38241 val_loss= 0.37936
# tensor(327294.5000, grad_fn=<AddBackward0>)
# tensor(326321.7500, grad_fn=<AddBackward0>)
# Epoch: 0147 train_loss= 0.38065 val_loss= 0.37663
# tensor(326321.7500, grad_fn=<AddBackward0>)
# tensor(325351.5625, grad_fn=<AddBackward0>)
# Epoch: 0148 train_loss= 0.37857 val_loss= 0.37533
# tensor(325351.5625, grad_fn=<AddBackward0>)
# tensor(324381.5000, grad_fn=<AddBackward0>)
# Epoch: 0149 train_loss= 0.37674 val_loss= 0.37381
# tensor(324381.5000, grad_fn=<AddBackward0>)
# tensor(323411.6875, grad_fn=<AddBackward0>)
# Epoch: 0150 train_loss= 0.37516 val_loss= 0.37101
# tensor(323411.6875, grad_fn=<AddBackward0>)
# tensor(322435.6875, grad_fn=<AddBackward0>)
# Epoch: 0151 train_loss= 0.37308 val_loss= 0.36949
# tensor(322435.6875, grad_fn=<AddBackward0>)
# tensor(321465.9062, grad_fn=<AddBackward0>)
# Epoch: 0152 train_loss= 0.37098 val_loss= 0.36820
# tensor(321465.9062, grad_fn=<AddBackward0>)
# tensor(320485.9688, grad_fn=<AddBackward0>)
# Epoch: 0153 train_loss= 0.36925 val_loss= 0.36663
# tensor(320485.9688, grad_fn=<AddBackward0>)
# tensor(319513.6875, grad_fn=<AddBackward0>)
# Epoch: 0154 train_loss= 0.36766 val_loss= 0.36409
# tensor(319513.6875, grad_fn=<AddBackward0>)
# tensor(318540.3438, grad_fn=<AddBackward0>)
# Epoch: 0155 train_loss= 0.36543 val_loss= 0.36249
# tensor(318540.3438, grad_fn=<AddBackward0>)
# tensor(317574.8750, grad_fn=<AddBackward0>)
# Epoch: 0156 train_loss= 0.36369 val_loss= 0.36119
# tensor(317574.8750, grad_fn=<AddBackward0>)
# tensor(316600.2500, grad_fn=<AddBackward0>)
# Epoch: 0157 train_loss= 0.36208 val_loss= 0.35850
# tensor(316600.2500, grad_fn=<AddBackward0>)
# tensor(315631., grad_fn=<AddBackward0>)
# Epoch: 0158 train_loss= 0.36037 val_loss= 0.35619
# tensor(315631., grad_fn=<AddBackward0>)
# tensor(314657.7188, grad_fn=<AddBackward0>)
# Epoch: 0159 train_loss= 0.35827 val_loss= 0.35443
# tensor(314657.7188, grad_fn=<AddBackward0>)
# tensor(313679.7500, grad_fn=<AddBackward0>)
# Epoch: 0160 train_loss= 0.35648 val_loss= 0.35278
# tensor(313679.7500, grad_fn=<AddBackward0>)
# tensor(312711.8438, grad_fn=<AddBackward0>)
# Epoch: 0161 train_loss= 0.35454 val_loss= 0.35161
# tensor(312711.8438, grad_fn=<AddBackward0>)
# tensor(311741.1250, grad_fn=<AddBackward0>)
# Epoch: 0162 train_loss= 0.35309 val_loss= 0.35104
# tensor(311741.1250, grad_fn=<AddBackward0>)
# tensor(310772.3750, grad_fn=<AddBackward0>)
# Epoch: 0163 train_loss= 0.35140 val_loss= 0.34840
# tensor(310772.3750, grad_fn=<AddBackward0>)
# tensor(309805.3750, grad_fn=<AddBackward0>)
# Epoch: 0164 train_loss= 0.35008 val_loss= 0.34748
# tensor(309805.3750, grad_fn=<AddBackward0>)
# tensor(308830.6875, grad_fn=<AddBackward0>)
# Epoch: 0165 train_loss= 0.34802 val_loss= 0.34586
# tensor(308830.6875, grad_fn=<AddBackward0>)
# tensor(307860.2188, grad_fn=<AddBackward0>)
# Epoch: 0166 train_loss= 0.34676 val_loss= 0.34328
# tensor(307860.2188, grad_fn=<AddBackward0>)
# tensor(306894.5625, grad_fn=<AddBackward0>)
# Epoch: 0167 train_loss= 0.34515 val_loss= 0.34201
# tensor(306894.5625, grad_fn=<AddBackward0>)
# tensor(305923.8750, grad_fn=<AddBackward0>)
# Epoch: 0168 train_loss= 0.34342 val_loss= 0.34092
# tensor(305923.8750, grad_fn=<AddBackward0>)
# tensor(304953.7500, grad_fn=<AddBackward0>)
# Epoch: 0169 train_loss= 0.34191 val_loss= 0.33927
# tensor(304953.7500, grad_fn=<AddBackward0>)
# tensor(303976.9375, grad_fn=<AddBackward0>)
# Epoch: 0170 train_loss= 0.34011 val_loss= 0.33753
# tensor(303976.9375, grad_fn=<AddBackward0>)
# tensor(303000.6875, grad_fn=<AddBackward0>)
# Epoch: 0171 train_loss= 0.33824 val_loss= 0.33596
# tensor(303000.6875, grad_fn=<AddBackward0>)
# tensor(302028.4375, grad_fn=<AddBackward0>)
# Epoch: 0172 train_loss= 0.33706 val_loss= 0.33463
# tensor(302028.4375, grad_fn=<AddBackward0>)
# tensor(301053.9375, grad_fn=<AddBackward0>)
# Epoch: 0173 train_loss= 0.33540 val_loss= 0.33264
# tensor(301053.9375, grad_fn=<AddBackward0>)
# tensor(300083.4375, grad_fn=<AddBackward0>)
# Epoch: 0174 train_loss= 0.33391 val_loss= 0.33179
# tensor(300083.4375, grad_fn=<AddBackward0>)
# tensor(299111.1875, grad_fn=<AddBackward0>)
# Epoch: 0175 train_loss= 0.33271 val_loss= 0.33009
# tensor(299111.1875, grad_fn=<AddBackward0>)
# tensor(298147.5000, grad_fn=<AddBackward0>)
# Epoch: 0176 train_loss= 0.33098 val_loss= 0.32860
# tensor(298147.5000, grad_fn=<AddBackward0>)
# tensor(297178.8125, grad_fn=<AddBackward0>)
# Epoch: 0177 train_loss= 0.32981 val_loss= 0.32680
# tensor(297178.8125, grad_fn=<AddBackward0>)
# tensor(296208.5000, grad_fn=<AddBackward0>)
# Epoch: 0178 train_loss= 0.32798 val_loss= 0.32466
# tensor(296208.5000, grad_fn=<AddBackward0>)
# tensor(295245.5938, grad_fn=<AddBackward0>)
# Epoch: 0179 train_loss= 0.32658 val_loss= 0.32399
# tensor(295245.5938, grad_fn=<AddBackward0>)
# tensor(294275.8125, grad_fn=<AddBackward0>)
# Epoch: 0180 train_loss= 0.32503 val_loss= 0.32260
# tensor(294275.8125, grad_fn=<AddBackward0>)
# tensor(293312.8750, grad_fn=<AddBackward0>)
# Epoch: 0181 train_loss= 0.32370 val_loss= 0.32111
# tensor(293312.8750, grad_fn=<AddBackward0>)
# tensor(292342.4375, grad_fn=<AddBackward0>)
# Epoch: 0182 train_loss= 0.32229 val_loss= 0.32014
# tensor(292342.4375, grad_fn=<AddBackward0>)
# tensor(291380.9062, grad_fn=<AddBackward0>)
# Epoch: 0183 train_loss= 0.32080 val_loss= 0.31828
# tensor(291380.9062, grad_fn=<AddBackward0>)
# tensor(290418.1562, grad_fn=<AddBackward0>)
# Epoch: 0184 train_loss= 0.31973 val_loss= 0.31787
# tensor(290418.1562, grad_fn=<AddBackward0>)
# tensor(289453.1562, grad_fn=<AddBackward0>)
# Epoch: 0185 train_loss= 0.31794 val_loss= 0.31591
# tensor(289453.1562, grad_fn=<AddBackward0>)
# tensor(288493.5000, grad_fn=<AddBackward0>)
# Epoch: 0186 train_loss= 0.31693 val_loss= 0.31446
# tensor(288493.5000, grad_fn=<AddBackward0>)
# tensor(287530.3750, grad_fn=<AddBackward0>)
# Epoch: 0187 train_loss= 0.31553 val_loss= 0.31444
# tensor(287530.3750, grad_fn=<AddBackward0>)
# tensor(286574.8750, grad_fn=<AddBackward0>)
# Epoch: 0188 train_loss= 0.31438 val_loss= 0.31165
# tensor(286574.8750, grad_fn=<AddBackward0>)
# tensor(285616., grad_fn=<AddBackward0>)
# Epoch: 0189 train_loss= 0.31276 val_loss= 0.31003
# tensor(285616., grad_fn=<AddBackward0>)
# tensor(284660.6250, grad_fn=<AddBackward0>)
# Epoch: 0190 train_loss= 0.31125 val_loss= 0.30906
# tensor(284660.6250, grad_fn=<AddBackward0>)
# tensor(283702.5000, grad_fn=<AddBackward0>)
# Epoch: 0191 train_loss= 0.31017 val_loss= 0.30835
# tensor(283702.5000, grad_fn=<AddBackward0>)
# tensor(282752.0625, grad_fn=<AddBackward0>)
# Epoch: 0192 train_loss= 0.30901 val_loss= 0.30717
# tensor(282752.0625, grad_fn=<AddBackward0>)
# tensor(281796.2500, grad_fn=<AddBackward0>)
# Epoch: 0193 train_loss= 0.30777 val_loss= 0.30579
# tensor(281796.2500, grad_fn=<AddBackward0>)
# tensor(280840.3125, grad_fn=<AddBackward0>)
# Epoch: 0194 train_loss= 0.30617 val_loss= 0.30395
# tensor(280840.3125, grad_fn=<AddBackward0>)
# tensor(279891.1875, grad_fn=<AddBackward0>)
# Epoch: 0195 train_loss= 0.30520 val_loss= 0.30378
# tensor(279891.1875, grad_fn=<AddBackward0>)
# tensor(278949., grad_fn=<AddBackward0>)
# Epoch: 0196 train_loss= 0.30398 val_loss= 0.30230
# tensor(278949., grad_fn=<AddBackward0>)
# tensor(278000.3125, grad_fn=<AddBackward0>)
# Epoch: 0197 train_loss= 0.30243 val_loss= 0.30052
# tensor(278000.3125, grad_fn=<AddBackward0>)
# tensor(277060.9062, grad_fn=<AddBackward0>)
# Epoch: 0198 train_loss= 0.30117 val_loss= 0.29932
# tensor(277060.9062, grad_fn=<AddBackward0>)
# tensor(276112.7500, grad_fn=<AddBackward0>)
# Epoch: 0199 train_loss= 0.29973 val_loss= 0.29828
# tensor(276112.7500, grad_fn=<AddBackward0>)
# tensor(275165.5938, grad_fn=<AddBackward0>)
# Epoch: 0200 train_loss= 0.29903 val_loss= 0.29736
# tensor(275165.5938, grad_fn=<AddBackward0>)
# tensor(274223.7500, grad_fn=<AddBackward0>)
# Epoch: 0201 train_loss= 0.29777 val_loss= 0.29577
# tensor(274223.7500, grad_fn=<AddBackward0>)
# tensor(273283.4688, grad_fn=<AddBackward0>)
# Epoch: 0202 train_loss= 0.29673 val_loss= 0.29503
# tensor(273283.4688, grad_fn=<AddBackward0>)
# tensor(272345.5000, grad_fn=<AddBackward0>)
# Epoch: 0203 train_loss= 0.29508 val_loss= 0.29373
# tensor(272345.5000, grad_fn=<AddBackward0>)
# tensor(271409.1250, grad_fn=<AddBackward0>)
# Epoch: 0204 train_loss= 0.29462 val_loss= 0.29237
# tensor(271409.1250, grad_fn=<AddBackward0>)
# tensor(270467.5938, grad_fn=<AddBackward0>)
# Epoch: 0205 train_loss= 0.29280 val_loss= 0.29195
# tensor(270467.5938, grad_fn=<AddBackward0>)
# tensor(269534.5312, grad_fn=<AddBackward0>)
# Epoch: 0206 train_loss= 0.29198 val_loss= 0.29083
# tensor(269534.5312, grad_fn=<AddBackward0>)
# tensor(268599.1562, grad_fn=<AddBackward0>)
# Epoch: 0207 train_loss= 0.29030 val_loss= 0.28910
# tensor(268599.1562, grad_fn=<AddBackward0>)
# tensor(267662.4375, grad_fn=<AddBackward0>)
# Epoch: 0208 train_loss= 0.28939 val_loss= 0.28800
# tensor(267662.4375, grad_fn=<AddBackward0>)
# tensor(266733.0625, grad_fn=<AddBackward0>)
# Epoch: 0209 train_loss= 0.28842 val_loss= 0.28652
# tensor(266733.0625, grad_fn=<AddBackward0>)
# tensor(265799.1562, grad_fn=<AddBackward0>)
# Epoch: 0210 train_loss= 0.28728 val_loss= 0.28570
# tensor(265799.1562, grad_fn=<AddBackward0>)
# tensor(264871.8125, grad_fn=<AddBackward0>)
# Epoch: 0211 train_loss= 0.28590 val_loss= 0.28457
# tensor(264871.8125, grad_fn=<AddBackward0>)
# tensor(263950.2812, grad_fn=<AddBackward0>)
# Epoch: 0212 train_loss= 0.28514 val_loss= 0.28315
# tensor(263950.2812, grad_fn=<AddBackward0>)
# tensor(263030.6562, grad_fn=<AddBackward0>)
# Epoch: 0213 train_loss= 0.28366 val_loss= 0.28205
# tensor(263030.6562, grad_fn=<AddBackward0>)
# tensor(262113.5625, grad_fn=<AddBackward0>)
# Epoch: 0214 train_loss= 0.28257 val_loss= 0.28159
# tensor(262113.5625, grad_fn=<AddBackward0>)
# tensor(261202.4375, grad_fn=<AddBackward0>)
# Epoch: 0215 train_loss= 0.28166 val_loss= 0.28051
# tensor(261202.4375, grad_fn=<AddBackward0>)
# tensor(260286.3906, grad_fn=<AddBackward0>)
# Epoch: 0216 train_loss= 0.28019 val_loss= 0.27871
# tensor(260286.3906, grad_fn=<AddBackward0>)
# tensor(259370.2500, grad_fn=<AddBackward0>)
# Epoch: 0217 train_loss= 0.27964 val_loss= 0.27842
# tensor(259370.2500, grad_fn=<AddBackward0>)
# tensor(258457.6875, grad_fn=<AddBackward0>)
# Epoch: 0218 train_loss= 0.27839 val_loss= 0.27708
# tensor(258457.6875, grad_fn=<AddBackward0>)
# tensor(257544.5000, grad_fn=<AddBackward0>)
# Epoch: 0219 train_loss= 0.27736 val_loss= 0.27584
# tensor(257544.5000, grad_fn=<AddBackward0>)
# tensor(256641.2344, grad_fn=<AddBackward0>)
# Epoch: 0220 train_loss= 0.27619 val_loss= 0.27477
# tensor(256641.2344, grad_fn=<AddBackward0>)
# tensor(255732.1250, grad_fn=<AddBackward0>)
# Epoch: 0221 train_loss= 0.27515 val_loss= 0.27377
# tensor(255732.1250, grad_fn=<AddBackward0>)
# tensor(254832.8594, grad_fn=<AddBackward0>)
# Epoch: 0222 train_loss= 0.27382 val_loss= 0.27297
# tensor(254832.8594, grad_fn=<AddBackward0>)
# tensor(253931.2812, grad_fn=<AddBackward0>)
# Epoch: 0223 train_loss= 0.27257 val_loss= 0.27176
# tensor(253931.2812, grad_fn=<AddBackward0>)
# tensor(253036.0781, grad_fn=<AddBackward0>)
# Epoch: 0224 train_loss= 0.27190 val_loss= 0.27049
# tensor(253036.0781, grad_fn=<AddBackward0>)
# tensor(252144.8281, grad_fn=<AddBackward0>)
# Epoch: 0225 train_loss= 0.27101 val_loss= 0.26970
# tensor(252144.8281, grad_fn=<AddBackward0>)
# tensor(251258.3438, grad_fn=<AddBackward0>)
# Epoch: 0226 train_loss= 0.26977 val_loss= 0.26898
# tensor(251258.3438, grad_fn=<AddBackward0>)
# tensor(250367.1094, grad_fn=<AddBackward0>)
# Epoch: 0227 train_loss= 0.26872 val_loss= 0.26714
# tensor(250367.1094, grad_fn=<AddBackward0>)
# tensor(249486.0625, grad_fn=<AddBackward0>)
# Epoch: 0228 train_loss= 0.26798 val_loss= 0.26617
# tensor(249486.0625, grad_fn=<AddBackward0>)
# tensor(248600.1094, grad_fn=<AddBackward0>)
# Epoch: 0229 train_loss= 0.26656 val_loss= 0.26557
# tensor(248600.1094, grad_fn=<AddBackward0>)
# tensor(247713.4062, grad_fn=<AddBackward0>)
# Epoch: 0230 train_loss= 0.26592 val_loss= 0.26479
# tensor(247713.4062, grad_fn=<AddBackward0>)
# tensor(246832.1719, grad_fn=<AddBackward0>)
# Epoch: 0231 train_loss= 0.26487 val_loss= 0.26371
# tensor(246832.1719, grad_fn=<AddBackward0>)
# tensor(245961.1250, grad_fn=<AddBackward0>)
# Epoch: 0232 train_loss= 0.26354 val_loss= 0.26250
# tensor(245961.1250, grad_fn=<AddBackward0>)
# tensor(245089.3125, grad_fn=<AddBackward0>)
# Epoch: 0233 train_loss= 0.26259 val_loss= 0.26157
# tensor(245089.3125, grad_fn=<AddBackward0>)
# tensor(244226.3438, grad_fn=<AddBackward0>)
# Epoch: 0234 train_loss= 0.26199 val_loss= 0.26108
# tensor(244226.3438, grad_fn=<AddBackward0>)
# tensor(243356.4688, grad_fn=<AddBackward0>)
# Epoch: 0235 train_loss= 0.26072 val_loss= 0.25961
# tensor(243356.4688, grad_fn=<AddBackward0>)
# tensor(242487.7812, grad_fn=<AddBackward0>)
# Epoch: 0236 train_loss= 0.26001 val_loss= 0.25855
# tensor(242487.7812, grad_fn=<AddBackward0>)
# tensor(241621.5938, grad_fn=<AddBackward0>)
# Epoch: 0237 train_loss= 0.25889 val_loss= 0.25726
# tensor(241621.5938, grad_fn=<AddBackward0>)
# tensor(240774.2500, grad_fn=<AddBackward0>)
# Epoch: 0238 train_loss= 0.25808 val_loss= 0.25650
# tensor(240774.2500, grad_fn=<AddBackward0>)
# tensor(239913.3438, grad_fn=<AddBackward0>)
# Epoch: 0239 train_loss= 0.25704 val_loss= 0.25613
# tensor(239913.3438, grad_fn=<AddBackward0>)
# tensor(239065.1562, grad_fn=<AddBackward0>)
# Epoch: 0240 train_loss= 0.25604 val_loss= 0.25455
# tensor(239065.1562, grad_fn=<AddBackward0>)
# tensor(238213.8281, grad_fn=<AddBackward0>)
# Epoch: 0241 train_loss= 0.25515 val_loss= 0.25430
# tensor(238213.8281, grad_fn=<AddBackward0>)
# tensor(237372.9531, grad_fn=<AddBackward0>)
# Epoch: 0242 train_loss= 0.25420 val_loss= 0.25246
# tensor(237372.9531, grad_fn=<AddBackward0>)
# tensor(236533.9688, grad_fn=<AddBackward0>)
# Epoch: 0243 train_loss= 0.25321 val_loss= 0.25184
# tensor(236533.9688, grad_fn=<AddBackward0>)
# tensor(235699.1250, grad_fn=<AddBackward0>)
# Epoch: 0244 train_loss= 0.25238 val_loss= 0.25118
# tensor(235699.1250, grad_fn=<AddBackward0>)
# tensor(234866.4375, grad_fn=<AddBackward0>)
# Epoch: 0245 train_loss= 0.25127 val_loss= 0.25063
# tensor(234866.4375, grad_fn=<AddBackward0>)
# tensor(234036.8125, grad_fn=<AddBackward0>)
# Epoch: 0246 train_loss= 0.25070 val_loss= 0.24937
# tensor(234036.8125, grad_fn=<AddBackward0>)
# tensor(233210.5000, grad_fn=<AddBackward0>)
# Epoch: 0247 train_loss= 0.24954 val_loss= 0.24851
# tensor(233210.5000, grad_fn=<AddBackward0>)
# tensor(232388.4375, grad_fn=<AddBackward0>)
# Epoch: 0248 train_loss= 0.24868 val_loss= 0.24746
# tensor(232388.4375, grad_fn=<AddBackward0>)
# tensor(231569.7500, grad_fn=<AddBackward0>)
# Epoch: 0249 train_loss= 0.24754 val_loss= 0.24634
# tensor(231569.7500, grad_fn=<AddBackward0>)
# tensor(230760.5625, grad_fn=<AddBackward0>)
# Epoch: 0250 train_loss= 0.24677 val_loss= 0.24581
# tensor(230760.5625, grad_fn=<AddBackward0>)
# tensor(229944.5000, grad_fn=<AddBackward0>)
# Epoch: 0251 train_loss= 0.24601 val_loss= 0.24501
# tensor(229944.5000, grad_fn=<AddBackward0>)
# tensor(229128.5469, grad_fn=<AddBackward0>)
# Epoch: 0252 train_loss= 0.24538 val_loss= 0.24428
# tensor(229128.5469, grad_fn=<AddBackward0>)
# tensor(228324.3281, grad_fn=<AddBackward0>)
# Epoch: 0253 train_loss= 0.24428 val_loss= 0.24340
# tensor(228324.3281, grad_fn=<AddBackward0>)
# tensor(227517.1250, grad_fn=<AddBackward0>)
# Epoch: 0254 train_loss= 0.24344 val_loss= 0.24221
# tensor(227517.1250, grad_fn=<AddBackward0>)
# tensor(226705.1562, grad_fn=<AddBackward0>)
# Epoch: 0255 train_loss= 0.24271 val_loss= 0.24197
# tensor(226705.1562, grad_fn=<AddBackward0>)
# tensor(225909.0625, grad_fn=<AddBackward0>)
# Epoch: 0256 train_loss= 0.24172 val_loss= 0.24099
# tensor(225909.0625, grad_fn=<AddBackward0>)
# tensor(225113.4062, grad_fn=<AddBackward0>)
# Epoch: 0257 train_loss= 0.24060 val_loss= 0.24065
# tensor(225113.4062, grad_fn=<AddBackward0>)
# tensor(224335., grad_fn=<AddBackward0>)
# Epoch: 0258 train_loss= 0.24032 val_loss= 0.23883
# tensor(224335., grad_fn=<AddBackward0>)
# tensor(223557.5000, grad_fn=<AddBackward0>)
# Epoch: 0259 train_loss= 0.23918 val_loss= 0.23868
# tensor(223557.5000, grad_fn=<AddBackward0>)
# tensor(222778.0781, grad_fn=<AddBackward0>)
# Epoch: 0260 train_loss= 0.23836 val_loss= 0.23741
# tensor(222778.0781, grad_fn=<AddBackward0>)
# tensor(221994.1250, grad_fn=<AddBackward0>)
# Epoch: 0261 train_loss= 0.23754 val_loss= 0.23627
# tensor(221994.1250, grad_fn=<AddBackward0>)
# tensor(221228.1094, grad_fn=<AddBackward0>)
# Epoch: 0262 train_loss= 0.23670 val_loss= 0.23523
# tensor(221228.1094, grad_fn=<AddBackward0>)
# tensor(220460.4844, grad_fn=<AddBackward0>)
# Epoch: 0263 train_loss= 0.23571 val_loss= 0.23463
# tensor(220460.4844, grad_fn=<AddBackward0>)
# tensor(219695.8125, grad_fn=<AddBackward0>)
# Epoch: 0264 train_loss= 0.23507 val_loss= 0.23388
# tensor(219695.8125, grad_fn=<AddBackward0>)
# tensor(218927.2500, grad_fn=<AddBackward0>)
# Epoch: 0265 train_loss= 0.23402 val_loss= 0.23331
# tensor(218927.2500, grad_fn=<AddBackward0>)
# tensor(218165.0469, grad_fn=<AddBackward0>)
# Epoch: 0266 train_loss= 0.23342 val_loss= 0.23262
# tensor(218165.0469, grad_fn=<AddBackward0>)
# tensor(217405.6250, grad_fn=<AddBackward0>)
# Epoch: 0267 train_loss= 0.23249 val_loss= 0.23175
# tensor(217405.6250, grad_fn=<AddBackward0>)
# tensor(216663.2812, grad_fn=<AddBackward0>)
# Epoch: 0268 train_loss= 0.23193 val_loss= 0.23127
# tensor(216663.2812, grad_fn=<AddBackward0>)
# tensor(215921.2812, grad_fn=<AddBackward0>)
# Epoch: 0269 train_loss= 0.23089 val_loss= 0.22993
# tensor(215921.2812, grad_fn=<AddBackward0>)
# tensor(215180.8438, grad_fn=<AddBackward0>)
# Epoch: 0270 train_loss= 0.23007 val_loss= 0.22898
# tensor(215180.8438, grad_fn=<AddBackward0>)
# tensor(214440.5625, grad_fn=<AddBackward0>)
# Epoch: 0271 train_loss= 0.22912 val_loss= 0.22802
# tensor(214440.5625, grad_fn=<AddBackward0>)
# tensor(213708.7812, grad_fn=<AddBackward0>)
# Epoch: 0272 train_loss= 0.22854 val_loss= 0.22750
# tensor(213708.7812, grad_fn=<AddBackward0>)
# tensor(212980.6562, grad_fn=<AddBackward0>)
# Epoch: 0273 train_loss= 0.22786 val_loss= 0.22601
# tensor(212980.6562, grad_fn=<AddBackward0>)
# tensor(212259.1562, grad_fn=<AddBackward0>)
# Epoch: 0274 train_loss= 0.22693 val_loss= 0.22584
# tensor(212259.1562, grad_fn=<AddBackward0>)
# tensor(211523.6406, grad_fn=<AddBackward0>)
# Epoch: 0275 train_loss= 0.22612 val_loss= 0.22529
# tensor(211523.6406, grad_fn=<AddBackward0>)
# tensor(210654.2656, grad_fn=<AddBackward0>)
# Epoch: 0276 train_loss= 0.22548 val_loss= 0.22444
# tensor(210654.2656, grad_fn=<AddBackward0>)
# tensor(209788.0938, grad_fn=<AddBackward0>)
# Epoch: 0277 train_loss= 0.22428 val_loss= 0.22417
# tensor(209788.0938, grad_fn=<AddBackward0>)
# tensor(208921.5625, grad_fn=<AddBackward0>)
# Epoch: 0278 train_loss= 0.22350 val_loss= 0.22227
# tensor(208921.5625, grad_fn=<AddBackward0>)
# tensor(208053.7188, grad_fn=<AddBackward0>)
# Epoch: 0279 train_loss= 0.22272 val_loss= 0.22137
# tensor(208053.7188, grad_fn=<AddBackward0>)
# tensor(207188.5312, grad_fn=<AddBackward0>)
# Epoch: 0280 train_loss= 0.22212 val_loss= 0.22199
# tensor(207188.5312, grad_fn=<AddBackward0>)
# tensor(206330.8125, grad_fn=<AddBackward0>)
# Epoch: 0281 train_loss= 0.22104 val_loss= 0.21958
# tensor(206330.8125, grad_fn=<AddBackward0>)
# tensor(205469.8125, grad_fn=<AddBackward0>)
# Epoch: 0282 train_loss= 0.22011 val_loss= 0.21926
# tensor(205469.8125, grad_fn=<AddBackward0>)
# tensor(204614.0625, grad_fn=<AddBackward0>)
# Epoch: 0283 train_loss= 0.21906 val_loss= 0.21809
# tensor(204614.0625, grad_fn=<AddBackward0>)
# tensor(203758.7969, grad_fn=<AddBackward0>)
# Epoch: 0284 train_loss= 0.21836 val_loss= 0.21723
# tensor(203758.7969, grad_fn=<AddBackward0>)
# tensor(202906.7188, grad_fn=<AddBackward0>)
# Epoch: 0285 train_loss= 0.21763 val_loss= 0.21604
# tensor(202906.7188, grad_fn=<AddBackward0>)
# tensor(202055.1875, grad_fn=<AddBackward0>)
# Epoch: 0286 train_loss= 0.21688 val_loss= 0.21538
# tensor(202055.1875, grad_fn=<AddBackward0>)
# tensor(201206.9531, grad_fn=<AddBackward0>)
# Epoch: 0287 train_loss= 0.21553 val_loss= 0.21485
# tensor(201206.9531, grad_fn=<AddBackward0>)
# tensor(200361.9375, grad_fn=<AddBackward0>)
# Epoch: 0288 train_loss= 0.21441 val_loss= 0.21371
# tensor(200361.9375, grad_fn=<AddBackward0>)
# tensor(199516.7188, grad_fn=<AddBackward0>)
# Epoch: 0289 train_loss= 0.21388 val_loss= 0.21289
# tensor(199516.7188, grad_fn=<AddBackward0>)
# tensor(198674.2500, grad_fn=<AddBackward0>)
# Epoch: 0290 train_loss= 0.21310 val_loss= 0.21185
# tensor(198674.2500, grad_fn=<AddBackward0>)
# tensor(197834.2188, grad_fn=<AddBackward0>)
# Epoch: 0291 train_loss= 0.21210 val_loss= 0.21130
# tensor(197834.2188, grad_fn=<AddBackward0>)
# tensor(196997.2500, grad_fn=<AddBackward0>)
# Epoch: 0292 train_loss= 0.21132 val_loss= 0.21031
# tensor(196997.2500, grad_fn=<AddBackward0>)
# tensor(196163.6094, grad_fn=<AddBackward0>)
# Epoch: 0293 train_loss= 0.21054 val_loss= 0.20937
# tensor(196163.6094, grad_fn=<AddBackward0>)
# tensor(195330.5000, grad_fn=<AddBackward0>)
# Epoch: 0294 train_loss= 0.20967 val_loss= 0.20816
# tensor(195330.5000, grad_fn=<AddBackward0>)
# tensor(194499.9531, grad_fn=<AddBackward0>)
# Epoch: 0295 train_loss= 0.20875 val_loss= 0.20734
# tensor(194499.9531, grad_fn=<AddBackward0>)
# tensor(193669.3750, grad_fn=<AddBackward0>)
# Epoch: 0296 train_loss= 0.20790 val_loss= 0.20699
# tensor(193669.3750, grad_fn=<AddBackward0>)
# tensor(192844.6250, grad_fn=<AddBackward0>)
# Epoch: 0297 train_loss= 0.20707 val_loss= 0.20556
# tensor(192844.6250, grad_fn=<AddBackward0>)
# tensor(192018.5312, grad_fn=<AddBackward0>)
# Epoch: 0298 train_loss= 0.20635 val_loss= 0.20498
# tensor(192018.5312, grad_fn=<AddBackward0>)
# tensor(191199.1562, grad_fn=<AddBackward0>)
# Epoch: 0299 train_loss= 0.20541 val_loss= 0.20487
# tensor(191199.1562, grad_fn=<AddBackward0>)
# tensor(190378.7188, grad_fn=<AddBackward0>)
# Epoch: 0300 train_loss= 0.20422 val_loss= 0.20339
# tensor(190378.7188, grad_fn=<AddBackward0>)
# tensor(189564.7812, grad_fn=<AddBackward0>)
# Epoch: 0301 train_loss= 0.20354 val_loss= 0.20299
# tensor(189564.7812, grad_fn=<AddBackward0>)
# tensor(188748.2188, grad_fn=<AddBackward0>)
# Epoch: 0302 train_loss= 0.20296 val_loss= 0.20208
# tensor(188748.2188, grad_fn=<AddBackward0>)
# tensor(187935.0156, grad_fn=<AddBackward0>)
# Epoch: 0303 train_loss= 0.20189 val_loss= 0.20139
# tensor(187935.0156, grad_fn=<AddBackward0>)
# tensor(187123.7188, grad_fn=<AddBackward0>)
# Epoch: 0304 train_loss= 0.20101 val_loss= 0.20038
# tensor(187123.7188, grad_fn=<AddBackward0>)
# tensor(186314.4531, grad_fn=<AddBackward0>)
# Epoch: 0305 train_loss= 0.20028 val_loss= 0.19936
# tensor(186314.4531, grad_fn=<AddBackward0>)
# tensor(185509.8438, grad_fn=<AddBackward0>)
# Epoch: 0306 train_loss= 0.19937 val_loss= 0.19820
# tensor(185509.8438, grad_fn=<AddBackward0>)
# tensor(184708.2031, grad_fn=<AddBackward0>)
# Epoch: 0307 train_loss= 0.19884 val_loss= 0.19775
# tensor(184708.2031, grad_fn=<AddBackward0>)
# tensor(183909.4688, grad_fn=<AddBackward0>)
# Epoch: 0308 train_loss= 0.19804 val_loss= 0.19652
# tensor(183909.4688, grad_fn=<AddBackward0>)
# tensor(183113.7188, grad_fn=<AddBackward0>)
# Epoch: 0309 train_loss= 0.19711 val_loss= 0.19616
# tensor(183113.7188, grad_fn=<AddBackward0>)
# tensor(182319.7812, grad_fn=<AddBackward0>)
# Epoch: 0310 train_loss= 0.19619 val_loss= 0.19581
# tensor(182319.7812, grad_fn=<AddBackward0>)
# tensor(181526.8594, grad_fn=<AddBackward0>)
# Epoch: 0311 train_loss= 0.19560 val_loss= 0.19487
# tensor(181526.8594, grad_fn=<AddBackward0>)
# tensor(180740.9375, grad_fn=<AddBackward0>)
# Epoch: 0312 train_loss= 0.19454 val_loss= 0.19420
# tensor(180740.9375, grad_fn=<AddBackward0>)
# tensor(179957.1562, grad_fn=<AddBackward0>)
# Epoch: 0313 train_loss= 0.19367 val_loss= 0.19289
# tensor(179957.1562, grad_fn=<AddBackward0>)
# tensor(179173.4375, grad_fn=<AddBackward0>)
# Epoch: 0314 train_loss= 0.19296 val_loss= 0.19174
# tensor(179173.4375, grad_fn=<AddBackward0>)
# tensor(178393.1875, grad_fn=<AddBackward0>)
# Epoch: 0315 train_loss= 0.19199 val_loss= 0.19130
# tensor(178393.1875, grad_fn=<AddBackward0>)
# tensor(177613.3438, grad_fn=<AddBackward0>)
# Epoch: 0316 train_loss= 0.19149 val_loss= 0.19043
# tensor(177613.3438, grad_fn=<AddBackward0>)
# tensor(176837.4688, grad_fn=<AddBackward0>)
# Epoch: 0317 train_loss= 0.19059 val_loss= 0.18924
# tensor(176837.4688, grad_fn=<AddBackward0>)
# tensor(176061.6250, grad_fn=<AddBackward0>)
# Epoch: 0318 train_loss= 0.19005 val_loss= 0.18919
# tensor(176061.6250, grad_fn=<AddBackward0>)
# tensor(175291.2500, grad_fn=<AddBackward0>)
# Epoch: 0319 train_loss= 0.18899 val_loss= 0.18799
# tensor(175291.2500, grad_fn=<AddBackward0>)
# tensor(174525.3438, grad_fn=<AddBackward0>)
# Epoch: 0320 train_loss= 0.18820 val_loss= 0.18751
# tensor(174525.3438, grad_fn=<AddBackward0>)
# tensor(173762.5312, grad_fn=<AddBackward0>)
# Epoch: 0321 train_loss= 0.18761 val_loss= 0.18679
# tensor(173762.5312, grad_fn=<AddBackward0>)
# tensor(173000.5938, grad_fn=<AddBackward0>)
# Epoch: 0322 train_loss= 0.18666 val_loss= 0.18527
# tensor(173000.5938, grad_fn=<AddBackward0>)
# tensor(172241.5000, grad_fn=<AddBackward0>)
# Epoch: 0323 train_loss= 0.18550 val_loss= 0.18463
# tensor(172241.5000, grad_fn=<AddBackward0>)
# tensor(171486.4688, grad_fn=<AddBackward0>)
# Epoch: 0324 train_loss= 0.18497 val_loss= 0.18412
# tensor(171486.4688, grad_fn=<AddBackward0>)
# tensor(170731.5625, grad_fn=<AddBackward0>)
# Epoch: 0325 train_loss= 0.18430 val_loss= 0.18304
# tensor(170731.5625, grad_fn=<AddBackward0>)
# tensor(169979.1562, grad_fn=<AddBackward0>)
# Epoch: 0326 train_loss= 0.18344 val_loss= 0.18291
# tensor(169979.1562, grad_fn=<AddBackward0>)
# tensor(169231.3750, grad_fn=<AddBackward0>)
# Epoch: 0327 train_loss= 0.18282 val_loss= 0.18226
# tensor(169231.3750, grad_fn=<AddBackward0>)
# tensor(168487.6562, grad_fn=<AddBackward0>)
# Epoch: 0328 train_loss= 0.18201 val_loss= 0.18190
# tensor(168487.6562, grad_fn=<AddBackward0>)
# tensor(167744.6562, grad_fn=<AddBackward0>)
# Epoch: 0329 train_loss= 0.18124 val_loss= 0.18043
# tensor(167744.6562, grad_fn=<AddBackward0>)
# tensor(167002.4062, grad_fn=<AddBackward0>)
# Epoch: 0330 train_loss= 0.18054 val_loss= 0.17992
# tensor(167002.4062, grad_fn=<AddBackward0>)
# tensor(166265.5625, grad_fn=<AddBackward0>)
# Epoch: 0331 train_loss= 0.18003 val_loss= 0.17870
# tensor(166265.5625, grad_fn=<AddBackward0>)
# tensor(165531.5000, grad_fn=<AddBackward0>)
# Epoch: 0332 train_loss= 0.17910 val_loss= 0.17861
# tensor(165531.5000, grad_fn=<AddBackward0>)
# tensor(164798.6562, grad_fn=<AddBackward0>)
# Epoch: 0333 train_loss= 0.17839 val_loss= 0.17683
# tensor(164798.6562, grad_fn=<AddBackward0>)
# tensor(164069.8281, grad_fn=<AddBackward0>)
# Epoch: 0334 train_loss= 0.17754 val_loss= 0.17650
# tensor(164069.8281, grad_fn=<AddBackward0>)
# tensor(163348.4375, grad_fn=<AddBackward0>)
# Epoch: 0335 train_loss= 0.17694 val_loss= 0.17570
# tensor(163348.4375, grad_fn=<AddBackward0>)
# tensor(162626.4219, grad_fn=<AddBackward0>)
# Epoch: 0336 train_loss= 0.17617 val_loss= 0.17507
# tensor(162626.4219, grad_fn=<AddBackward0>)
# tensor(161906.9688, grad_fn=<AddBackward0>)
# Epoch: 0337 train_loss= 0.17547 val_loss= 0.17509
# tensor(161906.9688, grad_fn=<AddBackward0>)
# tensor(161193.8125, grad_fn=<AddBackward0>)
# Epoch: 0338 train_loss= 0.17466 val_loss= 0.17357
# tensor(161193.8125, grad_fn=<AddBackward0>)
# tensor(160482.6875, grad_fn=<AddBackward0>)
# Epoch: 0339 train_loss= 0.17368 val_loss= 0.17254
# tensor(160482.6875, grad_fn=<AddBackward0>)
# tensor(159775.6562, grad_fn=<AddBackward0>)
# Epoch: 0340 train_loss= 0.17327 val_loss= 0.17207
# tensor(159775.6562, grad_fn=<AddBackward0>)
# tensor(159069.3438, grad_fn=<AddBackward0>)
# Epoch: 0341 train_loss= 0.17223 val_loss= 0.17199
# tensor(159069.3438, grad_fn=<AddBackward0>)
# tensor(158366.6250, grad_fn=<AddBackward0>)
# Epoch: 0342 train_loss= 0.17189 val_loss= 0.17150
# tensor(158366.6250, grad_fn=<AddBackward0>)
# tensor(157667.6719, grad_fn=<AddBackward0>)
# Epoch: 0343 train_loss= 0.17109 val_loss= 0.17041
# tensor(157667.6719, grad_fn=<AddBackward0>)
# tensor(156971.1562, grad_fn=<AddBackward0>)
# Epoch: 0344 train_loss= 0.17031 val_loss= 0.16947
# tensor(156971.1562, grad_fn=<AddBackward0>)
# tensor(156279.4688, grad_fn=<AddBackward0>)
# Epoch: 0345 train_loss= 0.16972 val_loss= 0.16835
# tensor(156279.4688, grad_fn=<AddBackward0>)
# tensor(155589.3594, grad_fn=<AddBackward0>)
# Epoch: 0346 train_loss= 0.16894 val_loss= 0.16857
# tensor(155589.3594, grad_fn=<AddBackward0>)
# tensor(154903.7031, grad_fn=<AddBackward0>)
# Epoch: 0347 train_loss= 0.16832 val_loss= 0.16754
# ...
# Epoch: 0737 train_loss= 0.06566 val_loss= 0.06534
# tensor(54112.0078, grad_fn=<AddBackward0>)
# tensor(54025.5859, grad_fn=<AddBackward0>)
# Epoch: 0738 train_loss= 0.06535 val_loss= 0.06549
# tensor(54025.5859, grad_fn=<AddBackward0>)
# tensor(53941.1211, grad_fn=<AddBackward0>)
# Epoch: 0739 train_loss= 0.06538 val_loss= 0.06516
# tensor(53941.1211, grad_fn=<AddBackward0>)
# tensor(53864.3125, grad_fn=<AddBackward0>)
# Epoch: 0740 train_loss= 0.06544 val_loss= 0.06526
# tensor(53864.3125, grad_fn=<AddBackward0>)
# tensor(53788.7070, grad_fn=<AddBackward0>)
# Epoch: 0741 train_loss= 0.06545 val_loss= 0.06496
# tensor(53788.7070, grad_fn=<AddBackward0>)
# tensor(53712.3359, grad_fn=<AddBackward0>)
# Epoch: 0742 train_loss= 0.06518 val_loss= 0.06513
# tensor(53712.3359, grad_fn=<AddBackward0>)
# tensor(53637.2656, grad_fn=<AddBackward0>)
# Epoch: 0743 train_loss= 0.06523 val_loss= 0.06496
# tensor(53637.2656, grad_fn=<AddBackward0>)
# tensor(53564.8203, grad_fn=<AddBackward0>)
# Epoch: 0744 train_loss= 0.06543 val_loss= 0.06489
# tensor(53564.8203, grad_fn=<AddBackward0>)
# tensor(53494.8047, grad_fn=<AddBackward0>)
# Epoch: 0745 train_loss= 0.06485 val_loss= 0.06524
# tensor(53494.8047, grad_fn=<AddBackward0>)
# tensor(53419.5430, grad_fn=<AddBackward0>)
# Epoch: 0746 train_loss= 0.06489 val_loss= 0.06446
# tensor(53419.5430, grad_fn=<AddBackward0>)
# tensor(53346.9062, grad_fn=<AddBackward0>)
# Epoch: 0747 train_loss= 0.06463 val_loss= 0.06455
# tensor(53346.9062, grad_fn=<AddBackward0>)
# tensor(53276.1602, grad_fn=<AddBackward0>)
# Epoch: 0748 train_loss= 0.06449 val_loss= 0.06534
# tensor(53276.1602, grad_fn=<AddBackward0>)
# tensor(53204.0469, grad_fn=<AddBackward0>)
# Epoch: 0749 train_loss= 0.06509 val_loss= 0.06404
# tensor(53204.0469, grad_fn=<AddBackward0>)
# tensor(53135.9648, grad_fn=<AddBackward0>)
# Epoch: 0750 train_loss= 0.06475 val_loss= 0.06434
# tensor(53135.9648, grad_fn=<AddBackward0>)
# tensor(53067.1094, grad_fn=<AddBackward0>)
# Epoch: 0751 train_loss= 0.06443 val_loss= 0.06427
# tensor(53067.1094, grad_fn=<AddBackward0>)
# tensor(52996.3281, grad_fn=<AddBackward0>)
# Epoch: 0752 train_loss= 0.06429 val_loss= 0.06421
# tensor(52996.3281, grad_fn=<AddBackward0>)
# tensor(52923.0938, grad_fn=<AddBackward0>)
# Epoch: 0753 train_loss= 0.06422 val_loss= 0.06435
# tensor(52923.0938, grad_fn=<AddBackward0>)
# tensor(52849.5977, grad_fn=<AddBackward0>)
# Epoch: 0754 train_loss= 0.06389 val_loss= 0.06421
# tensor(52849.5977, grad_fn=<AddBackward0>)
# tensor(52772.9805, grad_fn=<AddBackward0>)
# Epoch: 0755 train_loss= 0.06397 val_loss= 0.06401
# tensor(52772.9805, grad_fn=<AddBackward0>)
# tensor(52694.5859, grad_fn=<AddBackward0>)
# Epoch: 0756 train_loss= 0.06420 val_loss= 0.06345
# tensor(52694.5859, grad_fn=<AddBackward0>)
# tensor(52619.4375, grad_fn=<AddBackward0>)
# Epoch: 0757 train_loss= 0.06407 val_loss= 0.06429
# tensor(52619.4375, grad_fn=<AddBackward0>)
# tensor(52547.2500, grad_fn=<AddBackward0>)
# Epoch: 0758 train_loss= 0.06414 val_loss= 0.06395
# tensor(52547.2500, grad_fn=<AddBackward0>)
# tensor(52473.5703, grad_fn=<AddBackward0>)
# Epoch: 0759 train_loss= 0.06402 val_loss= 0.06479
# tensor(52473.5703, grad_fn=<AddBackward0>)
# tensor(52399.6445, grad_fn=<AddBackward0>)
# Epoch: 0760 train_loss= 0.06367 val_loss= 0.06386
# tensor(52399.6445, grad_fn=<AddBackward0>)
# tensor(52324.9922, grad_fn=<AddBackward0>)
# Epoch: 0761 train_loss= 0.06373 val_loss= 0.06379
# tensor(52324.9922, grad_fn=<AddBackward0>)
# tensor(52252.7539, grad_fn=<AddBackward0>)
# Epoch: 0762 train_loss= 0.06366 val_loss= 0.06394
# tensor(52252.7539, grad_fn=<AddBackward0>)
# tensor(52182.7734, grad_fn=<AddBackward0>)
# Epoch: 0763 train_loss= 0.06363 val_loss= 0.06400
# tensor(52182.7734, grad_fn=<AddBackward0>)
# tensor(52119.0938, grad_fn=<AddBackward0>)
# Epoch: 0764 train_loss= 0.06398 val_loss= 0.06352
# tensor(52119.0938, grad_fn=<AddBackward0>)
# tensor(52059.0039, grad_fn=<AddBackward0>)
# Epoch: 0765 train_loss= 0.06349 val_loss= 0.06312
# tensor(52059.0039, grad_fn=<AddBackward0>)
# tensor(51996.6875, grad_fn=<AddBackward0>)
# Epoch: 0766 train_loss= 0.06332 val_loss= 0.06385
# tensor(51996.6875, grad_fn=<AddBackward0>)
# tensor(51934.1172, grad_fn=<AddBackward0>)
# Epoch: 0767 train_loss= 0.06319 val_loss= 0.06327
# tensor(51934.1172, grad_fn=<AddBackward0>)
# tensor(51871.9492, grad_fn=<AddBackward0>)
# Epoch: 0768 train_loss= 0.06312 val_loss= 0.06314
# tensor(51871.9492, grad_fn=<AddBackward0>)
# tensor(51806.9062, grad_fn=<AddBackward0>)
# Epoch: 0769 train_loss= 0.06308 val_loss= 0.06316
# tensor(51806.9062, grad_fn=<AddBackward0>)
# tensor(51738.9531, grad_fn=<AddBackward0>)
# Epoch: 0770 train_loss= 0.06271 val_loss= 0.06348
# tensor(51738.9531, grad_fn=<AddBackward0>)
# tensor(51667.7656, grad_fn=<AddBackward0>)
# Epoch: 0771 train_loss= 0.06269 val_loss= 0.06298
# tensor(51667.7656, grad_fn=<AddBackward0>)
# tensor(51593.1406, grad_fn=<AddBackward0>)
# Epoch: 0772 train_loss= 0.06258 val_loss= 0.06287
# tensor(51593.1406, grad_fn=<AddBackward0>)
# tensor(51520.0156, grad_fn=<AddBackward0>)
# Epoch: 0773 train_loss= 0.06294 val_loss= 0.06292
# tensor(51520.0156, grad_fn=<AddBackward0>)
# tensor(51446.7422, grad_fn=<AddBackward0>)
# Epoch: 0774 train_loss= 0.06242 val_loss= 0.06256
# tensor(51446.7422, grad_fn=<AddBackward0>)
# tensor(51377.6719, grad_fn=<AddBackward0>)
# Epoch: 0775 train_loss= 0.06256 val_loss= 0.06288
# tensor(51377.6719, grad_fn=<AddBackward0>)
# tensor(51310.8984, grad_fn=<AddBackward0>)
# Epoch: 0776 train_loss= 0.06257 val_loss= 0.06290
# tensor(51310.8984, grad_fn=<AddBackward0>)
# tensor(51245.4414, grad_fn=<AddBackward0>)
# Epoch: 0777 train_loss= 0.06242 val_loss= 0.06265
# tensor(51245.4414, grad_fn=<AddBackward0>)
# tensor(51179.4492, grad_fn=<AddBackward0>)
# Epoch: 0778 train_loss= 0.06226 val_loss= 0.06226
# tensor(51179.4492, grad_fn=<AddBackward0>)
# tensor(51112.1797, grad_fn=<AddBackward0>)
# Epoch: 0779 train_loss= 0.06251 val_loss= 0.06193
# tensor(51112.1797, grad_fn=<AddBackward0>)
# tensor(51046.2891, grad_fn=<AddBackward0>)
# Epoch: 0780 train_loss= 0.06219 val_loss= 0.06270
# tensor(51046.2891, grad_fn=<AddBackward0>)
# tensor(50981.2812, grad_fn=<AddBackward0>)
# Epoch: 0781 train_loss= 0.06234 val_loss= 0.06155
# tensor(50981.2812, grad_fn=<AddBackward0>)
# tensor(50915.3398, grad_fn=<AddBackward0>)
# Epoch: 0782 train_loss= 0.06202 val_loss= 0.06238
# tensor(50915.3398, grad_fn=<AddBackward0>)
# tensor(50843.9180, grad_fn=<AddBackward0>)
# Epoch: 0783 train_loss= 0.06197 val_loss= 0.06220
# tensor(50843.9180, grad_fn=<AddBackward0>)
# tensor(50771.1523, grad_fn=<AddBackward0>)
# Epoch: 0784 train_loss= 0.06218 val_loss= 0.06191
# tensor(50771.1523, grad_fn=<AddBackward0>)
# tensor(50703.7578, grad_fn=<AddBackward0>)
# Epoch: 0785 train_loss= 0.06199 val_loss= 0.06138
# tensor(50703.7578, grad_fn=<AddBackward0>)
# tensor(50641.3984, grad_fn=<AddBackward0>)
# Epoch: 0786 train_loss= 0.06197 val_loss= 0.06195
# tensor(50641.3984, grad_fn=<AddBackward0>)
# tensor(50581.8125, grad_fn=<AddBackward0>)
# Epoch: 0787 train_loss= 0.06189 val_loss= 0.06267
# tensor(50581.8125, grad_fn=<AddBackward0>)
# tensor(50524.1875, grad_fn=<AddBackward0>)
# Epoch: 0788 train_loss= 0.06236 val_loss= 0.06136
# tensor(50524.1875, grad_fn=<AddBackward0>)
# tensor(50465.7031, grad_fn=<AddBackward0>)
# Epoch: 0789 train_loss= 0.06114 val_loss= 0.06194
# tensor(50465.7031, grad_fn=<AddBackward0>)
# tensor(50409.2578, grad_fn=<AddBackward0>)
# Epoch: 0790 train_loss= 0.06176 val_loss= 0.06170
# tensor(50409.2578, grad_fn=<AddBackward0>)
# tensor(50352.7422, grad_fn=<AddBackward0>)
# Epoch: 0791 train_loss= 0.06178 val_loss= 0.06270
# tensor(50352.7422, grad_fn=<AddBackward0>)
# tensor(50299.3516, grad_fn=<AddBackward0>)
# Epoch: 0792 train_loss= 0.06112 val_loss= 0.06256
# tensor(50299.3516, grad_fn=<AddBackward0>)
# tensor(50242.7109, grad_fn=<AddBackward0>)
# Epoch: 0793 train_loss= 0.06176 val_loss= 0.06163
# tensor(50242.7109, grad_fn=<AddBackward0>)
# tensor(50185.5156, grad_fn=<AddBackward0>)
# Epoch: 0794 train_loss= 0.06114 val_loss= 0.06159
# tensor(50185.5156, grad_fn=<AddBackward0>)
# tensor(50128.0664, grad_fn=<AddBackward0>)
# Epoch: 0795 train_loss= 0.06133 val_loss= 0.06171
# tensor(50128.0664, grad_fn=<AddBackward0>)
# tensor(50072.1875, grad_fn=<AddBackward0>)
# Epoch: 0796 train_loss= 0.06129 val_loss= 0.06144
# tensor(50072.1875, grad_fn=<AddBackward0>)
# tensor(50020.5859, grad_fn=<AddBackward0>)
# Epoch: 0797 train_loss= 0.06110 val_loss= 0.06174
# tensor(50020.5859, grad_fn=<AddBackward0>)
# tensor(49968.3047, grad_fn=<AddBackward0>)
# Epoch: 0798 train_loss= 0.06132 val_loss= 0.06136
# tensor(49968.3047, grad_fn=<AddBackward0>)
# tensor(49918.6055, grad_fn=<AddBackward0>)
# Epoch: 0799 train_loss= 0.06118 val_loss= 0.06124
# tensor(49918.6055, grad_fn=<AddBackward0>)
# tensor(49866.4102, grad_fn=<AddBackward0>)
# Epoch: 0800 train_loss= 0.06127 val_loss= 0.06075
# tensor(49866.4102, grad_fn=<AddBackward0>)
# tensor(49811.0781, grad_fn=<AddBackward0>)
# Epoch: 0801 train_loss= 0.06104 val_loss= 0.06027
# tensor(49811.0781, grad_fn=<AddBackward0>)
# tensor(49759.2344, grad_fn=<AddBackward0>)
# Epoch: 0802 train_loss= 0.06102 val_loss= 0.06114
# tensor(49759.2344, grad_fn=<AddBackward0>)
# tensor(49706.4922, grad_fn=<AddBackward0>)
# Epoch: 0803 train_loss= 0.06118 val_loss= 0.06081
# tensor(49706.4922, grad_fn=<AddBackward0>)
# tensor(49653.8047, grad_fn=<AddBackward0>)
# Epoch: 0804 train_loss= 0.06071 val_loss= 0.06137
# tensor(49653.8047, grad_fn=<AddBackward0>)
# tensor(49600.3594, grad_fn=<AddBackward0>)
# Epoch: 0805 train_loss= 0.06075 val_loss= 0.06023
# tensor(49600.3594, grad_fn=<AddBackward0>)
# tensor(49544.8281, grad_fn=<AddBackward0>)
# Epoch: 0806 train_loss= 0.06047 val_loss= 0.06080
# tensor(49544.8281, grad_fn=<AddBackward0>)
# tensor(49491.1914, grad_fn=<AddBackward0>)
# Epoch: 0807 train_loss= 0.06046 val_loss= 0.06111
# tensor(49491.1914, grad_fn=<AddBackward0>)
# tensor(49435.9688, grad_fn=<AddBackward0>)
# Epoch: 0808 train_loss= 0.06031 val_loss= 0.06027
# tensor(49435.9688, grad_fn=<AddBackward0>)
# tensor(49377.8555, grad_fn=<AddBackward0>)
# Epoch: 0809 train_loss= 0.06046 val_loss= 0.06099
# tensor(49377.8555, grad_fn=<AddBackward0>)
# tensor(49319.3203, grad_fn=<AddBackward0>)
# Epoch: 0810 train_loss= 0.06019 val_loss= 0.06052
# tensor(49319.3203, grad_fn=<AddBackward0>)
# tensor(49259.4844, grad_fn=<AddBackward0>)
# Epoch: 0811 train_loss= 0.06027 val_loss= 0.06017
# tensor(49259.4844, grad_fn=<AddBackward0>)
# tensor(49195.5469, grad_fn=<AddBackward0>)
# Epoch: 0812 train_loss= 0.06011 val_loss= 0.06026
# tensor(49195.5469, grad_fn=<AddBackward0>)
# tensor(49129.1836, grad_fn=<AddBackward0>)
# Epoch: 0813 train_loss= 0.06003 val_loss= 0.06062
# tensor(49129.1836, grad_fn=<AddBackward0>)
# tensor(49063.4688, grad_fn=<AddBackward0>)
# Epoch: 0814 train_loss= 0.05988 val_loss= 0.05988
# tensor(49063.4688, grad_fn=<AddBackward0>)
# tensor(48995.8516, grad_fn=<AddBackward0>)
# Epoch: 0815 train_loss= 0.06031 val_loss= 0.05984
# tensor(48995.8516, grad_fn=<AddBackward0>)
# tensor(48930.3867, grad_fn=<AddBackward0>)
# Epoch: 0816 train_loss= 0.05966 val_loss= 0.06002
# tensor(48930.3867, grad_fn=<AddBackward0>)
# tensor(48865.5938, grad_fn=<AddBackward0>)
# Epoch: 0817 train_loss= 0.05971 val_loss= 0.05987
# tensor(48865.5938, grad_fn=<AddBackward0>)
# tensor(48798.6367, grad_fn=<AddBackward0>)
# Epoch: 0818 train_loss= 0.05957 val_loss= 0.06052
# tensor(48798.6367, grad_fn=<AddBackward0>)
# tensor(48730.5781, grad_fn=<AddBackward0>)
# Epoch: 0819 train_loss= 0.05956 val_loss= 0.06019
# tensor(48730.5781, grad_fn=<AddBackward0>)
# tensor(48666.1562, grad_fn=<AddBackward0>)
# Epoch: 0820 train_loss= 0.05966 val_loss= 0.05975
# tensor(48666.1562, grad_fn=<AddBackward0>)
# tensor(48603.4297, grad_fn=<AddBackward0>)
# Epoch: 0821 train_loss= 0.05957 val_loss= 0.05944
# tensor(48603.4297, grad_fn=<AddBackward0>)
# tensor(48540.3359, grad_fn=<AddBackward0>)
# Epoch: 0822 train_loss= 0.05941 val_loss= 0.05999
# tensor(48540.3359, grad_fn=<AddBackward0>)
# tensor(48476.1562, grad_fn=<AddBackward0>)
# Epoch: 0823 train_loss= 0.05952 val_loss= 0.05939
# tensor(48476.1562, grad_fn=<AddBackward0>)
# tensor(48411.3398, grad_fn=<AddBackward0>)
# Epoch: 0824 train_loss= 0.05940 val_loss= 0.05978
# tensor(48411.3398, grad_fn=<AddBackward0>)
# tensor(48346.6094, grad_fn=<AddBackward0>)
# Epoch: 0825 train_loss= 0.05913 val_loss= 0.05895
# tensor(48346.6094, grad_fn=<AddBackward0>)
# tensor(48284.9531, grad_fn=<AddBackward0>)
# Epoch: 0826 train_loss= 0.05943 val_loss= 0.05908
# tensor(48284.9531, grad_fn=<AddBackward0>)
# tensor(48228.2188, grad_fn=<AddBackward0>)
# Epoch: 0827 train_loss= 0.05945 val_loss= 0.05944
# tensor(48228.2188, grad_fn=<AddBackward0>)
# tensor(48169.7109, grad_fn=<AddBackward0>)
# Epoch: 0828 train_loss= 0.05902 val_loss= 0.05934
# tensor(48169.7109, grad_fn=<AddBackward0>)
# tensor(48109.5078, grad_fn=<AddBackward0>)
# Epoch: 0829 train_loss= 0.05911 val_loss= 0.05945
# tensor(48109.5078, grad_fn=<AddBackward0>)
# tensor(48049.7148, grad_fn=<AddBackward0>)
# Epoch: 0830 train_loss= 0.05892 val_loss= 0.05942
# tensor(48049.7148, grad_fn=<AddBackward0>)
# tensor(47992.3984, grad_fn=<AddBackward0>)
# Epoch: 0831 train_loss= 0.05853 val_loss= 0.05915
# tensor(47992.3984, grad_fn=<AddBackward0>)
# tensor(47933.1406, grad_fn=<AddBackward0>)
# Epoch: 0832 train_loss= 0.05926 val_loss= 0.05931
# tensor(47933.1406, grad_fn=<AddBackward0>)
# tensor(47875.6055, grad_fn=<AddBackward0>)
# Epoch: 0833 train_loss= 0.05922 val_loss= 0.05891
# tensor(47875.6055, grad_fn=<AddBackward0>)
# tensor(47821.0430, grad_fn=<AddBackward0>)
# Epoch: 0834 train_loss= 0.05871 val_loss= 0.05962
# tensor(47821.0430, grad_fn=<AddBackward0>)
# tensor(47768.8906, grad_fn=<AddBackward0>)
# Epoch: 0835 train_loss= 0.05895 val_loss= 0.05871
# tensor(47768.8906, grad_fn=<AddBackward0>)
# tensor(47721.8203, grad_fn=<AddBackward0>)
# Epoch: 0836 train_loss= 0.05867 val_loss= 0.05841
# tensor(47721.8203, grad_fn=<AddBackward0>)
# tensor(47673.7500, grad_fn=<AddBackward0>)
# Epoch: 0837 train_loss= 0.05880 val_loss= 0.05851
# tensor(47673.7500, grad_fn=<AddBackward0>)
# tensor(47628.9297, grad_fn=<AddBackward0>)
# Epoch: 0838 train_loss= 0.05884 val_loss= 0.05890
# tensor(47628.9297, grad_fn=<AddBackward0>)
# tensor(47586.8047, grad_fn=<AddBackward0>)
# Epoch: 0839 train_loss= 0.05842 val_loss= 0.05922
# tensor(47586.8047, grad_fn=<AddBackward0>)
# tensor(47542.5234, grad_fn=<AddBackward0>)
# Epoch: 0840 train_loss= 0.05901 val_loss= 0.05839
# tensor(47542.5234, grad_fn=<AddBackward0>)
# tensor(47500.2852, grad_fn=<AddBackward0>)
# Epoch: 0841 train_loss= 0.05839 val_loss= 0.05870
# tensor(47500.2852, grad_fn=<AddBackward0>)
# tensor(47458.7812, grad_fn=<AddBackward0>)
# Epoch: 0842 train_loss= 0.05855 val_loss= 0.05864
# tensor(47458.7812, grad_fn=<AddBackward0>)
# tensor(47415.2578, grad_fn=<AddBackward0>)
# Epoch: 0843 train_loss= 0.05850 val_loss= 0.05834
# tensor(47415.2578, grad_fn=<AddBackward0>)
# tensor(47372.6250, grad_fn=<AddBackward0>)
# Epoch: 0844 train_loss= 0.05798 val_loss= 0.05902
# tensor(47372.6250, grad_fn=<AddBackward0>)
# tensor(47332.9922, grad_fn=<AddBackward0>)
# Epoch: 0845 train_loss= 0.05857 val_loss= 0.05871
# tensor(47332.9922, grad_fn=<AddBackward0>)
# tensor(47290.7500, grad_fn=<AddBackward0>)
# Epoch: 0846 train_loss= 0.05791 val_loss= 0.05873
# tensor(47290.7500, grad_fn=<AddBackward0>)
# tensor(47245.0469, grad_fn=<AddBackward0>)
# Epoch: 0847 train_loss= 0.05822 val_loss= 0.05824
# tensor(47245.0469, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9c797013058b> in <module>()
#       6
#       7     train_loss = my_model.forward(train_features_tensor)
# ----> 8     my_model.backward()
#       9     val_loss = my_model.forward(val_features_tensor)
#      10     my_model.optimizer.zero_grad()
#
# <ipython-input-2-ead51de5af7e> in backward(self)
#      74         self.optimizer.zero_grad()
#      75         self.loss.backward()
# ---> 76         self.optimizer.step()
#      77
#      78
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#     105                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#     106
# --> 107                 p.data.addcdiv_(-step_size, exp_avg, denom)
#     108
#     109         return loss
#
# KeyboardInterrupt:

# %%
my_model.forward(train_features_tensor)
my_model.drouput1.eval()
my_model.drouput2.eval()

#my_model.drouput1.train()
#my_model.drouput2.train()

print(my_model.forward(train_features_tensor))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(47202.7383, grad_fn=<AddBackward0>)
# tensor(47202.7383, grad_fn=<AddBackward0>)
# 0.05017867311835289

# %%
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
np.savetxt("/content/drive/My Drive/Data Fusion/results/emb_v13_dropout_0.5_0.3_l1.txt",emb,delimiter='\t')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(47202.7383, grad_fn=<AddBackward0>)

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
emb = np.loadtxt("/content/drive/My Drive/Data Fusion/results/emb_v11.txt",delimiter='\t')
# Out:
# [1, 1, 1, 1, 1]

# %%
####PCA on embedding
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
circle_areas = (truelabel[:,1].astype(float)/8)
X_embedded = PCA(n_components=2).fit_transform(emb)
plt.scatter(x=X_embedded[:,0], y=X_embedded[:,1], s=circle_areas, c= 1*np.ones(215), alpha=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(47202.7383, grad_fn=<AddBackward0>)

# %%
### TSNE on embedding
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
circle_areas = (truelabel[:,1].astype(float)/8)
X_embedded = TSNE(n_components=2).fit_transform(emb)
plt.scatter(x=X_embedded[:,0], y=X_embedded[:,1], s=circle_areas, c= 1*np.ones(215), alpha=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(47202.7383, grad_fn=<AddBackward0>)

# %%
from sklearn.cluster import KMeans
X = emb
n_clusters=3
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X)

for i in range(n_clusters):
    indx = np.argwhere(kmeans.labels_==i).reshape(-1)
    print(truelabel[indx][:,1].mean())
# Out:
# 626.8765432098766
# 536.3030303030303
# 573.3168316831683

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
emb = np.loadtxt("/content/drive/My Drive/Data Fusion/results/emb_v11.txt",delimiter='\t')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#print(list(my_model.W0.parameters()))
print(torch.norm(list(my_model.W0.parameters())[0],1))
#l1_regularization += torch.norm(param, 1)
#torch.norm()
# Out:
# tensor(220043., grad_fn=<NormBackward0>)
