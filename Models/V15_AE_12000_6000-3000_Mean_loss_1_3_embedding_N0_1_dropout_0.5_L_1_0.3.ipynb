# %%
## This Cell is related to date preprocessing and is completely copied from original kipf's github code!

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.sparse as sp
import torch,torch.nn,torch.sparse,torch.nn.functional,torch.distributions
from sklearn.metrics import roc_auc_score,average_precision_score
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
np.set_printoptions(threshold=np.inf)


from google.colab import drive
drive.mount('/content/drive')


W_gene      =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/gene.txt", delim_whitespace=True).to_numpy()
W_methy     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/methy.txt", delim_whitespace=True).to_numpy()
W_mirna     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM_Adjacency_matrices/mirna.txt", delim_whitespace=True).to_numpy()

gene      =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Gene_Expression.txt", delim_whitespace=True).to_numpy().transpose()
methy     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Methy_Expression.txt", delim_whitespace=True).to_numpy().transpose()
mirna     =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Mirna_Expression.txt", delim_whitespace=True).to_numpy().transpose()
truelabel =  pd.read_table( "/content/drive/My Drive/Data Fusion/GBM/GLIO_Survival.txt", delim_whitespace=True).to_numpy()



print(gene.shape)
print(methy.shape)
print(mirna.shape)

def get_nomralized_laplacian(a):
    b = np.diag(np.power(1.0 / a.sum(axis=1), 0.5))
    return (b @ a @ b)





features = np.c_[mirna,methy,gene]

patient_no = features.shape[0]

idx = np.arange(patient_no)
np.random.shuffle(idx)
train_idx = idx[0:int(patient_no * 0.75)]
val_idx =   idx[int(patient_no * 0.75):]

train_features = features[train_idx]
train_features = features
val_features   = features[val_idx]
print(train_features.shape)
print(val_features.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
# (215, 12042)
# (215, 1305)
# (215, 534)
# (215, 13881)
# (54, 13881)

# %%
#Model definition Cell

num_features = features.shape[1]

train_features_tensor  = torch.Tensor(train_features)
val_features_tensor    = torch.Tensor(val_features)





class Model(torch.nn.Module):

    def __init__(self,**kwargs):
        super(Model, self).__init__(**kwargs)
        
        
        
            

        self.W0 = torch.nn.Linear(num_features,6000)
        self.W1 = torch.nn.Linear(6000,3000)
        self.W2 = torch.nn.Linear(3000,6000)
        self.W3 = torch.nn.Linear(6000,num_features)

        self.drouput1 = torch.nn.Dropout(p=0.5)
        self.drouput2 = torch.nn.Dropout(p=0.5)
        
        param_list = []
        param_list += list(self.W0.parameters())
        param_list += list(self.W1.parameters())
        param_list += list(self.W2.parameters())
        param_list += list(self.W3.parameters())
        
        

        self.optimizer = torch.optim.Adam(param_list,lr=0.0001)
        self.recon = None
        
        self.normal_dist = torch.distributions.MultivariateNormal(loc=torch.zeros(3000),scale_tril=torch.eye(3000))

        
        
        
    


        
    def forward(self,x) : 
        self.layer_1 = torch.nn.functional.tanh(self.W0(self.drouput1(x)))
        self.layer_2 = torch.nn.functional.tanh(self.W1(self.drouput2(self.layer_1)))
        self.layer_3 = torch.nn.functional.tanh(self.W2(self.layer_2+self.normal_dist.sample((x.shape[0],))))
        self.layer_4 = self.W3(self.layer_3)
        
        

        self.x_prim = self.layer_4
        self.embedding = self.layer_2
        
        self.recon_loss = ((self.x_prim-x)**2).mean(0)
        self.recon_loss = self.recon_loss[0:534].mean()+self.recon_loss[534:534+1305].mean()+self.recon_loss[534+1305:534+1305+12042].mean()
        self.recon_loss = self.recon_loss/3
       
        self.l1_regularization =  (torch.norm(list(self.W0.parameters())[0],1))+(torch.norm(list(self.W1.parameters())[0],1))

        print(self.l1_regularization)
        self.loss = self.recon_loss+self.l1_regularization/1000000
       
        
        
        
        
        
        return self.loss.item()
        
    def backward(self) :
        
        self.optimizer.zero_grad()
        self.loss.backward()
        self.optimizer.step()

        
        
    def get_cosine_sim_emb(self):
        
        emb = self.embedding.detach().numpy()

        norms =  (emb*emb).sum(1).reshape(-1,1)**0.5
        normalized_emb = emb/norms

        emb_matrix = np.abs( normalized_emb@normalized_emb.transpose())
        return emb_matrix
        

    def get_euclidian(self):
        emb = self.embedding.detach().numpy()
        
        emb_matrix = np.zeros((emb.shape[0],emb.shape[0]))
        
        for i in range(emb.shape[0]):
            for j in range(emb.shape[0]):
                emb_matrix[i,j] = ((emb[i]-emb[j])**2).sum()
                
        return emb_matrix

# %%
#Training Cell 

my_model = Model()


for epoch_counter in range(20000):
    
    train_loss = my_model.forward(train_features_tensor)
    my_model.backward()
    val_loss = my_model.forward(val_features_tensor)
    my_model.optimizer.zero_grad()
    #val_loss = 0

    if epoch_counter % 1 ==0:
        print("Epoch:", '%04d' % (epoch_counter + 1), "train_loss=", "{:.5f}".format(train_loss), "val_loss=", "{:.5f}".format(val_loss))


print('\n',"#########################################################",'\n')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(404075.3750, grad_fn=<AddBackward0>)
# tensor(403281.3125, grad_fn=<AddBackward0>)
# Epoch: 0001 train_loss= 1.47777 val_loss= 1.45166
# tensor(403281.3125, grad_fn=<AddBackward0>)
# tensor(402438.5625, grad_fn=<AddBackward0>)
# Epoch: 0002 train_loss= 1.45101 val_loss= 1.42216
# tensor(402438.5625, grad_fn=<AddBackward0>)
# tensor(401610.3750, grad_fn=<AddBackward0>)
# Epoch: 0003 train_loss= 1.42182 val_loss= 1.38424
# tensor(401610.3750, grad_fn=<AddBackward0>)
# tensor(400778.4375, grad_fn=<AddBackward0>)
# Epoch: 0004 train_loss= 1.38571 val_loss= 1.34460
# tensor(400778.4375, grad_fn=<AddBackward0>)
# tensor(399934.2500, grad_fn=<AddBackward0>)
# Epoch: 0005 train_loss= 1.34713 val_loss= 1.30751
# tensor(399934.2500, grad_fn=<AddBackward0>)
# tensor(399058.8438, grad_fn=<AddBackward0>)
# Epoch: 0006 train_loss= 1.31083 val_loss= 1.27717
# tensor(399058.8438, grad_fn=<AddBackward0>)
# tensor(398191.6875, grad_fn=<AddBackward0>)
# Epoch: 0007 train_loss= 1.28102 val_loss= 1.24578
# tensor(398191.6875, grad_fn=<AddBackward0>)
# tensor(397369.3125, grad_fn=<AddBackward0>)
# Epoch: 0008 train_loss= 1.25134 val_loss= 1.22117
# tensor(397369.3125, grad_fn=<AddBackward0>)
# tensor(396680.9375, grad_fn=<AddBackward0>)
# Epoch: 0009 train_loss= 1.22939 val_loss= 1.19629
# tensor(396680.9375, grad_fn=<AddBackward0>)
# tensor(396064.8750, grad_fn=<AddBackward0>)
# Epoch: 0010 train_loss= 1.20615 val_loss= 1.17662
# tensor(396064.8750, grad_fn=<AddBackward0>)
# tensor(395483.0625, grad_fn=<AddBackward0>)
# Epoch: 0011 train_loss= 1.18639 val_loss= 1.15919
# tensor(395483.0625, grad_fn=<AddBackward0>)
# tensor(394933.1875, grad_fn=<AddBackward0>)
# Epoch: 0012 train_loss= 1.16680 val_loss= 1.13958
# tensor(394933.1875, grad_fn=<AddBackward0>)
# tensor(394403.7812, grad_fn=<AddBackward0>)
# Epoch: 0013 train_loss= 1.14608 val_loss= 1.12324
# tensor(394403.7812, grad_fn=<AddBackward0>)
# tensor(393887.3125, grad_fn=<AddBackward0>)
# Epoch: 0014 train_loss= 1.12785 val_loss= 1.10497
# tensor(393887.3125, grad_fn=<AddBackward0>)
# tensor(393391.1875, grad_fn=<AddBackward0>)
# Epoch: 0015 train_loss= 1.11104 val_loss= 1.09302
# tensor(393391.1875, grad_fn=<AddBackward0>)
# tensor(392901.6250, grad_fn=<AddBackward0>)
# Epoch: 0016 train_loss= 1.09739 val_loss= 1.07928
# tensor(392901.6250, grad_fn=<AddBackward0>)
# tensor(392411.0312, grad_fn=<AddBackward0>)
# Epoch: 0017 train_loss= 1.08427 val_loss= 1.06632
# tensor(392411.0312, grad_fn=<AddBackward0>)
# tensor(391933.9375, grad_fn=<AddBackward0>)
# Epoch: 0018 train_loss= 1.07140 val_loss= 1.05030
# tensor(391933.9375, grad_fn=<AddBackward0>)
# tensor(391473.4375, grad_fn=<AddBackward0>)
# Epoch: 0019 train_loss= 1.05860 val_loss= 1.04321
# tensor(391473.4375, grad_fn=<AddBackward0>)
# tensor(391008.6875, grad_fn=<AddBackward0>)
# Epoch: 0020 train_loss= 1.04655 val_loss= 1.03107
# tensor(391008.6875, grad_fn=<AddBackward0>)
# tensor(390560.6875, grad_fn=<AddBackward0>)
# Epoch: 0021 train_loss= 1.03470 val_loss= 1.01920
# tensor(390560.6875, grad_fn=<AddBackward0>)
# tensor(390120.1875, grad_fn=<AddBackward0>)
# Epoch: 0022 train_loss= 1.02365 val_loss= 1.01070
# tensor(390120.1875, grad_fn=<AddBackward0>)
# tensor(389673.5938, grad_fn=<AddBackward0>)
# Epoch: 0023 train_loss= 1.01291 val_loss= 0.99808
# tensor(389673.5938, grad_fn=<AddBackward0>)
# tensor(389234.0625, grad_fn=<AddBackward0>)
# Epoch: 0024 train_loss= 1.00446 val_loss= 0.98838
# tensor(389234.0625, grad_fn=<AddBackward0>)
# tensor(388794., grad_fn=<AddBackward0>)
# Epoch: 0025 train_loss= 0.99425 val_loss= 0.97910
# tensor(388794., grad_fn=<AddBackward0>)
# tensor(388365.9688, grad_fn=<AddBackward0>)
# Epoch: 0026 train_loss= 0.98672 val_loss= 0.96988
# tensor(388365.9688, grad_fn=<AddBackward0>)
# tensor(387935.9688, grad_fn=<AddBackward0>)
# Epoch: 0027 train_loss= 0.97617 val_loss= 0.96527
# tensor(387935.9688, grad_fn=<AddBackward0>)
# tensor(387515.2500, grad_fn=<AddBackward0>)
# Epoch: 0028 train_loss= 0.96784 val_loss= 0.95537
# tensor(387515.2500, grad_fn=<AddBackward0>)
# tensor(387095.1875, grad_fn=<AddBackward0>)
# Epoch: 0029 train_loss= 0.96005 val_loss= 0.94746
# tensor(387095.1875, grad_fn=<AddBackward0>)
# tensor(386678.7500, grad_fn=<AddBackward0>)
# Epoch: 0030 train_loss= 0.95191 val_loss= 0.94352
# tensor(386678.7500, grad_fn=<AddBackward0>)
# tensor(386278.6875, grad_fn=<AddBackward0>)
# Epoch: 0031 train_loss= 0.94496 val_loss= 0.93118
# tensor(386278.6875, grad_fn=<AddBackward0>)
# tensor(385871.7500, grad_fn=<AddBackward0>)
# Epoch: 0032 train_loss= 0.93764 val_loss= 0.92558
# tensor(385871.7500, grad_fn=<AddBackward0>)
# tensor(385463.7500, grad_fn=<AddBackward0>)
# Epoch: 0033 train_loss= 0.93015 val_loss= 0.91853
# tensor(385463.7500, grad_fn=<AddBackward0>)
# tensor(385064.5000, grad_fn=<AddBackward0>)
# Epoch: 0034 train_loss= 0.92210 val_loss= 0.91345
# tensor(385064.5000, grad_fn=<AddBackward0>)
# tensor(384676.2188, grad_fn=<AddBackward0>)
# Epoch: 0035 train_loss= 0.91479 val_loss= 0.90673
# tensor(384676.2188, grad_fn=<AddBackward0>)
# tensor(384286.9375, grad_fn=<AddBackward0>)
# Epoch: 0036 train_loss= 0.90669 val_loss= 0.89918
# tensor(384286.9375, grad_fn=<AddBackward0>)
# tensor(383902.1250, grad_fn=<AddBackward0>)
# Epoch: 0037 train_loss= 0.90164 val_loss= 0.88933
# tensor(383902.1250, grad_fn=<AddBackward0>)
# tensor(383504., grad_fn=<AddBackward0>)
# Epoch: 0038 train_loss= 0.89428 val_loss= 0.88743
# tensor(383504., grad_fn=<AddBackward0>)
# tensor(383120.0312, grad_fn=<AddBackward0>)
# Epoch: 0039 train_loss= 0.88933 val_loss= 0.88029
# tensor(383120.0312, grad_fn=<AddBackward0>)
# tensor(382730.3125, grad_fn=<AddBackward0>)
# Epoch: 0040 train_loss= 0.88262 val_loss= 0.87594
# tensor(382730.3125, grad_fn=<AddBackward0>)
# tensor(382357.9375, grad_fn=<AddBackward0>)
# Epoch: 0041 train_loss= 0.87627 val_loss= 0.86819
# tensor(382357.9375, grad_fn=<AddBackward0>)
# tensor(381987.6875, grad_fn=<AddBackward0>)
# Epoch: 0042 train_loss= 0.87149 val_loss= 0.86503
# tensor(381987.6875, grad_fn=<AddBackward0>)
# tensor(381621.5312, grad_fn=<AddBackward0>)
# Epoch: 0043 train_loss= 0.86678 val_loss= 0.85771
# tensor(381621.5312, grad_fn=<AddBackward0>)
# tensor(381256.4062, grad_fn=<AddBackward0>)
# Epoch: 0044 train_loss= 0.86050 val_loss= 0.85174
# tensor(381256.4062, grad_fn=<AddBackward0>)
# tensor(380892.8125, grad_fn=<AddBackward0>)
# Epoch: 0045 train_loss= 0.85550 val_loss= 0.84660
# tensor(380892.8125, grad_fn=<AddBackward0>)
# tensor(380534.2500, grad_fn=<AddBackward0>)
# Epoch: 0046 train_loss= 0.84963 val_loss= 0.84470
# tensor(380534.2500, grad_fn=<AddBackward0>)
# tensor(380173.8750, grad_fn=<AddBackward0>)
# Epoch: 0047 train_loss= 0.84411 val_loss= 0.83841
# tensor(380173.8750, grad_fn=<AddBackward0>)
# tensor(379819.4688, grad_fn=<AddBackward0>)
# Epoch: 0048 train_loss= 0.84043 val_loss= 0.83287
# tensor(379819.4688, grad_fn=<AddBackward0>)
# tensor(379460.2812, grad_fn=<AddBackward0>)
# Epoch: 0049 train_loss= 0.83462 val_loss= 0.82888
# tensor(379460.2812, grad_fn=<AddBackward0>)
# tensor(379110.7500, grad_fn=<AddBackward0>)
# Epoch: 0050 train_loss= 0.82926 val_loss= 0.82554
# tensor(379110.7500, grad_fn=<AddBackward0>)
# tensor(378770.0938, grad_fn=<AddBackward0>)
# Epoch: 0051 train_loss= 0.82605 val_loss= 0.82064
# tensor(378770.0938, grad_fn=<AddBackward0>)
# tensor(378420.9062, grad_fn=<AddBackward0>)
# Epoch: 0052 train_loss= 0.82160 val_loss= 0.81315
# tensor(378420.9062, grad_fn=<AddBackward0>)
# tensor(378074.6250, grad_fn=<AddBackward0>)
# Epoch: 0053 train_loss= 0.81573 val_loss= 0.81158
# tensor(378074.6250, grad_fn=<AddBackward0>)
# tensor(377729.9688, grad_fn=<AddBackward0>)
# Epoch: 0054 train_loss= 0.81170 val_loss= 0.80686
# tensor(377729.9688, grad_fn=<AddBackward0>)
# tensor(377394.1875, grad_fn=<AddBackward0>)
# Epoch: 0055 train_loss= 0.80768 val_loss= 0.80086
# tensor(377394.1875, grad_fn=<AddBackward0>)
# tensor(377057.7188, grad_fn=<AddBackward0>)
# Epoch: 0056 train_loss= 0.80178 val_loss= 0.79842
# tensor(377057.7188, grad_fn=<AddBackward0>)
# tensor(376717.7812, grad_fn=<AddBackward0>)
# Epoch: 0057 train_loss= 0.79864 val_loss= 0.79579
# tensor(376717.7812, grad_fn=<AddBackward0>)
# tensor(376384.5625, grad_fn=<AddBackward0>)
# Epoch: 0058 train_loss= 0.79355 val_loss= 0.79113
# tensor(376384.5625, grad_fn=<AddBackward0>)
# tensor(376057.2500, grad_fn=<AddBackward0>)
# Epoch: 0059 train_loss= 0.79087 val_loss= 0.78389
# tensor(376057.2500, grad_fn=<AddBackward0>)
# tensor(375723.0625, grad_fn=<AddBackward0>)
# Epoch: 0060 train_loss= 0.78799 val_loss= 0.77998
# tensor(375723.0625, grad_fn=<AddBackward0>)
# tensor(375393.3438, grad_fn=<AddBackward0>)
# Epoch: 0061 train_loss= 0.78353 val_loss= 0.77886
# tensor(375393.3438, grad_fn=<AddBackward0>)
# tensor(375080.8438, grad_fn=<AddBackward0>)
# Epoch: 0062 train_loss= 0.78057 val_loss= 0.77075
# tensor(375080.8438, grad_fn=<AddBackward0>)
# tensor(374756.8750, grad_fn=<AddBackward0>)
# Epoch: 0063 train_loss= 0.77643 val_loss= 0.76935
# tensor(374756.8750, grad_fn=<AddBackward0>)
# tensor(374437.8750, grad_fn=<AddBackward0>)
# Epoch: 0064 train_loss= 0.77193 val_loss= 0.76732
# tensor(374437.8750, grad_fn=<AddBackward0>)
# tensor(374128.1562, grad_fn=<AddBackward0>)
# Epoch: 0065 train_loss= 0.76823 val_loss= 0.76288
# tensor(374128.1562, grad_fn=<AddBackward0>)
# tensor(373815.4375, grad_fn=<AddBackward0>)
# Epoch: 0066 train_loss= 0.76510 val_loss= 0.75743
# tensor(373815.4375, grad_fn=<AddBackward0>)
# tensor(373510.2188, grad_fn=<AddBackward0>)
# Epoch: 0067 train_loss= 0.76123 val_loss= 0.75596
# tensor(373510.2188, grad_fn=<AddBackward0>)
# tensor(373205.2188, grad_fn=<AddBackward0>)
# Epoch: 0068 train_loss= 0.75773 val_loss= 0.75101
# tensor(373205.2188, grad_fn=<AddBackward0>)
# tensor(372899.5312, grad_fn=<AddBackward0>)
# Epoch: 0069 train_loss= 0.75478 val_loss= 0.74906
# tensor(372899.5312, grad_fn=<AddBackward0>)
# tensor(372600.3750, grad_fn=<AddBackward0>)
# Epoch: 0070 train_loss= 0.74945 val_loss= 0.74536
# tensor(372600.3750, grad_fn=<AddBackward0>)
# tensor(372309.1250, grad_fn=<AddBackward0>)
# Epoch: 0071 train_loss= 0.74604 val_loss= 0.74084
# tensor(372309.1250, grad_fn=<AddBackward0>)
# tensor(372013.0312, grad_fn=<AddBackward0>)
# Epoch: 0072 train_loss= 0.74589 val_loss= 0.73807
# tensor(372013.0312, grad_fn=<AddBackward0>)
# tensor(371724.6250, grad_fn=<AddBackward0>)
# Epoch: 0073 train_loss= 0.73969 val_loss= 0.73181
# tensor(371724.6250, grad_fn=<AddBackward0>)
# tensor(371433.1250, grad_fn=<AddBackward0>)
# Epoch: 0074 train_loss= 0.73745 val_loss= 0.73256
# tensor(371433.1250, grad_fn=<AddBackward0>)
# tensor(371138.9375, grad_fn=<AddBackward0>)
# Epoch: 0075 train_loss= 0.73307 val_loss= 0.72680
# tensor(371138.9375, grad_fn=<AddBackward0>)
# tensor(370848.9688, grad_fn=<AddBackward0>)
# Epoch: 0076 train_loss= 0.73035 val_loss= 0.72512
# tensor(370848.9688, grad_fn=<AddBackward0>)
# tensor(370562.8438, grad_fn=<AddBackward0>)
# Epoch: 0077 train_loss= 0.72687 val_loss= 0.72307
# tensor(370562.8438, grad_fn=<AddBackward0>)
# tensor(370275.9375, grad_fn=<AddBackward0>)
# Epoch: 0078 train_loss= 0.72386 val_loss= 0.71959
# tensor(370275.9375, grad_fn=<AddBackward0>)
# tensor(370001.7500, grad_fn=<AddBackward0>)
# Epoch: 0079 train_loss= 0.72106 val_loss= 0.71333
# tensor(370001.7500, grad_fn=<AddBackward0>)
# tensor(369719.9688, grad_fn=<AddBackward0>)
# Epoch: 0080 train_loss= 0.71683 val_loss= 0.71402
# tensor(369719.9688, grad_fn=<AddBackward0>)
# tensor(369440.1875, grad_fn=<AddBackward0>)
# Epoch: 0081 train_loss= 0.71519 val_loss= 0.70831
# tensor(369440.1875, grad_fn=<AddBackward0>)
# tensor(369161.5000, grad_fn=<AddBackward0>)
# Epoch: 0082 train_loss= 0.71078 val_loss= 0.70583
# tensor(369161.5000, grad_fn=<AddBackward0>)
# tensor(368885.3125, grad_fn=<AddBackward0>)
# Epoch: 0083 train_loss= 0.70622 val_loss= 0.70444
# tensor(368885.3125, grad_fn=<AddBackward0>)
# tensor(368620.5000, grad_fn=<AddBackward0>)
# Epoch: 0084 train_loss= 0.70586 val_loss= 0.69900
# tensor(368620.5000, grad_fn=<AddBackward0>)
# tensor(368351.5000, grad_fn=<AddBackward0>)
# Epoch: 0085 train_loss= 0.70225 val_loss= 0.69828
# tensor(368351.5000, grad_fn=<AddBackward0>)
# tensor(368078.7500, grad_fn=<AddBackward0>)
# Epoch: 0086 train_loss= 0.70072 val_loss= 0.69675
# tensor(368078.7500, grad_fn=<AddBackward0>)
# tensor(367782.4062, grad_fn=<AddBackward0>)
# Epoch: 0087 train_loss= 0.69680 val_loss= 0.69216
# tensor(367782.4062, grad_fn=<AddBackward0>)
# tensor(366763.5000, grad_fn=<AddBackward0>)
# Epoch: 0088 train_loss= 0.69349 val_loss= 0.68752
# tensor(366763.5000, grad_fn=<AddBackward0>)
# tensor(365694.2188, grad_fn=<AddBackward0>)
# Epoch: 0089 train_loss= 0.69085 val_loss= 0.68353
# tensor(365694.2188, grad_fn=<AddBackward0>)
# tensor(364628.9062, grad_fn=<AddBackward0>)
# Epoch: 0090 train_loss= 0.68550 val_loss= 0.68090
# tensor(364628.9062, grad_fn=<AddBackward0>)
# tensor(363567.6875, grad_fn=<AddBackward0>)
# Epoch: 0091 train_loss= 0.68229 val_loss= 0.68005
# tensor(363567.6875, grad_fn=<AddBackward0>)
# tensor(362506.1250, grad_fn=<AddBackward0>)
# Epoch: 0092 train_loss= 0.67998 val_loss= 0.67274
# tensor(362506.1250, grad_fn=<AddBackward0>)
# tensor(361446.6875, grad_fn=<AddBackward0>)
# Epoch: 0093 train_loss= 0.67741 val_loss= 0.67303
# tensor(361446.6875, grad_fn=<AddBackward0>)
# tensor(360389.0938, grad_fn=<AddBackward0>)
# Epoch: 0094 train_loss= 0.67198 val_loss= 0.66837
# tensor(360389.0938, grad_fn=<AddBackward0>)
# tensor(359333.3125, grad_fn=<AddBackward0>)
# Epoch: 0095 train_loss= 0.66881 val_loss= 0.66401
# tensor(359333.3125, grad_fn=<AddBackward0>)
# tensor(358277.4688, grad_fn=<AddBackward0>)
# Epoch: 0096 train_loss= 0.66506 val_loss= 0.65747
# tensor(358277.4688, grad_fn=<AddBackward0>)
# tensor(357223.6875, grad_fn=<AddBackward0>)
# Epoch: 0097 train_loss= 0.66096 val_loss= 0.65655
# tensor(357223.6875, grad_fn=<AddBackward0>)
# tensor(356177.9062, grad_fn=<AddBackward0>)
# Epoch: 0098 train_loss= 0.65723 val_loss= 0.65211
# tensor(356177.9062, grad_fn=<AddBackward0>)
# tensor(355127.4375, grad_fn=<AddBackward0>)
# Epoch: 0099 train_loss= 0.65371 val_loss= 0.65054
# tensor(355127.4375, grad_fn=<AddBackward0>)
# tensor(354083.2500, grad_fn=<AddBackward0>)
# Epoch: 0100 train_loss= 0.65105 val_loss= 0.64751
# tensor(354083.2500, grad_fn=<AddBackward0>)
# tensor(353041.5000, grad_fn=<AddBackward0>)
# Epoch: 0101 train_loss= 0.64992 val_loss= 0.64478
# tensor(353041.5000, grad_fn=<AddBackward0>)
# tensor(351999.7188, grad_fn=<AddBackward0>)
# Epoch: 0102 train_loss= 0.64517 val_loss= 0.64003
# tensor(351999.7188, grad_fn=<AddBackward0>)
# tensor(350964.0625, grad_fn=<AddBackward0>)
# Epoch: 0103 train_loss= 0.64150 val_loss= 0.63873
# tensor(350964.0625, grad_fn=<AddBackward0>)
# tensor(349929.3125, grad_fn=<AddBackward0>)
# Epoch: 0104 train_loss= 0.63651 val_loss= 0.63240
# tensor(349929.3125, grad_fn=<AddBackward0>)
# tensor(348894.0625, grad_fn=<AddBackward0>)
# Epoch: 0105 train_loss= 0.63497 val_loss= 0.63251
# tensor(348894.0625, grad_fn=<AddBackward0>)
# tensor(347854.1562, grad_fn=<AddBackward0>)
# Epoch: 0106 train_loss= 0.63143 val_loss= 0.62848
# tensor(347854.1562, grad_fn=<AddBackward0>)
# tensor(346822.5938, grad_fn=<AddBackward0>)
# Epoch: 0107 train_loss= 0.62843 val_loss= 0.62322
# tensor(346822.5938, grad_fn=<AddBackward0>)
# tensor(345790.0625, grad_fn=<AddBackward0>)
# Epoch: 0108 train_loss= 0.62436 val_loss= 0.61922
# tensor(345790.0625, grad_fn=<AddBackward0>)
# tensor(344760.4375, grad_fn=<AddBackward0>)
# Epoch: 0109 train_loss= 0.62025 val_loss= 0.61836
# tensor(344760.4375, grad_fn=<AddBackward0>)
# tensor(343732.3750, grad_fn=<AddBackward0>)
# Epoch: 0110 train_loss= 0.61735 val_loss= 0.61137
# tensor(343732.3750, grad_fn=<AddBackward0>)
# tensor(342704.7500, grad_fn=<AddBackward0>)
# Epoch: 0111 train_loss= 0.61591 val_loss= 0.61003
# tensor(342704.7500, grad_fn=<AddBackward0>)
# tensor(341681., grad_fn=<AddBackward0>)
# Epoch: 0112 train_loss= 0.61202 val_loss= 0.60832
# tensor(341681., grad_fn=<AddBackward0>)
# tensor(340665.5625, grad_fn=<AddBackward0>)
# Epoch: 0113 train_loss= 0.60734 val_loss= 0.60216
# tensor(340665.5625, grad_fn=<AddBackward0>)
# tensor(339641.6562, grad_fn=<AddBackward0>)
# Epoch: 0114 train_loss= 0.60483 val_loss= 0.60229
# tensor(339641.6562, grad_fn=<AddBackward0>)
# tensor(338631.2188, grad_fn=<AddBackward0>)
# Epoch: 0115 train_loss= 0.60246 val_loss= 0.59600
# tensor(338631.2188, grad_fn=<AddBackward0>)
# tensor(337612.8125, grad_fn=<AddBackward0>)
# Epoch: 0116 train_loss= 0.59904 val_loss= 0.59527
# tensor(337612.8125, grad_fn=<AddBackward0>)
# tensor(336595.6875, grad_fn=<AddBackward0>)
# Epoch: 0117 train_loss= 0.59652 val_loss= 0.59354
# tensor(336595.6875, grad_fn=<AddBackward0>)
# tensor(335580.9688, grad_fn=<AddBackward0>)
# Epoch: 0118 train_loss= 0.59268 val_loss= 0.58859
# tensor(335580.9688, grad_fn=<AddBackward0>)
# tensor(334562.9062, grad_fn=<AddBackward0>)
# Epoch: 0119 train_loss= 0.58949 val_loss= 0.58568
# tensor(334562.9062, grad_fn=<AddBackward0>)
# tensor(333547.2812, grad_fn=<AddBackward0>)
# Epoch: 0120 train_loss= 0.58711 val_loss= 0.57846
# tensor(333547.2812, grad_fn=<AddBackward0>)
# tensor(332541.0312, grad_fn=<AddBackward0>)
# Epoch: 0121 train_loss= 0.58397 val_loss= 0.57675
# tensor(332541.0312, grad_fn=<AddBackward0>)
# tensor(331536.2812, grad_fn=<AddBackward0>)
# Epoch: 0122 train_loss= 0.57935 val_loss= 0.57529
# tensor(331536.2812, grad_fn=<AddBackward0>)
# tensor(330528.2500, grad_fn=<AddBackward0>)
# Epoch: 0123 train_loss= 0.57694 val_loss= 0.57349
# tensor(330528.2500, grad_fn=<AddBackward0>)
# tensor(329524.0625, grad_fn=<AddBackward0>)
# Epoch: 0124 train_loss= 0.57362 val_loss= 0.56872
# tensor(329524.0625, grad_fn=<AddBackward0>)
# tensor(328520.8125, grad_fn=<AddBackward0>)
# Epoch: 0125 train_loss= 0.57190 val_loss= 0.56697
# tensor(328520.8125, grad_fn=<AddBackward0>)
# tensor(327521.3125, grad_fn=<AddBackward0>)
# Epoch: 0126 train_loss= 0.57006 val_loss= 0.56610
# tensor(327521.3125, grad_fn=<AddBackward0>)
# tensor(326521.2500, grad_fn=<AddBackward0>)
# Epoch: 0127 train_loss= 0.56523 val_loss= 0.56013
# tensor(326521.2500, grad_fn=<AddBackward0>)
# tensor(325528.4688, grad_fn=<AddBackward0>)
# Epoch: 0128 train_loss= 0.56326 val_loss= 0.55829
# tensor(325528.4688, grad_fn=<AddBackward0>)
# tensor(324532.3125, grad_fn=<AddBackward0>)
# Epoch: 0129 train_loss= 0.56001 val_loss= 0.55571
# tensor(324532.3125, grad_fn=<AddBackward0>)
# tensor(323544.6875, grad_fn=<AddBackward0>)
# Epoch: 0130 train_loss= 0.55680 val_loss= 0.55226
# tensor(323544.6875, grad_fn=<AddBackward0>)
# tensor(322554.0312, grad_fn=<AddBackward0>)
# Epoch: 0131 train_loss= 0.55396 val_loss= 0.55250
# tensor(322554.0312, grad_fn=<AddBackward0>)
# tensor(321567.5000, grad_fn=<AddBackward0>)
# Epoch: 0132 train_loss= 0.54952 val_loss= 0.54695
# tensor(321567.5000, grad_fn=<AddBackward0>)
# tensor(320584.3125, grad_fn=<AddBackward0>)
# Epoch: 0133 train_loss= 0.54833 val_loss= 0.54563
# tensor(320584.3125, grad_fn=<AddBackward0>)
# tensor(319594.1250, grad_fn=<AddBackward0>)
# Epoch: 0134 train_loss= 0.54431 val_loss= 0.54091
# tensor(319594.1250, grad_fn=<AddBackward0>)
# tensor(318616.9688, grad_fn=<AddBackward0>)
# Epoch: 0135 train_loss= 0.54297 val_loss= 0.53875
# tensor(318616.9688, grad_fn=<AddBackward0>)
# tensor(317640.1250, grad_fn=<AddBackward0>)
# Epoch: 0136 train_loss= 0.53695 val_loss= 0.53653
# tensor(317640.1250, grad_fn=<AddBackward0>)
# tensor(316655.4688, grad_fn=<AddBackward0>)
# Epoch: 0137 train_loss= 0.53568 val_loss= 0.53439
# tensor(316655.4688, grad_fn=<AddBackward0>)
# tensor(315672.4688, grad_fn=<AddBackward0>)
# Epoch: 0138 train_loss= 0.53387 val_loss= 0.53169
# tensor(315672.4688, grad_fn=<AddBackward0>)
# tensor(314694.8125, grad_fn=<AddBackward0>)
# Epoch: 0139 train_loss= 0.53049 val_loss= 0.52442
# tensor(314694.8125, grad_fn=<AddBackward0>)
# tensor(313719.1875, grad_fn=<AddBackward0>)
# Epoch: 0140 train_loss= 0.52853 val_loss= 0.52141
# tensor(313719.1875, grad_fn=<AddBackward0>)
# tensor(312739.9062, grad_fn=<AddBackward0>)
# Epoch: 0141 train_loss= 0.52514 val_loss= 0.52435
# tensor(312739.9062, grad_fn=<AddBackward0>)
# tensor(311770.9375, grad_fn=<AddBackward0>)
# Epoch: 0142 train_loss= 0.52235 val_loss= 0.51838
# tensor(311770.9375, grad_fn=<AddBackward0>)
# tensor(310802.2812, grad_fn=<AddBackward0>)
# Epoch: 0143 train_loss= 0.52099 val_loss= 0.51488
# tensor(310802.2812, grad_fn=<AddBackward0>)
# tensor(309832.0625, grad_fn=<AddBackward0>)
# Epoch: 0144 train_loss= 0.51727 val_loss= 0.51269
# tensor(309832.0625, grad_fn=<AddBackward0>)
# tensor(308872.3125, grad_fn=<AddBackward0>)
# Epoch: 0145 train_loss= 0.51338 val_loss= 0.51266
# tensor(308872.3125, grad_fn=<AddBackward0>)
# tensor(307906.5000, grad_fn=<AddBackward0>)
# Epoch: 0146 train_loss= 0.51215 val_loss= 0.50604
# tensor(307906.5000, grad_fn=<AddBackward0>)
# tensor(306948.4375, grad_fn=<AddBackward0>)
# Epoch: 0147 train_loss= 0.50895 val_loss= 0.50428
# tensor(306948.4375, grad_fn=<AddBackward0>)
# tensor(305991.2500, grad_fn=<AddBackward0>)
# Epoch: 0148 train_loss= 0.50624 val_loss= 0.50186
# tensor(305991.2500, grad_fn=<AddBackward0>)
# tensor(305033., grad_fn=<AddBackward0>)
# Epoch: 0149 train_loss= 0.50226 val_loss= 0.49843
# tensor(305033., grad_fn=<AddBackward0>)
# tensor(304079.0938, grad_fn=<AddBackward0>)
# Epoch: 0150 train_loss= 0.49996 val_loss= 0.49541
# tensor(304079.0938, grad_fn=<AddBackward0>)
# tensor(303127.6875, grad_fn=<AddBackward0>)
# Epoch: 0151 train_loss= 0.49875 val_loss= 0.49453
# tensor(303127.6875, grad_fn=<AddBackward0>)
# tensor(302178.7500, grad_fn=<AddBackward0>)
# Epoch: 0152 train_loss= 0.49557 val_loss= 0.49160
# tensor(302178.7500, grad_fn=<AddBackward0>)
# tensor(301229.7500, grad_fn=<AddBackward0>)
# Epoch: 0153 train_loss= 0.49401 val_loss= 0.49003
# tensor(301229.7500, grad_fn=<AddBackward0>)
# tensor(300278.5312, grad_fn=<AddBackward0>)
# Epoch: 0154 train_loss= 0.49098 val_loss= 0.48328
# tensor(300278.5312, grad_fn=<AddBackward0>)
# tensor(299333.1250, grad_fn=<AddBackward0>)
# Epoch: 0155 train_loss= 0.48822 val_loss= 0.48005
# tensor(299333.1250, grad_fn=<AddBackward0>)
# tensor(298392.2812, grad_fn=<AddBackward0>)
# Epoch: 0156 train_loss= 0.48569 val_loss= 0.48024
# tensor(298392.2812, grad_fn=<AddBackward0>)
# tensor(297460.8750, grad_fn=<AddBackward0>)
# Epoch: 0157 train_loss= 0.48218 val_loss= 0.47983
# tensor(297460.8750, grad_fn=<AddBackward0>)
# tensor(296525.4375, grad_fn=<AddBackward0>)
# Epoch: 0158 train_loss= 0.47914 val_loss= 0.47639
# tensor(296525.4375, grad_fn=<AddBackward0>)
# tensor(295583.4375, grad_fn=<AddBackward0>)
# Epoch: 0159 train_loss= 0.47842 val_loss= 0.47147
# tensor(295583.4375, grad_fn=<AddBackward0>)
# tensor(294652., grad_fn=<AddBackward0>)
# Epoch: 0160 train_loss= 0.47572 val_loss= 0.46994
# tensor(294652., grad_fn=<AddBackward0>)
# tensor(293722.6250, grad_fn=<AddBackward0>)
# Epoch: 0161 train_loss= 0.47348 val_loss= 0.46903
# tensor(293722.6250, grad_fn=<AddBackward0>)
# tensor(292797.6875, grad_fn=<AddBackward0>)
# Epoch: 0162 train_loss= 0.47104 val_loss= 0.46407
# tensor(292797.6875, grad_fn=<AddBackward0>)
# tensor(291866.8750, grad_fn=<AddBackward0>)
# Epoch: 0163 train_loss= 0.46815 val_loss= 0.46261
# tensor(291866.8750, grad_fn=<AddBackward0>)
# tensor(290942.5000, grad_fn=<AddBackward0>)
# Epoch: 0164 train_loss= 0.46523 val_loss= 0.46042
# tensor(290942.5000, grad_fn=<AddBackward0>)
# tensor(290021.5000, grad_fn=<AddBackward0>)
# Epoch: 0165 train_loss= 0.46285 val_loss= 0.45784
# tensor(290021.5000, grad_fn=<AddBackward0>)
# tensor(289103.2812, grad_fn=<AddBackward0>)
# Epoch: 0166 train_loss= 0.45955 val_loss= 0.45491
# tensor(289103.2812, grad_fn=<AddBackward0>)
# tensor(288187.3750, grad_fn=<AddBackward0>)
# Epoch: 0167 train_loss= 0.45794 val_loss= 0.45278
# tensor(288187.3750, grad_fn=<AddBackward0>)
# tensor(287267.1250, grad_fn=<AddBackward0>)
# Epoch: 0168 train_loss= 0.45555 val_loss= 0.45113
# tensor(287267.1250, grad_fn=<AddBackward0>)
# tensor(286352.5000, grad_fn=<AddBackward0>)
# Epoch: 0169 train_loss= 0.45308 val_loss= 0.44891
# tensor(286352.5000, grad_fn=<AddBackward0>)
# tensor(285437.0625, grad_fn=<AddBackward0>)
# Epoch: 0170 train_loss= 0.45028 val_loss= 0.44621
# tensor(285437.0625, grad_fn=<AddBackward0>)
# tensor(284525.7500, grad_fn=<AddBackward0>)
# Epoch: 0171 train_loss= 0.44636 val_loss= 0.44527
# tensor(284525.7500, grad_fn=<AddBackward0>)
# tensor(283617.3750, grad_fn=<AddBackward0>)
# Epoch: 0172 train_loss= 0.44613 val_loss= 0.44226
# tensor(283617.3750, grad_fn=<AddBackward0>)
# tensor(282712.6250, grad_fn=<AddBackward0>)
# Epoch: 0173 train_loss= 0.44529 val_loss= 0.43937
# tensor(282712.6250, grad_fn=<AddBackward0>)
# tensor(281814.7500, grad_fn=<AddBackward0>)
# Epoch: 0174 train_loss= 0.44049 val_loss= 0.43618
# tensor(281814.7500, grad_fn=<AddBackward0>)
# tensor(280915.0625, grad_fn=<AddBackward0>)
# Epoch: 0175 train_loss= 0.43804 val_loss= 0.43408
# tensor(280915.0625, grad_fn=<AddBackward0>)
# tensor(280012.1875, grad_fn=<AddBackward0>)
# Epoch: 0176 train_loss= 0.43655 val_loss= 0.43027
# tensor(280012.1875, grad_fn=<AddBackward0>)
# tensor(279122.9688, grad_fn=<AddBackward0>)
# Epoch: 0177 train_loss= 0.43405 val_loss= 0.43031
# tensor(279122.9688, grad_fn=<AddBackward0>)
# tensor(278227.9375, grad_fn=<AddBackward0>)
# Epoch: 0178 train_loss= 0.43254 val_loss= 0.42802
# tensor(278227.9375, grad_fn=<AddBackward0>)
# tensor(277332.7812, grad_fn=<AddBackward0>)
# Epoch: 0179 train_loss= 0.42874 val_loss= 0.42391
# tensor(277332.7812, grad_fn=<AddBackward0>)
# tensor(276443.8750, grad_fn=<AddBackward0>)
# Epoch: 0180 train_loss= 0.42638 val_loss= 0.42149
# tensor(276443.8750, grad_fn=<AddBackward0>)
# tensor(275552., grad_fn=<AddBackward0>)
# Epoch: 0181 train_loss= 0.42270 val_loss= 0.42159
# tensor(275552., grad_fn=<AddBackward0>)
# tensor(274668.6562, grad_fn=<AddBackward0>)
# Epoch: 0182 train_loss= 0.42294 val_loss= 0.41742
# tensor(274668.6562, grad_fn=<AddBackward0>)
# tensor(273778.9688, grad_fn=<AddBackward0>)
# Epoch: 0183 train_loss= 0.41935 val_loss= 0.41679
# tensor(273778.9688, grad_fn=<AddBackward0>)
# tensor(272904.6562, grad_fn=<AddBackward0>)
# Epoch: 0184 train_loss= 0.41750 val_loss= 0.41653
# tensor(272904.6562, grad_fn=<AddBackward0>)
# tensor(272029.1250, grad_fn=<AddBackward0>)
# Epoch: 0185 train_loss= 0.41705 val_loss= 0.41170
# tensor(272029.1250, grad_fn=<AddBackward0>)
# tensor(271155.7812, grad_fn=<AddBackward0>)
# Epoch: 0186 train_loss= 0.41357 val_loss= 0.41147
# tensor(271155.7812, grad_fn=<AddBackward0>)
# tensor(270289.9375, grad_fn=<AddBackward0>)
# Epoch: 0187 train_loss= 0.41193 val_loss= 0.40875
# tensor(270289.9375, grad_fn=<AddBackward0>)
# tensor(269420.7500, grad_fn=<AddBackward0>)
# Epoch: 0188 train_loss= 0.40870 val_loss= 0.40727
# tensor(269420.7500, grad_fn=<AddBackward0>)
# tensor(268552.0625, grad_fn=<AddBackward0>)
# Epoch: 0189 train_loss= 0.40788 val_loss= 0.40523
# tensor(268552.0625, grad_fn=<AddBackward0>)
# tensor(267689.8438, grad_fn=<AddBackward0>)
# Epoch: 0190 train_loss= 0.40509 val_loss= 0.40360
# tensor(267689.8438, grad_fn=<AddBackward0>)
# tensor(266827.3125, grad_fn=<AddBackward0>)
# Epoch: 0191 train_loss= 0.40385 val_loss= 0.39862
# tensor(266827.3125, grad_fn=<AddBackward0>)
# tensor(265969.9688, grad_fn=<AddBackward0>)
# Epoch: 0192 train_loss= 0.40285 val_loss= 0.39998
# tensor(265969.9688, grad_fn=<AddBackward0>)
# tensor(265124.0312, grad_fn=<AddBackward0>)
# Epoch: 0193 train_loss= 0.39855 val_loss= 0.39489
# tensor(265124.0312, grad_fn=<AddBackward0>)
# tensor(264279.6250, grad_fn=<AddBackward0>)
# Epoch: 0194 train_loss= 0.39657 val_loss= 0.39489
# tensor(264279.6250, grad_fn=<AddBackward0>)
# tensor(263426.0938, grad_fn=<AddBackward0>)
# Epoch: 0195 train_loss= 0.39470 val_loss= 0.39496
# tensor(263426.0938, grad_fn=<AddBackward0>)
# tensor(262578.9375, grad_fn=<AddBackward0>)
# Epoch: 0196 train_loss= 0.39370 val_loss= 0.39111
# tensor(262578.9375, grad_fn=<AddBackward0>)
# tensor(261730.2812, grad_fn=<AddBackward0>)
# Epoch: 0197 train_loss= 0.39138 val_loss= 0.38802
# tensor(261730.2812, grad_fn=<AddBackward0>)
# tensor(260890.1250, grad_fn=<AddBackward0>)
# Epoch: 0198 train_loss= 0.38945 val_loss= 0.38632
# tensor(260890.1250, grad_fn=<AddBackward0>)
# tensor(260056.6406, grad_fn=<AddBackward0>)
# Epoch: 0199 train_loss= 0.38834 val_loss= 0.38451
# tensor(260056.6406, grad_fn=<AddBackward0>)
# tensor(259223.3125, grad_fn=<AddBackward0>)
# Epoch: 0200 train_loss= 0.38513 val_loss= 0.38254
# tensor(259223.3125, grad_fn=<AddBackward0>)
# tensor(258393.6875, grad_fn=<AddBackward0>)
# Epoch: 0201 train_loss= 0.38258 val_loss= 0.37964
# tensor(258393.6875, grad_fn=<AddBackward0>)
# tensor(257558.7344, grad_fn=<AddBackward0>)
# Epoch: 0202 train_loss= 0.38078 val_loss= 0.37738
# tensor(257558.7344, grad_fn=<AddBackward0>)
# tensor(256720.0938, grad_fn=<AddBackward0>)
# Epoch: 0203 train_loss= 0.37867 val_loss= 0.37504
# tensor(256720.0938, grad_fn=<AddBackward0>)
# tensor(255896.2656, grad_fn=<AddBackward0>)
# Epoch: 0204 train_loss= 0.37699 val_loss= 0.37354
# tensor(255896.2656, grad_fn=<AddBackward0>)
# tensor(255066.0781, grad_fn=<AddBackward0>)
# Epoch: 0205 train_loss= 0.37529 val_loss= 0.37351
# tensor(255066.0781, grad_fn=<AddBackward0>)
# tensor(254249.2812, grad_fn=<AddBackward0>)
# Epoch: 0206 train_loss= 0.37415 val_loss= 0.37225
# tensor(254249.2812, grad_fn=<AddBackward0>)
# tensor(253433.2656, grad_fn=<AddBackward0>)
# Epoch: 0207 train_loss= 0.37133 val_loss= 0.37206
# tensor(253433.2656, grad_fn=<AddBackward0>)
# tensor(252617.9531, grad_fn=<AddBackward0>)
# Epoch: 0208 train_loss= 0.36996 val_loss= 0.36711
# tensor(252617.9531, grad_fn=<AddBackward0>)
# tensor(251812.2812, grad_fn=<AddBackward0>)
# Epoch: 0209 train_loss= 0.36738 val_loss= 0.36688
# tensor(251812.2812, grad_fn=<AddBackward0>)
# tensor(251000.9688, grad_fn=<AddBackward0>)
# Epoch: 0210 train_loss= 0.36708 val_loss= 0.36396
# tensor(251000.9688, grad_fn=<AddBackward0>)
# tensor(250195.7969, grad_fn=<AddBackward0>)
# Epoch: 0211 train_loss= 0.36435 val_loss= 0.35865
# tensor(250195.7969, grad_fn=<AddBackward0>)
# tensor(249399.3906, grad_fn=<AddBackward0>)
# Epoch: 0212 train_loss= 0.36169 val_loss= 0.36009
# tensor(249399.3906, grad_fn=<AddBackward0>)
# tensor(248596.4062, grad_fn=<AddBackward0>)
# Epoch: 0213 train_loss= 0.36079 val_loss= 0.35739
# tensor(248596.4062, grad_fn=<AddBackward0>)
# tensor(247795.5469, grad_fn=<AddBackward0>)
# Epoch: 0214 train_loss= 0.35796 val_loss= 0.35841
# tensor(247795.5469, grad_fn=<AddBackward0>)
# tensor(246999.3750, grad_fn=<AddBackward0>)
# Epoch: 0215 train_loss= 0.35689 val_loss= 0.35549
# tensor(246999.3750, grad_fn=<AddBackward0>)
# tensor(246211.6562, grad_fn=<AddBackward0>)
# Epoch: 0216 train_loss= 0.35587 val_loss= 0.35394
# tensor(246211.6562, grad_fn=<AddBackward0>)
# tensor(245419., grad_fn=<AddBackward0>)
# Epoch: 0217 train_loss= 0.35296 val_loss= 0.35127
# tensor(245419., grad_fn=<AddBackward0>)
# tensor(244630.8750, grad_fn=<AddBackward0>)
# Epoch: 0218 train_loss= 0.35230 val_loss= 0.34960
# tensor(244630.8750, grad_fn=<AddBackward0>)
# tensor(243850.7500, grad_fn=<AddBackward0>)
# Epoch: 0219 train_loss= 0.35065 val_loss= 0.34851
# tensor(243850.7500, grad_fn=<AddBackward0>)
# tensor(243077.0625, grad_fn=<AddBackward0>)
# Epoch: 0220 train_loss= 0.34880 val_loss= 0.34592
# tensor(243077.0625, grad_fn=<AddBackward0>)
# tensor(242299.2500, grad_fn=<AddBackward0>)
# Epoch: 0221 train_loss= 0.34678 val_loss= 0.34347
# tensor(242299.2500, grad_fn=<AddBackward0>)
# tensor(241526.7500, grad_fn=<AddBackward0>)
# Epoch: 0222 train_loss= 0.34506 val_loss= 0.34243
# tensor(241526.7500, grad_fn=<AddBackward0>)
# tensor(240761.3750, grad_fn=<AddBackward0>)
# Epoch: 0223 train_loss= 0.34355 val_loss= 0.34207
# tensor(240761.3750, grad_fn=<AddBackward0>)
# tensor(240004.5938, grad_fn=<AddBackward0>)
# Epoch: 0224 train_loss= 0.34183 val_loss= 0.33997
# tensor(240004.5938, grad_fn=<AddBackward0>)
# tensor(239252.6406, grad_fn=<AddBackward0>)
# Epoch: 0225 train_loss= 0.34041 val_loss= 0.33987
# tensor(239252.6406, grad_fn=<AddBackward0>)
# tensor(238498.6406, grad_fn=<AddBackward0>)
# Epoch: 0226 train_loss= 0.33843 val_loss= 0.33579
# tensor(238498.6406, grad_fn=<AddBackward0>)
# tensor(237739.2031, grad_fn=<AddBackward0>)
# Epoch: 0227 train_loss= 0.33611 val_loss= 0.33320
# tensor(237739.2031, grad_fn=<AddBackward0>)
# tensor(236979.3750, grad_fn=<AddBackward0>)
# Epoch: 0228 train_loss= 0.33497 val_loss= 0.33308
# tensor(236979.3750, grad_fn=<AddBackward0>)
# tensor(236231.0156, grad_fn=<AddBackward0>)
# Epoch: 0229 train_loss= 0.33336 val_loss= 0.33204
# tensor(236231.0156, grad_fn=<AddBackward0>)
# tensor(235473.7188, grad_fn=<AddBackward0>)
# Epoch: 0230 train_loss= 0.33255 val_loss= 0.33093
# tensor(235473.7188, grad_fn=<AddBackward0>)
# tensor(234730.7500, grad_fn=<AddBackward0>)
# Epoch: 0231 train_loss= 0.33116 val_loss= 0.32893
# tensor(234730.7500, grad_fn=<AddBackward0>)
# tensor(233983.6250, grad_fn=<AddBackward0>)
# Epoch: 0232 train_loss= 0.32876 val_loss= 0.32765
# tensor(233983.6250, grad_fn=<AddBackward0>)
# tensor(233234.5625, grad_fn=<AddBackward0>)
# Epoch: 0233 train_loss= 0.32701 val_loss= 0.32728
# tensor(233234.5625, grad_fn=<AddBackward0>)
# tensor(232492.5156, grad_fn=<AddBackward0>)
# Epoch: 0234 train_loss= 0.32598 val_loss= 0.32551
# tensor(232492.5156, grad_fn=<AddBackward0>)
# tensor(231756.5469, grad_fn=<AddBackward0>)
# Epoch: 0235 train_loss= 0.32551 val_loss= 0.32228
# tensor(231756.5469, grad_fn=<AddBackward0>)
# tensor(231018.7969, grad_fn=<AddBackward0>)
# Epoch: 0236 train_loss= 0.32173 val_loss= 0.32112
# tensor(231018.7969, grad_fn=<AddBackward0>)
# tensor(230294.5625, grad_fn=<AddBackward0>)
# Epoch: 0237 train_loss= 0.32170 val_loss= 0.32026
# tensor(230294.5625, grad_fn=<AddBackward0>)
# tensor(229574.7969, grad_fn=<AddBackward0>)
# Epoch: 0238 train_loss= 0.32014 val_loss= 0.31820
# tensor(229574.7969, grad_fn=<AddBackward0>)
# tensor(228858.4375, grad_fn=<AddBackward0>)
# Epoch: 0239 train_loss= 0.31753 val_loss= 0.31657
# tensor(228858.4375, grad_fn=<AddBackward0>)
# tensor(228139.9062, grad_fn=<AddBackward0>)
# Epoch: 0240 train_loss= 0.31795 val_loss= 0.31564
# tensor(228139.9062, grad_fn=<AddBackward0>)
# tensor(227421.2500, grad_fn=<AddBackward0>)
# Epoch: 0241 train_loss= 0.31600 val_loss= 0.31285
# tensor(227421.2500, grad_fn=<AddBackward0>)
# tensor(226711.0625, grad_fn=<AddBackward0>)
# Epoch: 0242 train_loss= 0.31487 val_loss= 0.31272
# tensor(226711.0625, grad_fn=<AddBackward0>)
# tensor(226007.6094, grad_fn=<AddBackward0>)
# Epoch: 0243 train_loss= 0.31359 val_loss= 0.31055
# tensor(226007.6094, grad_fn=<AddBackward0>)
# tensor(225302.3438, grad_fn=<AddBackward0>)
# Epoch: 0244 train_loss= 0.31128 val_loss= 0.30854
# tensor(225302.3438, grad_fn=<AddBackward0>)
# tensor(224601.9844, grad_fn=<AddBackward0>)
# Epoch: 0245 train_loss= 0.31017 val_loss= 0.30651
# tensor(224601.9844, grad_fn=<AddBackward0>)
# tensor(223895.5000, grad_fn=<AddBackward0>)
# Epoch: 0246 train_loss= 0.30897 val_loss= 0.30585
# tensor(223895.5000, grad_fn=<AddBackward0>)
# tensor(223202.5625, grad_fn=<AddBackward0>)
# Epoch: 0247 train_loss= 0.30762 val_loss= 0.30634
# tensor(223202.5625, grad_fn=<AddBackward0>)
# tensor(222512.5000, grad_fn=<AddBackward0>)
# Epoch: 0248 train_loss= 0.30643 val_loss= 0.30275
# tensor(222512.5000, grad_fn=<AddBackward0>)
# tensor(221817.8281, grad_fn=<AddBackward0>)
# Epoch: 0249 train_loss= 0.30461 val_loss= 0.30593
# tensor(221817.8281, grad_fn=<AddBackward0>)
# tensor(221127.1562, grad_fn=<AddBackward0>)
# Epoch: 0250 train_loss= 0.30391 val_loss= 0.30204
# tensor(221127.1562, grad_fn=<AddBackward0>)
# tensor(220439.2969, grad_fn=<AddBackward0>)
# Epoch: 0251 train_loss= 0.30271 val_loss= 0.30331
# tensor(220439.2969, grad_fn=<AddBackward0>)
# tensor(219766.6875, grad_fn=<AddBackward0>)
# Epoch: 0252 train_loss= 0.30168 val_loss= 0.30062
# tensor(219766.6875, grad_fn=<AddBackward0>)
# tensor(219087.1875, grad_fn=<AddBackward0>)
# Epoch: 0253 train_loss= 0.29993 val_loss= 0.29703
# tensor(219087.1875, grad_fn=<AddBackward0>)
# tensor(218373.0781, grad_fn=<AddBackward0>)
# Epoch: 0254 train_loss= 0.29774 val_loss= 0.29705
# tensor(218373.0781, grad_fn=<AddBackward0>)
# tensor(217564.1406, grad_fn=<AddBackward0>)
# Epoch: 0255 train_loss= 0.29776 val_loss= 0.29644
# tensor(217564.1406, grad_fn=<AddBackward0>)
# tensor(216753.2031, grad_fn=<AddBackward0>)
# Epoch: 0256 train_loss= 0.29627 val_loss= 0.29307
# tensor(216753.2031, grad_fn=<AddBackward0>)
# tensor(215943.5781, grad_fn=<AddBackward0>)
# Epoch: 0257 train_loss= 0.29517 val_loss= 0.29433
# tensor(215943.5781, grad_fn=<AddBackward0>)
# tensor(215135.3438, grad_fn=<AddBackward0>)
# Epoch: 0258 train_loss= 0.29259 val_loss= 0.29134
# tensor(215135.3438, grad_fn=<AddBackward0>)
# tensor(214329.5938, grad_fn=<AddBackward0>)
# Epoch: 0259 train_loss= 0.29140 val_loss= 0.29028
# tensor(214329.5938, grad_fn=<AddBackward0>)
# tensor(213524.5000, grad_fn=<AddBackward0>)
# Epoch: 0260 train_loss= 0.29014 val_loss= 0.28943
# tensor(213524.5000, grad_fn=<AddBackward0>)
# tensor(212723.3594, grad_fn=<AddBackward0>)
# Epoch: 0261 train_loss= 0.28894 val_loss= 0.28696
# tensor(212723.3594, grad_fn=<AddBackward0>)
# tensor(211922.4688, grad_fn=<AddBackward0>)
# Epoch: 0262 train_loss= 0.28758 val_loss= 0.28670
# tensor(211922.4688, grad_fn=<AddBackward0>)
# tensor(211122.6406, grad_fn=<AddBackward0>)
# Epoch: 0263 train_loss= 0.28628 val_loss= 0.28349
# tensor(211122.6406, grad_fn=<AddBackward0>)
# tensor(210326.1562, grad_fn=<AddBackward0>)
# Epoch: 0264 train_loss= 0.28437 val_loss= 0.28385
# tensor(210326.1562, grad_fn=<AddBackward0>)
# tensor(209534.1094, grad_fn=<AddBackward0>)
# Epoch: 0265 train_loss= 0.28419 val_loss= 0.28231
# tensor(209534.1094, grad_fn=<AddBackward0>)
# tensor(208740.5000, grad_fn=<AddBackward0>)
# Epoch: 0266 train_loss= 0.28180 val_loss= 0.28179
# tensor(208740.5000, grad_fn=<AddBackward0>)
# tensor(207951.0312, grad_fn=<AddBackward0>)
# Epoch: 0267 train_loss= 0.28085 val_loss= 0.27989
# tensor(207951.0312, grad_fn=<AddBackward0>)
# tensor(207157.9844, grad_fn=<AddBackward0>)
# Epoch: 0268 train_loss= 0.27937 val_loss= 0.27857
# tensor(207157.9844, grad_fn=<AddBackward0>)
# tensor(206372.1875, grad_fn=<AddBackward0>)
# Epoch: 0269 train_loss= 0.27827 val_loss= 0.27668
# tensor(206372.1875, grad_fn=<AddBackward0>)
# tensor(205587.0625, grad_fn=<AddBackward0>)
# Epoch: 0270 train_loss= 0.27717 val_loss= 0.27488
# tensor(205587.0625, grad_fn=<AddBackward0>)
# tensor(204804.3750, grad_fn=<AddBackward0>)
# Epoch: 0271 train_loss= 0.27591 val_loss= 0.27589
# tensor(204804.3750, grad_fn=<AddBackward0>)
# tensor(204023.6875, grad_fn=<AddBackward0>)
# Epoch: 0272 train_loss= 0.27468 val_loss= 0.27217
# tensor(204023.6875, grad_fn=<AddBackward0>)
# tensor(203244.2500, grad_fn=<AddBackward0>)
# Epoch: 0273 train_loss= 0.27358 val_loss= 0.27165
# tensor(203244.2500, grad_fn=<AddBackward0>)
# tensor(202463.8281, grad_fn=<AddBackward0>)
# Epoch: 0274 train_loss= 0.27247 val_loss= 0.27117
# tensor(202463.8281, grad_fn=<AddBackward0>)
# tensor(201688.7656, grad_fn=<AddBackward0>)
# Epoch: 0275 train_loss= 0.27202 val_loss= 0.27007
# tensor(201688.7656, grad_fn=<AddBackward0>)
# tensor(200915.6719, grad_fn=<AddBackward0>)
# Epoch: 0276 train_loss= 0.27055 val_loss= 0.26809
# tensor(200915.6719, grad_fn=<AddBackward0>)
# tensor(200141.4375, grad_fn=<AddBackward0>)
# Epoch: 0277 train_loss= 0.26814 val_loss= 0.26748
# tensor(200141.4375, grad_fn=<AddBackward0>)
# tensor(199375.8750, grad_fn=<AddBackward0>)
# Epoch: 0278 train_loss= 0.26695 val_loss= 0.26695
# tensor(199375.8750, grad_fn=<AddBackward0>)
# tensor(198609.3438, grad_fn=<AddBackward0>)
# Epoch: 0279 train_loss= 0.26671 val_loss= 0.26415
# tensor(198609.3438, grad_fn=<AddBackward0>)
# tensor(197847.6562, grad_fn=<AddBackward0>)
# Epoch: 0280 train_loss= 0.26551 val_loss= 0.26205
# tensor(197847.6562, grad_fn=<AddBackward0>)
# tensor(197085.8750, grad_fn=<AddBackward0>)
# Epoch: 0281 train_loss= 0.26412 val_loss= 0.26332
# tensor(197085.8750, grad_fn=<AddBackward0>)
# tensor(196326.3594, grad_fn=<AddBackward0>)
# Epoch: 0282 train_loss= 0.26233 val_loss= 0.26142
# tensor(196326.3594, grad_fn=<AddBackward0>)
# tensor(195567.7812, grad_fn=<AddBackward0>)
# Epoch: 0283 train_loss= 0.26105 val_loss= 0.25937
# tensor(195567.7812, grad_fn=<AddBackward0>)
# tensor(194811.2500, grad_fn=<AddBackward0>)
# Epoch: 0284 train_loss= 0.26118 val_loss= 0.25914
# tensor(194811.2500, grad_fn=<AddBackward0>)
# tensor(194057.4062, grad_fn=<AddBackward0>)
# Epoch: 0285 train_loss= 0.25901 val_loss= 0.25706
# tensor(194057.4062, grad_fn=<AddBackward0>)
# tensor(193306.6406, grad_fn=<AddBackward0>)
# Epoch: 0286 train_loss= 0.25789 val_loss= 0.25677
# tensor(193306.6406, grad_fn=<AddBackward0>)
# tensor(192558.1562, grad_fn=<AddBackward0>)
# Epoch: 0287 train_loss= 0.25670 val_loss= 0.25630
# tensor(192558.1562, grad_fn=<AddBackward0>)
# tensor(191807.7656, grad_fn=<AddBackward0>)
# Epoch: 0288 train_loss= 0.25549 val_loss= 0.25427
# tensor(191807.7656, grad_fn=<AddBackward0>)
# tensor(191061.5312, grad_fn=<AddBackward0>)
# Epoch: 0289 train_loss= 0.25438 val_loss= 0.25315
# tensor(191061.5312, grad_fn=<AddBackward0>)
# tensor(190318.7812, grad_fn=<AddBackward0>)
# Epoch: 0290 train_loss= 0.25317 val_loss= 0.25181
# tensor(190318.7812, grad_fn=<AddBackward0>)
# tensor(189579.3125, grad_fn=<AddBackward0>)
# Epoch: 0291 train_loss= 0.25295 val_loss= 0.25172
# tensor(189579.3125, grad_fn=<AddBackward0>)
# tensor(188839.1250, grad_fn=<AddBackward0>)
# Epoch: 0292 train_loss= 0.25062 val_loss= 0.25104
# tensor(188839.1250, grad_fn=<AddBackward0>)
# tensor(188102.2500, grad_fn=<AddBackward0>)
# Epoch: 0293 train_loss= 0.25028 val_loss= 0.24956
# tensor(188102.2500, grad_fn=<AddBackward0>)
# tensor(187369.7812, grad_fn=<AddBackward0>)
# Epoch: 0294 train_loss= 0.24959 val_loss= 0.24770
# tensor(187369.7812, grad_fn=<AddBackward0>)
# tensor(186637.8750, grad_fn=<AddBackward0>)
# Epoch: 0295 train_loss= 0.24903 val_loss= 0.24814
# tensor(186637.8750, grad_fn=<AddBackward0>)
# tensor(185906.4375, grad_fn=<AddBackward0>)
# Epoch: 0296 train_loss= 0.24774 val_loss= 0.24553
# tensor(185906.4375, grad_fn=<AddBackward0>)
# tensor(185182.8125, grad_fn=<AddBackward0>)
# Epoch: 0297 train_loss= 0.24601 val_loss= 0.24535
# tensor(185182.8125, grad_fn=<AddBackward0>)
# tensor(184460.5000, grad_fn=<AddBackward0>)
# Epoch: 0298 train_loss= 0.24513 val_loss= 0.24388
# tensor(184460.5000, grad_fn=<AddBackward0>)
# tensor(183739.7969, grad_fn=<AddBackward0>)
# Epoch: 0299 train_loss= 0.24373 val_loss= 0.24217
# tensor(183739.7969, grad_fn=<AddBackward0>)
# tensor(183020.5938, grad_fn=<AddBackward0>)
# Epoch: 0300 train_loss= 0.24312 val_loss= 0.24161
# tensor(183020.5938, grad_fn=<AddBackward0>)
# tensor(182304.3594, grad_fn=<AddBackward0>)
# Epoch: 0301 train_loss= 0.24238 val_loss= 0.24067
# tensor(182304.3594, grad_fn=<AddBackward0>)
# tensor(181593., grad_fn=<AddBackward0>)
# Epoch: 0302 train_loss= 0.24051 val_loss= 0.24055
# tensor(181593., grad_fn=<AddBackward0>)
# tensor(180880.6719, grad_fn=<AddBackward0>)
# Epoch: 0303 train_loss= 0.24035 val_loss= 0.23918
# tensor(180880.6719, grad_fn=<AddBackward0>)
# tensor(180172.8281, grad_fn=<AddBackward0>)
# Epoch: 0304 train_loss= 0.23873 val_loss= 0.23787
# tensor(180172.8281, grad_fn=<AddBackward0>)
# tensor(179467.9688, grad_fn=<AddBackward0>)
# Epoch: 0305 train_loss= 0.23903 val_loss= 0.23581
# tensor(179467.9688, grad_fn=<AddBackward0>)
# tensor(178765.6562, grad_fn=<AddBackward0>)
# Epoch: 0306 train_loss= 0.23745 val_loss= 0.23637
# tensor(178765.6562, grad_fn=<AddBackward0>)
# tensor(178068.0781, grad_fn=<AddBackward0>)
# Epoch: 0307 train_loss= 0.23718 val_loss= 0.23495
# tensor(178068.0781, grad_fn=<AddBackward0>)
# tensor(177371.5625, grad_fn=<AddBackward0>)
# Epoch: 0308 train_loss= 0.23541 val_loss= 0.23438
# tensor(177371.5625, grad_fn=<AddBackward0>)
# tensor(176676.9844, grad_fn=<AddBackward0>)
# Epoch: 0309 train_loss= 0.23395 val_loss= 0.23271
# tensor(176676.9844, grad_fn=<AddBackward0>)
# tensor(175988.2812, grad_fn=<AddBackward0>)
# Epoch: 0310 train_loss= 0.23369 val_loss= 0.23171
# tensor(175988.2812, grad_fn=<AddBackward0>)
# tensor(175300.1094, grad_fn=<AddBackward0>)
# Epoch: 0311 train_loss= 0.23211 val_loss= 0.23173
# tensor(175300.1094, grad_fn=<AddBackward0>)
# tensor(174609.4688, grad_fn=<AddBackward0>)
# Epoch: 0312 train_loss= 0.23141 val_loss= 0.23073
# tensor(174609.4688, grad_fn=<AddBackward0>)
# tensor(173925.4375, grad_fn=<AddBackward0>)
# Epoch: 0313 train_loss= 0.23110 val_loss= 0.23004
# tensor(173925.4375, grad_fn=<AddBackward0>)
# tensor(173245.3906, grad_fn=<AddBackward0>)
# Epoch: 0314 train_loss= 0.22973 val_loss= 0.22886
# tensor(173245.3906, grad_fn=<AddBackward0>)
# tensor(172567.5312, grad_fn=<AddBackward0>)
# Epoch: 0315 train_loss= 0.22875 val_loss= 0.22797
# tensor(172567.5312, grad_fn=<AddBackward0>)
# tensor(171891., grad_fn=<AddBackward0>)
# Epoch: 0316 train_loss= 0.22819 val_loss= 0.22906
# tensor(171891., grad_fn=<AddBackward0>)
# tensor(171217.7812, grad_fn=<AddBackward0>)
# Epoch: 0317 train_loss= 0.22712 val_loss= 0.22480
# tensor(171217.7812, grad_fn=<AddBackward0>)
# tensor(170546., grad_fn=<AddBackward0>)
# Epoch: 0318 train_loss= 0.22566 val_loss= 0.22389
# tensor(170546., grad_fn=<AddBackward0>)
# tensor(169877.3906, grad_fn=<AddBackward0>)
# Epoch: 0319 train_loss= 0.22534 val_loss= 0.22422
# tensor(169877.3906, grad_fn=<AddBackward0>)
# tensor(169211.6875, grad_fn=<AddBackward0>)
# Epoch: 0320 train_loss= 0.22453 val_loss= 0.22399
# tensor(169211.6875, grad_fn=<AddBackward0>)
# tensor(168547.3438, grad_fn=<AddBackward0>)
# Epoch: 0321 train_loss= 0.22281 val_loss= 0.22197
# tensor(168547.3438, grad_fn=<AddBackward0>)
# tensor(167889.8281, grad_fn=<AddBackward0>)
# Epoch: 0322 train_loss= 0.22209 val_loss= 0.22024
# tensor(167889.8281, grad_fn=<AddBackward0>)
# tensor(167235.0781, grad_fn=<AddBackward0>)
# Epoch: 0323 train_loss= 0.22092 val_loss= 0.22147
# tensor(167235.0781, grad_fn=<AddBackward0>)
# tensor(166580.9688, grad_fn=<AddBackward0>)
# Epoch: 0324 train_loss= 0.22031 val_loss= 0.21937
# tensor(166580.9688, grad_fn=<AddBackward0>)
# tensor(165929.9375, grad_fn=<AddBackward0>)
# Epoch: 0325 train_loss= 0.21960 val_loss= 0.21876
# tensor(165929.9375, grad_fn=<AddBackward0>)
# tensor(165280.4531, grad_fn=<AddBackward0>)
# Epoch: 0326 train_loss= 0.21797 val_loss= 0.21940
# tensor(165280.4531, grad_fn=<AddBackward0>)
# tensor(164639.1875, grad_fn=<AddBackward0>)
# Epoch: 0327 train_loss= 0.21731 val_loss= 0.21587
# tensor(164639.1875, grad_fn=<AddBackward0>)
# tensor(163997.6406, grad_fn=<AddBackward0>)
# Epoch: 0328 train_loss= 0.21786 val_loss= 0.21619
# tensor(163997.6406, grad_fn=<AddBackward0>)
# tensor(163360.1406, grad_fn=<AddBackward0>)
# Epoch: 0329 train_loss= 0.21671 val_loss= 0.21457
# tensor(163360.1406, grad_fn=<AddBackward0>)
# tensor(162722.5000, grad_fn=<AddBackward0>)
# Epoch: 0330 train_loss= 0.21495 val_loss= 0.21314
# tensor(162722.5000, grad_fn=<AddBackward0>)
# tensor(162089.9688, grad_fn=<AddBackward0>)
# Epoch: 0331 train_loss= 0.21443 val_loss= 0.21266
# tensor(162089.9688, grad_fn=<AddBackward0>)
# tensor(161456.4688, grad_fn=<AddBackward0>)
# Epoch: 0332 train_loss= 0.21398 val_loss= 0.21271
# tensor(161456.4688, grad_fn=<AddBackward0>)
# tensor(160831.0938, grad_fn=<AddBackward0>)
# Epoch: 0333 train_loss= 0.21305 val_loss= 0.21270
# tensor(160831.0938, grad_fn=<AddBackward0>)
# tensor(160205.5312, grad_fn=<AddBackward0>)
# Epoch: 0334 train_loss= 0.21196 val_loss= 0.21076
# tensor(160205.5312, grad_fn=<AddBackward0>)
# tensor(159581.5156, grad_fn=<AddBackward0>)
# Epoch: 0335 train_loss= 0.21141 val_loss= 0.20955
# tensor(159581.5156, grad_fn=<AddBackward0>)
# tensor(158963.7969, grad_fn=<AddBackward0>)
# Epoch: 0336 train_loss= 0.21047 val_loss= 0.20856
# tensor(158963.7969, grad_fn=<AddBackward0>)
# tensor(158349.2500, grad_fn=<AddBackward0>)
# Epoch: 0337 train_loss= 0.20950 val_loss= 0.20837
# tensor(158349.2500, grad_fn=<AddBackward0>)
# tensor(157737.0938, grad_fn=<AddBackward0>)
# Epoch: 0338 train_loss= 0.20856 val_loss= 0.20789
# tensor(157737.0938, grad_fn=<AddBackward0>)
# tensor(157127.6250, grad_fn=<AddBackward0>)
# Epoch: 0339 train_loss= 0.20805 val_loss= 0.20738
# tensor(157127.6250, grad_fn=<AddBackward0>)
# tensor(156523.2812, grad_fn=<AddBackward0>)
# Epoch: 0340 train_loss= 0.20642 val_loss= 0.20709
# tensor(156523.2812, grad_fn=<AddBackward0>)
# tensor(155919.3438, grad_fn=<AddBackward0>)
# Epoch: 0341 train_loss= 0.20653 val_loss= 0.20687
# tensor(155919.3438, grad_fn=<AddBackward0>)
# tensor(155315.4688, grad_fn=<AddBackward0>)
# Epoch: 0342 train_loss= 0.20564 val_loss= 0.20407
# tensor(155315.4688, grad_fn=<AddBackward0>)
# tensor(154714., grad_fn=<AddBackward0>)
# Epoch: 0343 train_loss= 0.20486 val_loss= 0.20342
# tensor(154714., grad_fn=<AddBackward0>)
# tensor(154120.0312, grad_fn=<AddBackward0>)
# Epoch: 0344 train_loss= 0.20440 val_loss= 0.20324
# tensor(154120.0312, grad_fn=<AddBackward0>)
# tensor(153531.2031, grad_fn=<AddBackward0>)
# Epoch: 0345 train_loss= 0.20360 val_loss= 0.20147
# tensor(153531.2031, grad_fn=<AddBackward0>)
# tensor(152940.9219, grad_fn=<AddBackward0>)
# Epoch: 0346 train_loss= 0.20272 val_loss= 0.20160
# tensor(152940.9219, grad_fn=<AddBackward0>)
# tensor(152355.4375, grad_fn=<AddBackward0>)
# ...
# tensor(88643.4766, grad_fn=<AddBackward0>)
# tensor(88481.0469, grad_fn=<AddBackward0>)
# Epoch: 0533 train_loss= 0.12361 val_loss= 0.12313
# tensor(88481.0469, grad_fn=<AddBackward0>)
# tensor(88316.3438, grad_fn=<AddBackward0>)
# Epoch: 0534 train_loss= 0.12371 val_loss= 0.12370
# tensor(88316.3438, grad_fn=<AddBackward0>)
# tensor(88153.7734, grad_fn=<AddBackward0>)
# Epoch: 0535 train_loss= 0.12358 val_loss= 0.12299
# tensor(88153.7734, grad_fn=<AddBackward0>)
# tensor(87991.7188, grad_fn=<AddBackward0>)
# Epoch: 0536 train_loss= 0.12392 val_loss= 0.12193
# tensor(87991.7188, grad_fn=<AddBackward0>)
# tensor(87832.6875, grad_fn=<AddBackward0>)
# Epoch: 0537 train_loss= 0.12335 val_loss= 0.12283
# tensor(87832.6875, grad_fn=<AddBackward0>)
# tensor(87674.3438, grad_fn=<AddBackward0>)
# Epoch: 0538 train_loss= 0.12304 val_loss= 0.12330
# tensor(87674.3438, grad_fn=<AddBackward0>)
# tensor(87514.3125, grad_fn=<AddBackward0>)
# Epoch: 0539 train_loss= 0.12283 val_loss= 0.12166
# tensor(87514.3125, grad_fn=<AddBackward0>)
# tensor(87349.6406, grad_fn=<AddBackward0>)
# Epoch: 0540 train_loss= 0.12245 val_loss= 0.12206
# tensor(87349.6406, grad_fn=<AddBackward0>)
# tensor(87188.7578, grad_fn=<AddBackward0>)
# Epoch: 0541 train_loss= 0.12190 val_loss= 0.12090
# tensor(87188.7578, grad_fn=<AddBackward0>)
# tensor(87028.2500, grad_fn=<AddBackward0>)
# Epoch: 0542 train_loss= 0.12221 val_loss= 0.12150
# tensor(87028.2500, grad_fn=<AddBackward0>)
# tensor(86866.5469, grad_fn=<AddBackward0>)
# Epoch: 0543 train_loss= 0.12158 val_loss= 0.12199
# tensor(86866.5469, grad_fn=<AddBackward0>)
# tensor(86706.6719, grad_fn=<AddBackward0>)
# Epoch: 0544 train_loss= 0.12113 val_loss= 0.12068
# tensor(86706.6719, grad_fn=<AddBackward0>)
# tensor(86545.0312, grad_fn=<AddBackward0>)
# Epoch: 0545 train_loss= 0.12113 val_loss= 0.11983
# tensor(86545.0312, grad_fn=<AddBackward0>)
# tensor(86382.3438, grad_fn=<AddBackward0>)
# Epoch: 0546 train_loss= 0.12077 val_loss= 0.12027
# tensor(86382.3438, grad_fn=<AddBackward0>)
# tensor(86221.6719, grad_fn=<AddBackward0>)
# Epoch: 0547 train_loss= 0.12119 val_loss= 0.11940
# tensor(86221.6719, grad_fn=<AddBackward0>)
# tensor(86057.8359, grad_fn=<AddBackward0>)
# Epoch: 0548 train_loss= 0.12027 val_loss= 0.11940
# tensor(86057.8359, grad_fn=<AddBackward0>)
# tensor(85892.1562, grad_fn=<AddBackward0>)
# Epoch: 0549 train_loss= 0.12086 val_loss= 0.11928
# tensor(85892.1562, grad_fn=<AddBackward0>)
# tensor(85726.2188, grad_fn=<AddBackward0>)
# Epoch: 0550 train_loss= 0.12019 val_loss= 0.12022
# tensor(85726.2188, grad_fn=<AddBackward0>)
# tensor(85562.3750, grad_fn=<AddBackward0>)
# Epoch: 0551 train_loss= 0.11990 val_loss= 0.11920
# tensor(85562.3750, grad_fn=<AddBackward0>)
# tensor(85400.2656, grad_fn=<AddBackward0>)
# Epoch: 0552 train_loss= 0.11981 val_loss= 0.11925
# tensor(85400.2656, grad_fn=<AddBackward0>)
# tensor(85238.9688, grad_fn=<AddBackward0>)
# Epoch: 0553 train_loss= 0.11955 val_loss= 0.11880
# tensor(85238.9688, grad_fn=<AddBackward0>)
# tensor(85079.7344, grad_fn=<AddBackward0>)
# Epoch: 0554 train_loss= 0.12000 val_loss= 0.11822
# tensor(85079.7344, grad_fn=<AddBackward0>)
# tensor(84921.5000, grad_fn=<AddBackward0>)
# Epoch: 0555 train_loss= 0.11916 val_loss= 0.11879
# tensor(84921.5000, grad_fn=<AddBackward0>)
# tensor(84760.3047, grad_fn=<AddBackward0>)
# Epoch: 0556 train_loss= 0.11885 val_loss= 0.11891
# tensor(84760.3047, grad_fn=<AddBackward0>)
# tensor(84602.4766, grad_fn=<AddBackward0>)
# Epoch: 0557 train_loss= 0.11902 val_loss= 0.11860
# tensor(84602.4766, grad_fn=<AddBackward0>)
# tensor(84445.8516, grad_fn=<AddBackward0>)
# Epoch: 0558 train_loss= 0.11897 val_loss= 0.11822
# tensor(84445.8516, grad_fn=<AddBackward0>)
# tensor(84292.3672, grad_fn=<AddBackward0>)
# Epoch: 0559 train_loss= 0.11873 val_loss= 0.11759
# tensor(84292.3672, grad_fn=<AddBackward0>)
# tensor(84143.7031, grad_fn=<AddBackward0>)
# Epoch: 0560 train_loss= 0.11820 val_loss= 0.12045
# tensor(84143.7031, grad_fn=<AddBackward0>)
# tensor(83993.7266, grad_fn=<AddBackward0>)
# Epoch: 0561 train_loss= 0.11828 val_loss= 0.11718
# tensor(83993.7266, grad_fn=<AddBackward0>)
# tensor(83845.3984, grad_fn=<AddBackward0>)
# Epoch: 0562 train_loss= 0.11809 val_loss= 0.11650
# tensor(83845.3984, grad_fn=<AddBackward0>)
# tensor(83695.1094, grad_fn=<AddBackward0>)
# Epoch: 0563 train_loss= 0.11821 val_loss= 0.11699
# tensor(83695.1094, grad_fn=<AddBackward0>)
# tensor(83547.7656, grad_fn=<AddBackward0>)
# Epoch: 0564 train_loss= 0.11757 val_loss= 0.11754
# tensor(83547.7656, grad_fn=<AddBackward0>)
# tensor(83401.2891, grad_fn=<AddBackward0>)
# Epoch: 0565 train_loss= 0.11697 val_loss= 0.11625
# tensor(83401.2891, grad_fn=<AddBackward0>)
# tensor(83260.5781, grad_fn=<AddBackward0>)
# Epoch: 0566 train_loss= 0.11739 val_loss= 0.11747
# tensor(83260.5781, grad_fn=<AddBackward0>)
# tensor(83121.2969, grad_fn=<AddBackward0>)
# Epoch: 0567 train_loss= 0.11659 val_loss= 0.11613
# tensor(83121.2969, grad_fn=<AddBackward0>)
# tensor(82980.7422, grad_fn=<AddBackward0>)
# Epoch: 0568 train_loss= 0.11615 val_loss= 0.11590
# tensor(82980.7422, grad_fn=<AddBackward0>)
# tensor(82836.0859, grad_fn=<AddBackward0>)
# Epoch: 0569 train_loss= 0.11604 val_loss= 0.11722
# tensor(82836.0859, grad_fn=<AddBackward0>)
# tensor(82688.2266, grad_fn=<AddBackward0>)
# Epoch: 0570 train_loss= 0.11651 val_loss= 0.11563
# tensor(82688.2266, grad_fn=<AddBackward0>)
# tensor(82541.1875, grad_fn=<AddBackward0>)
# Epoch: 0571 train_loss= 0.11624 val_loss= 0.11536
# tensor(82541.1875, grad_fn=<AddBackward0>)
# tensor(82395.7734, grad_fn=<AddBackward0>)
# Epoch: 0572 train_loss= 0.11560 val_loss= 0.11588
# tensor(82395.7734, grad_fn=<AddBackward0>)
# tensor(82251.4844, grad_fn=<AddBackward0>)
# Epoch: 0573 train_loss= 0.11596 val_loss= 0.11526
# tensor(82251.4844, grad_fn=<AddBackward0>)
# tensor(82107.7109, grad_fn=<AddBackward0>)
# Epoch: 0574 train_loss= 0.11541 val_loss= 0.11509
# tensor(82107.7109, grad_fn=<AddBackward0>)
# tensor(81964.5234, grad_fn=<AddBackward0>)
# Epoch: 0575 train_loss= 0.11501 val_loss= 0.11378
# tensor(81964.5234, grad_fn=<AddBackward0>)
# tensor(81819.7578, grad_fn=<AddBackward0>)
# Epoch: 0576 train_loss= 0.11529 val_loss= 0.11413
# tensor(81819.7578, grad_fn=<AddBackward0>)
# tensor(81675.6094, grad_fn=<AddBackward0>)
# Epoch: 0577 train_loss= 0.11466 val_loss= 0.11523
# tensor(81675.6094, grad_fn=<AddBackward0>)
# tensor(81530.6250, grad_fn=<AddBackward0>)
# Epoch: 0578 train_loss= 0.11535 val_loss= 0.11507
# tensor(81530.6250, grad_fn=<AddBackward0>)
# tensor(81393.1797, grad_fn=<AddBackward0>)
# Epoch: 0579 train_loss= 0.11506 val_loss= 0.11359
# tensor(81393.1797, grad_fn=<AddBackward0>)
# tensor(81256.1328, grad_fn=<AddBackward0>)
# Epoch: 0580 train_loss= 0.11439 val_loss= 0.11512
# tensor(81256.1328, grad_fn=<AddBackward0>)
# tensor(81121.1953, grad_fn=<AddBackward0>)
# Epoch: 0581 train_loss= 0.11416 val_loss= 0.11208
# tensor(81121.1953, grad_fn=<AddBackward0>)
# tensor(80985.8594, grad_fn=<AddBackward0>)
# Epoch: 0582 train_loss= 0.11431 val_loss= 0.11260
# tensor(80985.8594, grad_fn=<AddBackward0>)
# tensor(80851.4609, grad_fn=<AddBackward0>)
# Epoch: 0583 train_loss= 0.11424 val_loss= 0.11287
# tensor(80851.4609, grad_fn=<AddBackward0>)
# tensor(80714.7734, grad_fn=<AddBackward0>)
# Epoch: 0584 train_loss= 0.11436 val_loss= 0.11434
# tensor(80714.7734, grad_fn=<AddBackward0>)
# tensor(80579.5391, grad_fn=<AddBackward0>)
# Epoch: 0585 train_loss= 0.11337 val_loss= 0.11377
# tensor(80579.5391, grad_fn=<AddBackward0>)
# tensor(80449.1953, grad_fn=<AddBackward0>)
# Epoch: 0586 train_loss= 0.11347 val_loss= 0.11418
# tensor(80449.1953, grad_fn=<AddBackward0>)
# tensor(80320.4688, grad_fn=<AddBackward0>)
# Epoch: 0587 train_loss= 0.11346 val_loss= 0.11250
# tensor(80320.4688, grad_fn=<AddBackward0>)
# tensor(80192.4219, grad_fn=<AddBackward0>)
# Epoch: 0588 train_loss= 0.11282 val_loss= 0.11296
# tensor(80192.4219, grad_fn=<AddBackward0>)
# tensor(80064.9062, grad_fn=<AddBackward0>)
# Epoch: 0589 train_loss= 0.11227 val_loss= 0.11269
# tensor(80064.9062, grad_fn=<AddBackward0>)
# tensor(79939.4141, grad_fn=<AddBackward0>)
# Epoch: 0590 train_loss= 0.11288 val_loss= 0.11283
# tensor(79939.4141, grad_fn=<AddBackward0>)
# tensor(79812.8281, grad_fn=<AddBackward0>)
# Epoch: 0591 train_loss= 0.11311 val_loss= 0.11253
# tensor(79812.8281, grad_fn=<AddBackward0>)
# tensor(79683.7656, grad_fn=<AddBackward0>)
# Epoch: 0592 train_loss= 0.11218 val_loss= 0.11106
# tensor(79683.7656, grad_fn=<AddBackward0>)
# tensor(79553.1875, grad_fn=<AddBackward0>)
# Epoch: 0593 train_loss= 0.11221 val_loss= 0.11174
# tensor(79553.1875, grad_fn=<AddBackward0>)
# tensor(79420.5625, grad_fn=<AddBackward0>)
# Epoch: 0594 train_loss= 0.11252 val_loss= 0.11036
# tensor(79420.5625, grad_fn=<AddBackward0>)
# tensor(79288.0469, grad_fn=<AddBackward0>)
# Epoch: 0595 train_loss= 0.11182 val_loss= 0.11132
# tensor(79288.0469, grad_fn=<AddBackward0>)
# tensor(79154.8594, grad_fn=<AddBackward0>)
# Epoch: 0596 train_loss= 0.11132 val_loss= 0.11254
# tensor(79154.8594, grad_fn=<AddBackward0>)
# tensor(79023.6172, grad_fn=<AddBackward0>)
# Epoch: 0597 train_loss= 0.11191 val_loss= 0.11224
# tensor(79023.6172, grad_fn=<AddBackward0>)
# tensor(78894.0234, grad_fn=<AddBackward0>)
# Epoch: 0598 train_loss= 0.11108 val_loss= 0.11140
# tensor(78894.0234, grad_fn=<AddBackward0>)
# tensor(78763., grad_fn=<AddBackward0>)
# Epoch: 0599 train_loss= 0.11124 val_loss= 0.11101
# tensor(78763., grad_fn=<AddBackward0>)
# tensor(78627.8750, grad_fn=<AddBackward0>)
# Epoch: 0600 train_loss= 0.11067 val_loss= 0.11091
# tensor(78627.8750, grad_fn=<AddBackward0>)
# tensor(78492.2188, grad_fn=<AddBackward0>)
# Epoch: 0601 train_loss= 0.11033 val_loss= 0.11088
# tensor(78492.2188, grad_fn=<AddBackward0>)
# tensor(78359.3125, grad_fn=<AddBackward0>)
# Epoch: 0602 train_loss= 0.11024 val_loss= 0.11052
# tensor(78359.3125, grad_fn=<AddBackward0>)
# tensor(78227.5781, grad_fn=<AddBackward0>)
# Epoch: 0603 train_loss= 0.11139 val_loss= 0.11044
# tensor(78227.5781, grad_fn=<AddBackward0>)
# tensor(78098.9141, grad_fn=<AddBackward0>)
# Epoch: 0604 train_loss= 0.11053 val_loss= 0.11073
# tensor(78098.9141, grad_fn=<AddBackward0>)
# tensor(77972.4531, grad_fn=<AddBackward0>)
# Epoch: 0605 train_loss= 0.10993 val_loss= 0.11011
# tensor(77972.4531, grad_fn=<AddBackward0>)
# tensor(77851.0547, grad_fn=<AddBackward0>)
# Epoch: 0606 train_loss= 0.11080 val_loss= 0.10935
# tensor(77851.0547, grad_fn=<AddBackward0>)
# tensor(77729.9688, grad_fn=<AddBackward0>)
# Epoch: 0607 train_loss= 0.11045 val_loss= 0.10842
# tensor(77729.9688, grad_fn=<AddBackward0>)
# tensor(77608.6250, grad_fn=<AddBackward0>)
# Epoch: 0608 train_loss= 0.10946 val_loss= 0.10949
# tensor(77608.6250, grad_fn=<AddBackward0>)
# tensor(77485.8672, grad_fn=<AddBackward0>)
# Epoch: 0609 train_loss= 0.10933 val_loss= 0.10985
# tensor(77485.8672, grad_fn=<AddBackward0>)
# tensor(77363.0703, grad_fn=<AddBackward0>)
# Epoch: 0610 train_loss= 0.10974 val_loss= 0.10888
# tensor(77363.0703, grad_fn=<AddBackward0>)
# tensor(77243.3125, grad_fn=<AddBackward0>)
# Epoch: 0611 train_loss= 0.10999 val_loss= 0.10919
# tensor(77243.3125, grad_fn=<AddBackward0>)
# tensor(77127.2344, grad_fn=<AddBackward0>)
# Epoch: 0612 train_loss= 0.10913 val_loss= 0.10878
# tensor(77127.2344, grad_fn=<AddBackward0>)
# tensor(77012.0469, grad_fn=<AddBackward0>)
# Epoch: 0613 train_loss= 0.10875 val_loss= 0.10868
# tensor(77012.0469, grad_fn=<AddBackward0>)
# tensor(76901.4531, grad_fn=<AddBackward0>)
# Epoch: 0614 train_loss= 0.10948 val_loss= 0.10842
# tensor(76901.4531, grad_fn=<AddBackward0>)
# tensor(76790.8281, grad_fn=<AddBackward0>)
# Epoch: 0615 train_loss= 0.10885 val_loss= 0.10917
# tensor(76790.8281, grad_fn=<AddBackward0>)
# tensor(76686.3594, grad_fn=<AddBackward0>)
# Epoch: 0616 train_loss= 0.10879 val_loss= 0.10811
# tensor(76686.3594, grad_fn=<AddBackward0>)
# tensor(76581.7969, grad_fn=<AddBackward0>)
# Epoch: 0617 train_loss= 0.10848 val_loss= 0.10825
# tensor(76581.7969, grad_fn=<AddBackward0>)
# tensor(76477.7031, grad_fn=<AddBackward0>)
# Epoch: 0618 train_loss= 0.10847 val_loss= 0.10852
# tensor(76477.7031, grad_fn=<AddBackward0>)
# tensor(76370.8750, grad_fn=<AddBackward0>)
# Epoch: 0619 train_loss= 0.10772 val_loss= 0.10714
# tensor(76370.8750, grad_fn=<AddBackward0>)
# tensor(76261.0859, grad_fn=<AddBackward0>)
# Epoch: 0620 train_loss= 0.10797 val_loss= 0.10783
# tensor(76261.0859, grad_fn=<AddBackward0>)
# tensor(76151.9766, grad_fn=<AddBackward0>)
# Epoch: 0621 train_loss= 0.10761 val_loss= 0.10653
# tensor(76151.9766, grad_fn=<AddBackward0>)
# tensor(76042.9375, grad_fn=<AddBackward0>)
# Epoch: 0622 train_loss= 0.10850 val_loss= 0.10700
# tensor(76042.9375, grad_fn=<AddBackward0>)
# tensor(75933.3281, grad_fn=<AddBackward0>)
# Epoch: 0623 train_loss= 0.10777 val_loss= 0.10581
# tensor(75933.3281, grad_fn=<AddBackward0>)
# tensor(75826.4844, grad_fn=<AddBackward0>)
# Epoch: 0624 train_loss= 0.10771 val_loss= 0.10705
# tensor(75826.4844, grad_fn=<AddBackward0>)
# tensor(75721.3281, grad_fn=<AddBackward0>)
# Epoch: 0625 train_loss= 0.10815 val_loss= 0.10665
# tensor(75721.3281, grad_fn=<AddBackward0>)
# tensor(75621.2031, grad_fn=<AddBackward0>)
# Epoch: 0626 train_loss= 0.10730 val_loss= 0.10643
# tensor(75621.2031, grad_fn=<AddBackward0>)
# tensor(75524., grad_fn=<AddBackward0>)
# Epoch: 0627 train_loss= 0.10672 val_loss= 0.10720
# tensor(75524., grad_fn=<AddBackward0>)
# tensor(75431.4453, grad_fn=<AddBackward0>)
# Epoch: 0628 train_loss= 0.10637 val_loss= 0.10652
# tensor(75431.4453, grad_fn=<AddBackward0>)
# tensor(75337.2031, grad_fn=<AddBackward0>)
# Epoch: 0629 train_loss= 0.10706 val_loss= 0.10653
# tensor(75337.2031, grad_fn=<AddBackward0>)
# tensor(75235.0234, grad_fn=<AddBackward0>)
# Epoch: 0630 train_loss= 0.10682 val_loss= 0.10702
# tensor(75235.0234, grad_fn=<AddBackward0>)
# tensor(75131.3281, grad_fn=<AddBackward0>)
# Epoch: 0631 train_loss= 0.10665 val_loss= 0.10573
# tensor(75131.3281, grad_fn=<AddBackward0>)
# tensor(75027.3438, grad_fn=<AddBackward0>)
# Epoch: 0632 train_loss= 0.10647 val_loss= 0.10643
# tensor(75027.3438, grad_fn=<AddBackward0>)
# tensor(74925.5859, grad_fn=<AddBackward0>)
# Epoch: 0633 train_loss= 0.10607 val_loss= 0.10549
# tensor(74925.5859, grad_fn=<AddBackward0>)
# tensor(74825.5781, grad_fn=<AddBackward0>)
# Epoch: 0634 train_loss= 0.10584 val_loss= 0.10616
# tensor(74825.5781, grad_fn=<AddBackward0>)
# tensor(74725.7500, grad_fn=<AddBackward0>)
# Epoch: 0635 train_loss= 0.10616 val_loss= 0.10428
# tensor(74725.7500, grad_fn=<AddBackward0>)
# tensor(74623.8906, grad_fn=<AddBackward0>)
# Epoch: 0636 train_loss= 0.10565 val_loss= 0.10540
# tensor(74623.8906, grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9c797013058b> in <module>()
#       7     train_loss = my_model.forward(train_features_tensor)
#       8     my_model.backward()
# ----> 9     val_loss = my_model.forward(val_features_tensor)
#      10     my_model.optimizer.zero_grad()
#      11     #val_loss = 0
#
# <ipython-input-2-542771661295> in forward(self, x)
#      49         self.layer_1 = torch.nn.functional.tanh(self.W0(self.drouput1(x)))
#      50         self.layer_2 = torch.nn.functional.tanh(self.W1(self.drouput2(self.layer_1)))
# ---> 51         self.layer_3 = torch.nn.functional.tanh(self.W2(self.layer_2+self.normal_dist.sample((x.shape[0],))))
#      52         self.layer_4 = self.W3(self.layer_3)
#      53
#
# /usr/local/lib/python3.6/dist-packages/torch/distributions/distribution.py in sample(self, sample_shape)
#     117         """
#     118         with torch.no_grad():
# --> 119             return self.rsample(sample_shape)
#     120
#     121     def rsample(self, sample_shape=torch.Size()):
#
# /usr/local/lib/python3.6/dist-packages/torch/distributions/multivariate_normal.py in rsample(self, sample_shape)
#     191         shape = self._extended_shape(sample_shape)
#     192         eps = _standard_normal(shape, dtype=self.loc.dtype, device=self.loc.device)
# --> 193         return self.loc + _batch_mv(self._unbroadcasted_scale_tril, eps)
#     194
#     195     def log_prob(self, value):
#
# /usr/local/lib/python3.6/dist-packages/torch/distributions/multivariate_normal.py in _batch_mv(bmat, bvec)
#      18     just ones which can be broadcasted.
#      19     """
# ---> 20     return torch.matmul(bmat, bvec.unsqueeze(-1)).squeeze(-1)
#      21
#      22
#
# KeyboardInterrupt:

# %%
my_model.forward(train_features_tensor)
my_model.drouput1.eval()
my_model.drouput2.eval()

#my_model.drouput1.train()
#my_model.drouput2.train()

print(my_model.forward(train_features_tensor))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(74516.1328, grad_fn=<AddBackward0>)
# tensor(74516.1328, grad_fn=<AddBackward0>)
# 0.10072823613882065

# %%
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
np.savetxt("/content/drive/My Drive/Data Fusion/results/emb_v15_N_0_1_dropout_0.5_L1_0.3.txt",emb,delimiter='\t')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(74516.1328, grad_fn=<AddBackward0>)

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
emb = np.loadtxt("/content/drive/My Drive/Data Fusion/results/emb_v11.txt",delimiter='\t')
# Out:
# [1, 1, 1, 1, 1]

# %%
####PCA on embedding
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
circle_areas = (truelabel[:,1].astype(float)/8)
X_embedded = PCA(n_components=2).fit_transform(emb)
plt.scatter(x=X_embedded[:,0], y=X_embedded[:,1], s=circle_areas, c= 1*np.ones(215), alpha=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(74516.1328, grad_fn=<AddBackward0>)

# %%
### TSNE on embedding
my_model.forward(train_features_tensor)
emb = my_model.embedding.detach().numpy()
circle_areas = (truelabel[:,1].astype(float)/8)
X_embedded = TSNE(n_components=2).fit_transform(emb)
plt.scatter(x=X_embedded[:,0], y=X_embedded[:,1], s=circle_areas, c= 1*np.ones(215), alpha=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# tensor(74516.1328, grad_fn=<AddBackward0>)

# %%
from sklearn.cluster import KMeans
X = emb
n_clusters=3
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(X)

for i in range(n_clusters):
    indx = np.argwhere(kmeans.labels_==i).reshape(-1)
    print(truelabel[indx][:,1].mean())
# Out:
# 626.8765432098766
# 536.3030303030303
# 573.3168316831683

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
emb = np.loadtxt("/content/drive/My Drive/Data Fusion/results/emb_v11.txt",delimiter='\t')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#print(list(my_model.W0.parameters()))
print(torch.norm(list(my_model.W0.parameters())[0],1))
#l1_regularization += torch.norm(param, 1)
#torch.norm()
# Out:
# tensor(220043., grad_fn=<NormBackward0>)
